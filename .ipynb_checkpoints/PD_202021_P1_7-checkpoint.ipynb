# %% [markdown]
# ## Data Mining / Prospeção de Dados
#
# ## Diogo Soares and Sara C. Madeira, 2020/21
#
# # Project 1 - Pattern Mining

# %% [markdown]
# ## Logistics
# **_Read Carefully_**
#
# **Students should work in teams of 2 or 3 people**.
#
# **TASK 3 - Spring vs Summer Purchases** must be done only by groups of 3 people.
#
# Individual projects might be allowed (with valid justification), but will not have better grades for this reason.
#
# The quality of the project will dictate its grade, not the number of people working.
#
# **The project's solution should be uploaded in Moodle before the end of `March, 28th (23:59)`.**
#
# Students should **upload a `.zip` file** containing all the files necessary for project evaluation.
# Groups should be registered in [Moodle](https://moodle.ciencias.ulisboa.pt/mod/groupselect/view.php?id=139096) and the zip file should be identified as `PDnn.zip` where `nn` is the number of your group.
#
# **It is mandatory to produce a Jupyter notebook containing code and text/images/tables/etc describing the solution and the results. Projects not delivered in this format will not be graded. You can use `PD_202021_P1.ipynb`as template. In your `.zip` folder you should also include an HTML version of your notebook with all the outputs** (File > Download as > HTML).
#
# **Decisions should be justified and results should be critically discussed.**
#
# _Project solutions containing only code and outputs without discussions will achieve a maximum grade 10 out of 20._

# %% [markdown]
# ## Dataset and Tools
#
#
#
# In this project you will analyse data from an online Store collected over 4 months (April - July 2014). The folder `data` contains three files that you should use to obtain the dataset to be used in pattern mining.
#
# The file `store-buys.dat` comprises the buy events of the users over the items. It contains **318.444 sessions**. Each record/line in the file has the following fields (with this order):
#
# * **Session ID** - the id of the session. In one session there are one or many buying events. Could be represented as an integer number.
# * **Timestamp** - the time when the buy occurred. Format of YYYY-MM-DDThh:mm:ss.SSSZ
# * **Item ID** – the unique identifier of item that has been bought. Could be represented as an integer number.
# * **Price** – the price of the item. Could be represented as an integer number.
# * **Quantity** – the quantity in this buying.  Could be represented as an integer number.
#
# The file `store-clicks.dat` comprises the clicks of the users over the items. It contains **5.613.499 sessions**.  Each record/line in the file has the following fields (with this order):
#
# * **Session ID** – the id of the session. In one session there are one or many clicks. Could be represented as an integer number.
# * **Timestamp** – the time when the click occurred. Format of YYYY-MM-DDThh:mm:ss.SSSZ
# * **Item ID** – the unique identifier of the item that has been clicked. Could be represented as an integer number.
# * **Context** – the context of the click. The value "S" indicates a special offer, "0" indicates  a missing value, a number between 1 to 12 indicates a real category identifier,
# any other number indicates a brand. E.g. if an item has been clicked in the context of a promotion or special offer then the value will be "S", if the context was a brand i.e BOSCH,
# then the value will be an 8-10 digits number. If the item has been clicked under regular category, i.e. sport, then the value will be a number between 1 to 12.
#
# The file `products.csv` comprises the list of products sold by the online store. It contains **46.294 different products** associated with **123 different subcategories**. Each record/line in the file has the following fields:
#
# * **Item ID** - the unique identifier of the item. Could be represented as an integer number.
# * **Product Categories** - the category and subcategories of the item. It is a string containing the category and subcategories of the item. Eg. `appliances.kitchen.juice`
#
#
# In this project you should use [Python 3](https://www.python.org), [Jupyter Notebook](http://jupyter.org) and **[MLxtend](http://rasbt.github.io/mlxtend/)**. When using MLxtend, frequent patterns can either be discovered using `Apriori` and `FP-Growth`. **Choose the pattern mining algorithm to be used.**

# %% [markdown]
# ## Team Identification
#
# **GROUP NNN**
#
# Students:
#
# * Student 1 - n_student1
# * Student 2 - n_student2
# * Student 3 - n_student3

# %% [markdown]
# ## 1. Mining Frequent Itemsets and Association Rules
#
#
# In this first part of the project you should load and preprocess the dataset  in order to compute frequent itemsets and generate association rules considering all the sessions.

# %% [markdown]
# **In what follows keep the following question in mind and be creative!**
#
# 1. What are the most interesting products?
# 2. What are the most bought products?
# 3. Which products are bought together?
# 4. Can you find associations between the clicked products?
# 5. Can you find associations highliting that when people buy a product/set of products also buy other product(s)?
# 6. Can you find associations highliting that when people click in a product/set of products also buy this product(s)?
# 7. Can you find relevant associated categories?

# %% [markdown]
# ### 1.1. Load and Preprocess Data
#
#  **Product quantities should not be considered.**

# %% [markdown]
# Here we did the imports for the models necessary for the development of this project

# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import  TransactionEncoder
from mlxtend.frequent_patterns import apriori
import mlxtend.preprocessing
import mlxtend.frequent_patterns
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpmax

# %% [markdown]
# ### 1.1.1 Product
#
# The file `products.csv` comprises the list of products sold by the online store. It contains **46.294 different products** associated with **123 different subcategories**. Each record/line in the file has the following fields:
#
# * **Item ID** - the unique identifier of the item. Could be represented as an integer number.
# * **Product Categories** - the category and subcategories of the item. It is a string containing the category and subcategories of the item. Eg. `appliances.kitchen.juice`

# %%
product_df = pd.read_csv("products.csv")
product_df.columns = ["Item_ID","Product_Categories"]
product_df.head(5)
# Out:
#      Item_ID            Product_Categories
# 0  214536500            electronics.tablet
# 1  214536506            electronics.tablet
# 2  214577561   electronics.audio.headphone
# 3  214662742       furniture.kitchen.table
# 4  214662742       furniture.kitchen.table

# %%
product_df.shape
# Out:
# (20704558, 2)

# %% [markdown]
# For this df it doesn't make sense to have the same product and product categories repeated, soo we decided to drop the duplicated rows

# %%
pdf = product_df.drop_duplicates()

# %%
pdf.shape
# Out:
# (46294, 2)

# %% [markdown]
# ### 1.1.2 Store-buys
#
# The file `store-buys.dat` comprises the buy events of the users over the items. It contains **318.444 sessions**. Each record/line in the file has the following fields (with this order):
#
# * **Session ID** - the id of the session. In one session there are one or many buying events. Could be represented as an integer number.
# * **Timestamp** - the time when the buy occurred. Format of YYYY-MM-DDThh:mm:ss.SSSZ
# * **Item ID** – the unique identifier of item that has been bought. Could be represented as an integer number.
# * **Price** – the price of the item. Could be represented as an integer number.
# * **Quantity** – the quantity in this buying.  Could be represented as an integer number.

# %%
store_buys = pd.read_csv("store-buys.dat")

store_buys.columns = ["Session_ID","Timestamp","Item_ID", "Price", "Quantity"]

store_buys.head(5)
# Out:
#    Session_ID                 Timestamp    Item_ID  Price  Quantity
# 0      420374  2014-04-06T18:44:58.325Z  214537850  10471         1
# 1      281626  2014-04-06T09:40:13.032Z  214535653   1883         1
# 2      420368  2014-04-04T06:13:28.848Z  214530572   6073         1
# 3      420368  2014-04-04T06:13:28.858Z  214835025   2617         1
# 4      140806  2014-04-07T09:22:28.132Z  214668193    523         1

# %% [markdown]
# As product quantities should not be considered we dropped the collumn regarding the quantity.
#
# We also decided to drop te collumn relative to the price of the products since they are not relevant for the analysis of the dataframes of this project.

# %%
store_buys = store_buys.drop("Quantity",axis=1)
store_buys = store_buys.drop("Price",axis=1)
store_buys.head(5)
# Out:
#    Session_ID                 Timestamp    Item_ID
# 0      420374  2014-04-06T18:44:58.325Z  214537850
# 1      281626  2014-04-06T09:40:13.032Z  214535653
# 2      420368  2014-04-04T06:13:28.848Z  214530572
# 3      420368  2014-04-04T06:13:28.858Z  214835025
# 4      140806  2014-04-07T09:22:28.132Z  214668193

# %% [markdown]
# ### 1.1.3 Store-clicks
#
#
# The file `store-clicks.dat` comprises the clicks of the users over the items. It contains **5.613.499 sessions**.  Each record/line in the file has the following fields (with this order):
#
# * **Session ID** – the id of the session. In one session there are one or many clicks. Could be represented as an integer number.
# * **Timestamp** – the time when the click occurred. Format of YYYY-MM-DDThh:mm:ss.SSSZ
# * **Item ID** – the unique identifier of the item that has been clicked. Could be represented as an integer number.
# * **Context** – the context of the click. The value "S" indicates a special offer, "0" indicates  a missing value, a number between 1 to 12 indicates a real category identifier,
# any other number indicates a brand. E.g. if an item has been clicked in the context of a promotion or special offer then the value will be "S", if the context was a brand i.e BOSCH,
# then the value will be an 8-10 digits number. If the item has been clicked under regular category, i.e. sport, then the value will be a number between 1 to 12.

# %%
store_clicks = pd.read_csv("store-clicks.dat")

store_clicks.columns = ["Session_ID","Timestamp","Item_ID", "Context"]

store_clicks.head(5)
# Out:
# D:\Apps\ANACONDA\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Session_ID                 Timestamp    Item_ID Context
# 0           1  2014-04-07T10:54:09.868Z  214536500       0
# 1           1  2014-04-07T10:54:46.998Z  214536506       0
# 2           1  2014-04-07T10:57:00.306Z  214577561       0
# 3           2  2014-04-07T13:56:37.614Z  214662742       0
# 4           2  2014-04-07T13:57:19.373Z  214662742       0

# %%
store_clicks.shape
# Out:
# (20704558, 4)

# %% [markdown]
# Since the parameter "context" represents the context of the click, this means, when the value of the "context" is 0 indicates a missing value. Then, we decided to drop all the products with context equal to "0" because it's not relevant in this case .

# %%
indexNames = store_clicks[store_clicks['Context']==0].index
store_clicks.drop(indexNames , inplace=True)
store_clicks.shape
# Out:
# (6155566, 4)

# %% [markdown]
# In this section we only wanted the transactions where the users finished the purchase. This means that we only consider the transactions where the clicked products are actually bought.
#
# The "buyers list" corresponds to the list of the sessions where the purchase was carried out.

# %%
buyers_list = list(store_buys.Session_ID.unique())
store_clicks = store_clicks.loc[store_clicks.Session_ID.isin(buyers_list)]
store_clicks.shape
# Out:
# (606709, 4)

# %% [markdown]
# ### 1.1.4 Merge store-buys and product_df
#
# We merged store_buys with pdf (product df) in order to correspond the description of the product with his associated Item_ID.

# %%
masterdf = pd.merge(pdf.set_index('Item_ID'), store_buys.set_index('Item_ID'),on='Item_ID')
masterdf = masterdf.reset_index()

# %%
masterdf = masterdf[['Session_ID','Item_ID','Product_Categories','Timestamp']]

# %%
masterdf
# Out:
#         Session_ID    Item_ID          Product_Categories  \
# 0          2859734  214536500          electronics.tablet
# 1          4276371  214536500          electronics.tablet
# 2          4440056  214536500          electronics.tablet
# 3            70532  214536506          electronics.tablet
# 4           691119  214536506          electronics.tablet
# ...            ...        ...                         ...
# 679483     6649378  214851182   furniture.universal.light
# 679484     6649378  214851182   furniture.universal.light
# 679485     7001599  214571152            stationery.paper
# 679486     6961172  214571152            stationery.paper
# 679487     6873084  214847137                sport.tennis
#
#                        Timestamp
# 0       2014-05-14T12:06:02.717Z
# 1       2014-06-04T13:44:10.725Z
# 2       2014-06-14T19:14:00.581Z
# 3       2014-04-06T09:59:03.143Z
# 4       2014-04-14T15:56:30.514Z
# ...                          ...
# 679483  2014-07-28T15:33:57.709Z
# 679484  2014-07-28T15:53:12.209Z
# 679485  2014-07-24T20:16:42.857Z
# 679486  2014-07-28T19:39:09.688Z
# 679487  2014-07-23T14:35:11.496Z
#
# [679488 rows x 4 columns]

# %% [markdown]
# "buy_transactions" is a list of lists (nested list) where each list element is a list by itself. Each one of these lists represent a transaction of a given session ID.

# %%
buy_transactions= []
for i in list(masterdf.Session_ID.unique()):
    buy_transactions.append(masterdf[masterdf.Session_ID==i].Product_Categories.values.tolist())
    
buy_transactions
# Out:
# [[' electronics.tablet'],
#  [' electronics.tablet', ' computers.peripherals.monitor'],
#  [' electronics.tablet', ' sport.tennis'],
#  [' electronics.tablet'],
#  [' electronics.tablet',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' furniture.living_room.cabinet'],
#  [' furniture.kitchen.table', ' computers.components.memory'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv'],
#  [' furniture.kitchen.table', ' electronics.audio.dictaphone'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table', ' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table',
#   ' computers.components.videocards',
#   ' furniture.kitchen.table',
#   ' country_yard.lawn_mower'],
#  [' electronics.smartphone', ' computers.components.memory'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.iron',
#   ' appliances.environment.water_heater',
#   ' construction.tools.heater'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' computers.peripherals.scanner'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' computers.notebook'],
#  [' appliances.kitchen.refrigerators', ' appliances.sewing_machine'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators', ' medicine.tools.tonometer'],
#  [' appliances.kitchen.refrigerators', ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators',
#   ' construction.tools.screw',
#   ' furniture.kitchen.table',
#   ' stationery.stapler',
#   ' appliances.kitchen.coffee_machine',
#   ' apparel.trousers',
#   ' construction.tools.heater',
#   ' construction.tools.saw',
#   ' construction.tools.heater',
#   ' computers.components.cpu',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.hdd',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' construction.tools.heater'],
#  [' appliances.kitchen.refrigerators', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.motherboard'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.water_heater'],
#  [' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.peripherals.camera',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.camera'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.living_room.cabinet',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.hood',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' country_yard.cultivator',
#   ' apparel.trousers'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.environment.air_heater'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.components.memory'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' furniture.living_room.shelving',
#   ' appliances.kitchen.blender'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' stationery.cartrige'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.peripherals.mouse'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' auto.accessories.player'],
#  [' electronics.video.tv', ' electronics.video.tv', ' accessories.bag'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' accessories.bag', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.mixer', ' electronics.tablet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.components.memory'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.telephone'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' computers.desktop',
#   ' computers.peripherals.mouse',
#   ' construction.tools.saw'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.steam_cooker'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.clocks', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' furniture.living_room.cabinet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.microwave'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' auto.accessories.videoregister'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' furniture.living_room.shelving'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.cartrige',
#   ' computers.components.cpu'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.paper',
#   ' sport.tennis',
#   ' appliances.environment.fan'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.kitchen.table',
#   ' computers.components.videocards'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' apparel.costume',
#   ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.bedroom.blanket',
#   ' furniture.bedroom.blanket',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' apparel.shoes', ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' electronics.telephone',
#   ' appliances.iron'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' sport.bicycle',
#   ' construction.tools.generator'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.printer'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.mouse'],
#  [' computers.components.cpu',
#   ' computers.notebook',
#   ' apparel.sock',
#   ' furniture.living_room.sofa'],
#  [' computers.components.cpu',
#   ' appliances.environment.water_heater',
#   ' computers.peripherals.scanner'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.kitchen.microwave'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.toster'],
#  [' computers.components.cpu', ' computers.peripherals.monitor'],
#  [' computers.components.cpu', ' medicine.tools.tonometer'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' construction.tools.welding',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' computers.notebook', ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.power_supply'],
#  [' computers.components.cpu',
#   ' appliances.environment.climate',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' electronics.tablet',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.dishwasher',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' kids.toys'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.peripherals.camera',
#   ' electronics.tablet',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.steam_cleaner'],
#  [' computers.components.cpu', ' appliances.kitchen.toster', ' sport.tennis'],
#  [' computers.components.cpu', ' accessories.bag', ' sport.tennis'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.notebook', ' sport.ski'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' apparel.trousers'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' auto.accessories.videoregister',
#   ' furniture.living_room.shelving',
#   ' electronics.video.projector',
#   ' apparel.trousers'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook', ' furniture.bedroom.blanket'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' apparel.trousers',
#   ' apparel.trousers',
#   ' country_yard.watering',
#   ' country_yard.watering'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.audio.microphone',
#   ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' accessories.bag',
#   ' sport.bicycle',
#   ' accessories.bag'],
#  [' computers.notebook',
#   ' computers.peripherals.printer',
#   ' computers.components.motherboard',
#   ' electronics.telephone'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.peripherals.camera'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' construction.tools.screw'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook', ' appliances.environment.fan'],
#  [' computers.notebook', ' appliances.environment.water_heater'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.telephone',
#   ' computers.components.memory',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' apparel.costume'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.hdd',
#   ' computers.peripherals.printer'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.components.memory', ' sport.tennis'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' apparel.tshirt', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' apparel.shirt'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook', ' apparel.shirt'],
#  [' computers.notebook', ' electronics.camera.video'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.gaming',
#   ' apparel.sock',
#   ' electronics.clocks'],
#  [' computers.notebook', ' computers.peripherals.scanner', ' apparel.costume'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.notebook',
#   ' furniture.living_room.chair',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.headphone',
#   ' apparel.glove',
#   ' construction.tools.heater',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster'],
#  [' computers.notebook', ' electronics.video.tv'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.components.cooler'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.monitor',
#   ' appliances.iron',
#   ' appliances.kitchen.kettle'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' stationery.cartrige'],
#  [' computers.peripherals.monitor', ' stationery.battery'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' appliances.kitchen.toster'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.printer'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' accessories.bag'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' electronics.video.tv'],
#  [' appliances.kitchen.kettle',
#   ' electronics.camera.photo',
#   ' computers.peripherals.mouse',
#   ' sport.ski',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' stationery.cartrige',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' furniture.bedroom.pillow'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.ironing_board',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' appliances.iron'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' sport.tennis',
#   ' appliances.environment.climate'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.video.tv',
#   ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' furniture.bedroom.pillow',
#   ' construction.tools.screw'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' auto.accessories.videoregister'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' stationery.battery'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.watering',
#   ' appliances.environment.vacuum',
#   ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' apparel.trousers'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.tablet'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' appliances.iron',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.air_conditioner',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.screw',
#   ' appliances.environment.fan',
#   ' construction.tools.screw',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.fan'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.ebooks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.videocards',
#   ' accessories.bag'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' furniture.kitchen.table'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' electronics.clocks',
#   ' computers.components.hdd'],
#  [' computers.components.memory', ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.ebooks',
#   ' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' appliances.environment.climate',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' electronics.camera.video',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' appliances.environment.climate'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.ebooks',
#   ' accessories.umbrella'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_grinder',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.printer'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.camera.photo'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory', ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.air_conditioner',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' auto.accessories.compressor'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' appliances.environment.climate'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' accessories.umbrella'],
#  [' computers.components.memory', ' electronics.audio.headphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards'],
#  [' computers.components.memory', ' appliances.iron', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow'],
#  [' computers.components.memory', ' computers.components.videocards'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.telephone',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.peripherals.camera',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' apparel.sock',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.dishwasher'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.ebooks',
#   ' computers.ebooks'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' computers.desktop'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' construction.tools.welding',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.juicer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' construction.tools.screw',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.microwave',
#   ' auto.accessories.alarm'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.welding',
#   ' computers.components.memory',
#   ' construction.tools.generator',
#   ' apparel.trousers',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.ebooks',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.ebooks',
#   ' appliances.kitchen.blender',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' electronics.audio.subwoofer',
#   ' auto.accessories.radar'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.environment.fan'],
#  [' computers.components.memory', ' stationery.cartrige'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.telephone'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' auto.accessories.player',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' appliances.environment.fan'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' stationery.battery'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
# ...
#  [' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.notebook',
#   ' computers.peripherals.printer',
#   ' sport.tennis'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' construction.tools.light',
#   ' appliances.kitchen.blender',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory', ' electronics.calculator'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.smartphone',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' appliances.iron', ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.juicer',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' medicine.tools.tonometer',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' electronics.clocks'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.living_room.shelving',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.generator',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.calculator',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' kids.toys',
#   ' electronics.video.tv',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.living_room.shelving',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' electronics.video.tv',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' computers.notebook',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.grill',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.steam_cooker',
#   ' electronics.video.tv',
#   ' furniture.kitchen.table',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' computers.ebooks'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' furniture.kitchen.chair',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.personal.hair_cutter',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' construction.tools.welding',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' furniture.living_room.sofa',
#   ' sport.tennis',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.blender',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.juicer',
#   ' appliances.environment.air_conditioner',
#   ' electronics.telephone',
#   ' computers.desktop',
#   ' electronics.camera.video',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' furniture.bedroom.pillow',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' kids.toys',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' construction.tools.screw',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' appliances.personal.massager',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.environment.climate',
#   ' computers.components.videocards',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks'],
#  [' computers.components.memory', ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' construction.tools.welding',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower',
#   ' country_yard.cultivator'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.washer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.fan',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' furniture.bedroom.pillow'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory', ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory', ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' kids.bottles',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' stationery.battery',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' furniture.living_room.shelving',
#   ' electronics.calculator',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' apparel.tshirt',
#   ' appliances.kitchen.hood',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' electronics.video.tv',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.notebook'],
#  ...]

# %% [markdown]
# Since The Apriori implementation at MLxtend receives a binary databse, we used "TransactionEncoder()" to transform the transactions list in binary database

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(buy_transactions).transform(buy_transactions)
binary_database = pd.DataFrame(trans_array, columns=tr_enc.columns_)
binary_database
# Out:
#          accessories.bag   accessories.umbrella   apparel.costume  \
# 0                  False                  False             False
# 1                  False                  False             False
# 2                  False                  False             False
# 3                  False                  False             False
# 4                  False                  False             False
# ...                  ...                    ...               ...
# 318439             False                  False             False
# 318440             False                  False             False
# 318441             False                  False             False
# 318442             False                  False             False
# 318443             False                  False             False
#
#          apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0                False           False           False          False
# 1                False           False           False          False
# 2                False           False           False          False
# 3                False           False           False          False
# 4                False           False           False          False
# ...                ...             ...             ...            ...
# 318439           False           False           False          False
# 318440           False           False           False          False
# 318441           False           False           False          False
# 318442           False           False           False          False
# 318443           False           False           False          False
#
#          apparel.trousers   apparel.tshirt  \
# 0                   False            False
# 1                   False            False
# 2                   False            False
# 3                   False            False
# 4                   False            False
# ...                   ...              ...
# 318439              False            False
# 318440              False            False
# 318441              False            False
# 318442              False            False
# 318443              False            False
#
#          appliances.environment.air_conditioner  ...   sport.bicycle  \
# 0                                         False  ...           False
# 1                                         False  ...           False
# 2                                         False  ...           False
# 3                                         False  ...           False
# 4                                         False  ...           False
# ...                                         ...  ...             ...
# 318439                                    False  ...           False
# 318440                                    False  ...           False
# 318441                                    False  ...           False
# 318442                                    False  ...           False
# 318443                                    False  ...           False
#
#          sport.diving   sport.ski   sport.snowboard   sport.tennis  \
# 0               False       False             False          False
# 1               False       False             False          False
# 2               False       False             False           True
# 3               False       False             False          False
# 4               False       False             False          False
# ...               ...         ...               ...            ...
# 318439          False       False             False          False
# 318440          False       False             False          False
# 318441          False       False             False          False
# 318442          False       False             False          False
# 318443          False       False             False          False
#
#          sport.trainer   stationery.battery   stationery.cartrige  \
# 0                False                False                 False
# 1                False                False                 False
# 2                False                False                 False
# 3                False                False                 False
# 4                False                False                 False
# ...                ...                  ...                   ...
# 318439           False                False                 False
# 318440           False                False                 False
# 318441           False                False                 False
# 318442           False                False                 False
# 318443           False                False                 False
#
#          stationery.paper   stationery.stapler
# 0                   False                False
# 1                   False                False
# 2                   False                False
# 3                   False                False
# 4                   False                False
# ...                   ...                  ...
# 318439              False                False
# 318440              False                False
# 318441              False                False
# 318442              False                False
# 318443              False                False
#
# [318444 rows x 123 columns]

# %% [markdown]
# ### 1.1.5  Merge store-clicks and product_df
#
# We merged store_clicks with pdf (product df) in order to correspond the description of the product with his associated Item_ID.

# %%
clickprod_df = pd.merge(pdf.set_index('Item_ID'), store_clicks.set_index('Item_ID'),on='Item_ID')
clickprod_df = clickprod_df.reset_index()

# %%
clickprod_df = clickprod_df[['Session_ID','Item_ID','Product_Categories','Timestamp']]

# %%
clickprod_df
# Out:
#         Session_ID    Item_ID              Product_Categories  \
# 0          5737263  214536500              electronics.tablet
# 1          5737263  214536500              electronics.tablet
# 2          5702866  214536500              electronics.tablet
# 3          6172052  214536500              electronics.tablet
# 4          5879836  214536500              electronics.tablet
# ...            ...        ...                             ...
# 606704     6860077  214712259   computers.peripherals.scanner
# 606705     6857052  214846592         country_yard.lawn_mower
# 606706     6883899  214822181         furniture.bathroom.bath
# 606707     6883899  214823535     electronics.audio.subwoofer
# 606708     6938531  214808205        computers.network.router
#
#                        Timestamp
# 0       2014-07-03T21:16:08.804Z
# 1       2014-07-03T21:21:22.935Z
# 2       2014-07-06T18:34:10.251Z
# 3       2014-07-11T10:50:14.687Z
# 4       2014-07-10T18:54:15.150Z
# ...                          ...
# 606704  2014-07-23T20:14:38.234Z
# 606705  2014-07-27T15:47:53.609Z
# 606706  2014-07-23T06:42:59.242Z
# 606707  2014-07-23T06:43:24.528Z
# 606708  2014-07-24T20:07:04.296Z
#
# [606709 rows x 4 columns]

# %% [markdown]
# "click_transactions" is a list of lists (nested list) where each list element is a list by itself. Each one of these lists represent a transaction of a given session ID.

# %%
click_transactions= []

for i in list(clickprod_df.Session_ID.unique()):
    click_transactions.append(clickprod_df[clickprod_df.Session_ID==i].Product_Categories.values.tolist())
    
click_transactions
# Out:
# [[' electronics.tablet',
#   ' electronics.tablet',
#   ' kids.swing',
#   ' appliances.environment.air_heater',
#   ' appliances.kitchen.washer',
#   ' kids.swing',
#   ' kids.swing',
#   ' kids.swing',
#   ' computers.components.videocards',
#   ' construction.tools.drill'],
#  [' electronics.tablet',
#   ' kids.swing',
#   ' electronics.tablet',
#   ' appliances.kitchen.steam_cooker',
#   ' furniture.living_room.shelving',
#   ' furniture.living_room.chair',
#   ' construction.tools.generator',
#   ' furniture.kitchen.chair',
#   ' construction.tools.pump',
#   ' appliances.environment.air_conditioner',
#   ' construction.tools.pump',
#   ' furniture.kitchen.chair',
#   ' furniture.kitchen.chair',
#   ' construction.tools.pump',
#   ' furniture.living_room.chair',
#   ' sport.ski',
#   ' stationery.cartrige',
#   ' computers.components.videocards',
#   ' furniture.living_room.shelving',
#   ' appliances.environment.vacuum',
#   ' kids.fmcg.diapers',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' electronics.tablet',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' computers.components.videocards'],
#  [' electronics.tablet',
#   ' computers.peripherals.mouse',
#   ' electronics.tablet',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' apparel.tshirt',
#   ' sport.snowboard',
#   ' country_yard.cultivator',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer'],
#  [' furniture.kitchen.table',
#   ' computers.components.motherboard',
#   ' computers.components.memory',
#   ' electronics.audio.headphone',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' apparel.tshirt',
#   ' furniture.bedroom.pillow',
#   ' furniture.kitchen.table',
#   ' electronics.calculator',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' kids.bottles'],
#  [' furniture.kitchen.table',
#   ' computers.components.cpu',
#   ' computers.peripherals.keyboard',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' accessories.bag',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.mixer',
#   ' furniture.living_room.cabinet',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.toster',
#   ' apparel.shoes',
#   ' appliances.sewing_machine',
#   ' computers.peripherals.scanner',
#   ' construction.tools.generator',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' computers.components.power_supply',
#   ' electronics.tablet',
#   ' appliances.kitchen.coffee_machine',
#   ' computers.components.power_supply',
#   ' auto.accessories.videoregister',
#   ' furniture.bedroom.pillow',
#   ' furniture.living_room.shelving',
#   ' electronics.audio.headphone',
#   ' electronics.telephone',
#   ' computers.components.power_supply',
#   ' appliances.personal.hair_cutter',
#   ' kids.toys',
#   ' auto.accessories.anti_freeze',
#   ' furniture.kitchen.table',
#   ' electronics.video.tv',
#   ' computers.components.cpu',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' furniture.kitchen.table',
#   ' furniture.kitchen.table',
#   ' furniture.bedroom.pillow',
#   ' computers.components.memory',
#   ' construction.tools.light',
#   ' electronics.calculator',
#   ' furniture.kitchen.table',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' appliances.steam_cleaner'],
#  [' furniture.kitchen.table',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.mouse',
#   ' computers.components.videocards',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' electronics.audio.microphone',
#   ' furniture.bedroom.bed',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' appliances.iron',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.printer',
#   ' appliances.personal.hair_cutter',
#   ' computers.gaming',
#   ' furniture.bedroom.bed',
#   ' appliances.kitchen.mixer',
#   ' electronics.clocks',
#   ' kids.skates',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.bicycle',
#   ' sport.bicycle',
#   ' appliances.kitchen.dishwasher',
#   ' furniture.kitchen.table',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' apparel.glove',
#   ' apparel.glove',
#   ' electronics.clocks',
#   ' computers.components.cooler',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' electronics.smartphone',
#   ' electronics.smartphone',
#   ' appliances.environment.climate',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.iron'],
#  [' furniture.kitchen.table',
#   ' appliances.kitchen.blender',
#   ' accessories.bag',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.environment.climate',
#   ' construction.tools.light',
#   ' electronics.video.projector',
#   ' construction.tools.light',
#   ' auto.accessories.player',
#   ' appliances.kitchen.hood',
#   ' kids.toys',
#   ' furniture.kitchen.table',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' furniture.kitchen.table',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.light',
#   ' computers.peripherals.camera',
#   ' furniture.kitchen.table',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' appliances.environment.vacuum',
#   ' construction.tools.drill'],
#  [' furniture.kitchen.table',
#   ' appliances.kitchen.coffee_grinder',
#   ' appliances.environment.climate',
#   ' computers.components.videocards',
#   ' computers.peripherals.printer',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' electronics.audio.headphone',
#   ' construction.tools.light',
#   ' computers.peripherals.printer',
#   ' apparel.tshirt',
#   ' furniture.kitchen.table',
#   ' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' furniture.kitchen.table',
#   ' accessories.bag',
#   ' stationery.cartrige',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.juicer',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.coffee_machine',
#   ' electronics.audio.headphone',
#   ' country_yard.weather_station',
#   ' country_yard.weather_station',
#   ' appliances.personal.scales',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.toster',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' furniture.kitchen.table',
#   ' computers.components.motherboard',
#   ' electronics.audio.headphone',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' construction.tools.screw',
#   ' construction.tools.light',
#   ' appliances.iron',
#   ' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower'],
#  [' electronics.smartphone',
#   ' computers.peripherals.scanner',
#   ' furniture.kitchen.table',
#   ' construction.tools.drill',
#   ' computers.components.cpu',
#   ' electronics.audio.subwoofer',
#   ' electronics.calculator',
#   ' kids.toys',
#   ' kids.toys',
#   ' kids.toys',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.refrigerators',
#   ' kids.fmcg.diapers',
#   ' electronics.camera.video',
#   ' computers.ebooks',
#   ' appliances.sewing_machine',
#   ' computers.notebook',
#   ' furniture.living_room.cabinet',
#   ' furniture.living_room.cabinet',
#   ' furniture.universal.light',
#   ' electronics.camera.video',
#   ' appliances.environment.fan',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light'],
#  [' appliances.kitchen.refrigerators', ' sport.tennis'],
#  [' appliances.kitchen.refrigerators',
#   ' electronics.camera.photo',
#   ' electronics.camera.photo',
#   ' computers.network.router',
#   ' stationery.battery',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.camera',
#   ' appliances.kitchen.juicer',
#   ' furniture.living_room.cabinet',
#   ' construction.tools.screw',
#   ' kids.fmcg.diapers',
#   ' stationery.paper',
#   ' electronics.audio.subwoofer',
#   ' electronics.calculator',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.mixer',
#   ' appliances.personal.hair_cutter',
#   ' appliances.kitchen.microwave'],
#  [' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' computers.desktop',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' medicine.tools.tonometer'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' furniture.kitchen.chair',
#   ' appliances.environment.air_heater',
#   ' construction.tools.pump',
#   ' furniture.kitchen.chair',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' medicine.tools.tonometer'],
#  [' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [' appliances.personal.scales', ' sport.ski'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.network.router',
#   ' appliances.steam_cleaner'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.components.hdd',
#   ' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' computers.components.cdrw',
#   ' furniture.living_room.chair',
#   ' computers.ebooks',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.juicer',
#   ' furniture.living_room.shelving',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' stationery.paper',
#   ' apparel.glove',
#   ' apparel.glove'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.ebooks',
#   ' kids.toys',
#   ' construction.tools.light',
#   ' furniture.living_room.sofa',
#   ' electronics.telephone',
#   ' apparel.shoes',
#   ' electronics.audio.microphone',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' appliances.kitchen.microwave',
#   ' apparel.sock',
#   ' electronics.smartphone',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.microwave',
#   ' computers.components.hdd'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' furniture.living_room.chair',
#   ' appliances.personal.scales'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' accessories.bag'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.personal.hair_cutter',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.clocks',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.clocks',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.clocks'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' furniture.kitchen.chair',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.microwave',
#   ' appliances.environment.water_heater',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' computers.peripherals.printer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' apparel.tshirt',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.personal.hair_cutter',
#   ' computers.components.hdd',
#   ' appliances.kitchen.mixer',
#   ' computers.components.videocards',
#   ' apparel.tshirt',
#   ' appliances.kitchen.steam_cooker',
#   ' furniture.bedroom.pillow',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' kids.bottles',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' kids.bottles',
#   ' kids.bottles'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.peripherals.scanner',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' sport.trainer',
#   ' computers.components.videocards'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.iron',
#   ' computers.components.hdd',
#   ' computers.components.cdrw',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.environment.vacuum',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' construction.tools.screw',
#   ' auto.accessories.radar',
#   ' auto.accessories.radar',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv', ' computers.components.memory'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' construction.tools.heater',
#   ' construction.tools.heater',
#   ' computers.network.router',
#   ' construction.tools.heater',
#   ' construction.tools.heater',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' construction.tools.heater',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer',
#   ' construction.tools.drill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv', ' electronics.video.tv', ' computers.notebook'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.printer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.camera',
#   ' electronics.clocks'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.audio.dictaphone',
#   ' electronics.video.tv',
#   ' computers.peripherals.joystick',
#   ' electronics.video.tv',
#   ' appliances.personal.scales',
#   ' construction.tools.heater',
#   ' electronics.calculator',
#   ' apparel.sock',
#   ' auto.accessories.videoregister',
#   ' construction.tools.screw',
#   ' medicine.tools.tonometer',
#   ' country_yard.weather_station',
#   ' auto.accessories.radar',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.heater',
#   ' electronics.telephone',
#   ' furniture.kitchen.chair',
#   ' electronics.audio.microphone',
#   ' apparel.trousers',
#   ' sport.snowboard',
#   ' computers.components.videocards',
#   ' sport.tennis',
#   ' sport.diving',
#   ' computers.peripherals.monitor',
#   ' kids.fmcg.diapers',
#   ' electronics.smartphone',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' construction.tools.drill'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' sport.trainer',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' computers.components.power_supply',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' apparel.sock',
#   ' furniture.kitchen.chair'],
#  [' electronics.video.tv',
#   ' electronics.camera.photo',
#   ' medicine.tools.tonometer',
#   ' auto.accessories.compressor',
#   ' medicine.tools.tonometer',
#   ' furniture.kitchen.chair',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' kids.bottles'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.meat_grinder',
#   ' apparel.tshirt'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' appliances.personal.scales'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.iron',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.scanner',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' furniture.bedroom.pillow',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' furniture.universal.light',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.telephone',
#   ' electronics.telephone',
#   ' furniture.bathroom.toilet',
#   ' appliances.ironing_board',
#   ' furniture.bathroom.toilet',
#   ' electronics.video.tv',
#   ' computers.components.videocards',
#   ' appliances.kitchen.fryer',
#   ' computers.components.power_supply',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' kids.toys',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.scanner',
#   ' electronics.video.tv',
#   ' computers.peripherals.mouse',
#   ' apparel.shirt',
#   ' appliances.kitchen.grill',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.hood',
#   ' auto.accessories.anti_freeze',
#   ' furniture.bedroom.bed',
#   ' stationery.stapler',
#   ' accessories.bag',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.dishwasher',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.monitor',
#   ' sport.snowboard',
#   ' auto.accessories.radar',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' apparel.shoes',
#   ' apparel.shoes',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' appliances.iron',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' kids.toys',
#   ' medicine.tools.tonometer',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' computers.components.memory',
#   ' furniture.living_room.shelving',
#   ' stationery.battery',
#   ' stationery.battery',
#   ' sport.snowboard',
#   ' auto.accessories.videoregister',
#   ' electronics.calculator',
#   ' furniture.living_room.cabinet',
#   ' electronics.video.tv',
#   ' electronics.clocks',
#   ' auto.accessories.radar',
#   ' computers.gaming',
#   ' computers.gaming',
#   ' country_yard.cultivator',
#   ' furniture.living_room.chair',
#   ' country_yard.weather_station',
#   ' computers.ebooks',
#   ' country_yard.lawn_mower',
#   ' stationery.stapler',
#   ' sport.snowboard',
#   ' sport.snowboard',
#   ' apparel.glove',
#   ' electronics.calculator',
#   ' appliances.kitchen.washer',
#   ' stationery.stapler',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.dishwasher',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.coffee_machine',
#   ' electronics.video.tv',
#   ' appliances.environment.climate',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' appliances.kitchen.microwave',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.audio.headphone',
#   ' apparel.shoes',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.iron',
#   ' stationery.battery',
#   ' appliances.kitchen.coffee_machine',
#   ' stationery.battery',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.network.router',
#   ' computers.network.router',
#   ' computers.network.router',
#   ' construction.tools.screw',
#   ' furniture.bedroom.bed',
#   ' auto.accessories.anti_freeze',
#   ' appliances.kitchen.dishwasher',
#   ' electronics.clocks',
#   ' construction.tools.screw',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' construction.components.faucet',
#   ' construction.components.faucet',
#   ' construction.components.faucet'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.audio.dictaphone',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' electronics.video.tv',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster',
#   ' kids.bottles',
#   ' appliances.kitchen.grill',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.personal.scales',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' computers.components.cdrw',
#   ' electronics.calculator',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.juicer',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' kids.bottles',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' electronics.calculator'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' apparel.shoes',
#   ' kids.skates',
#   ' stationery.stapler',
#   ' appliances.iron',
#   ' construction.tools.heater',
#   ' appliances.kitchen.kettle',
#   ' furniture.kitchen.chair',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.climate',
#   ' furniture.bedroom.blanket',
#   ' apparel.shoes',
#   ' furniture.bedroom.pillow',
#   ' sport.tennis',
#   ' computers.components.power_supply',
#   ' kids.bottles'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.smartphone',
#   ' appliances.kitchen.mixer'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' apparel.costume',
#   ' apparel.costume',
#   ' apparel.costume',
#   ' apparel.costume',
#   ' apparel.costume',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' apparel.sock',
#   ' computers.ebooks',
#   ' furniture.bedroom.blanket',
#   ' country_yard.cultivator'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' sport.ski',
#   ' sport.ski',
#   ' sport.ski',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.personal.scales',
#   ' sport.ski',
#   ' computers.components.cpu',
#   ' sport.ski'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.audio.subwoofer',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' apparel.trousers',
#   ' computers.peripherals.monitor',
#   ' furniture.bedroom.bed',
#   ' appliances.kitchen.fryer',
#   ' appliances.environment.water_heater',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.battery',
#   ' apparel.tshirt',
#   ' computers.notebook',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill'],
#  [' computers.components.cpu',
#   ' electronics.audio.dictaphone',
#   ' appliances.environment.water_heater',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' furniture.living_room.sofa',
#   ' furniture.living_room.sofa'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.kitchen.fryer',
#   ' construction.tools.generator',
#   ' electronics.tablet',
#   ' construction.tools.heater',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' country_yard.watering',
#   ' country_yard.watering',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.camera',
#   ' kids.fmcg.diapers',
#   ' kids.toys',
#   ' kids.toys',
#   ' computers.gaming',
#   ' construction.tools.heater',
#   ' auto.accessories.videoregister',
#   ' computers.notebook',
#   ' construction.tools.generator',
#   ' stationery.cartrige',
#   ' computers.components.cooler',
#   ' construction.tools.saw',
#   ' construction.tools.heater',
#   ' electronics.tablet',
#   ' furniture.universal.light',
#   ' computers.components.cpu',
#   ' appliances.environment.air_conditioner',
#   ' construction.tools.generator',
#   ' appliances.kitchen.oven',
#   ' construction.tools.heater',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.dishwasher',
#   ' computers.components.cooler',
#   ' appliances.kitchen.kettle',
#   ' sport.tennis',
#   ' apparel.trousers'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.video.tv',
#   ' kids.toys',
#   ' kids.toys',
#   ' sport.bicycle',
#   ' sport.bicycle',
#   ' computers.components.cpu',
#   ' electronics.calculator',
#   ' computers.components.memory'],
#  [' computers.components.cpu',
#   ' kids.swing',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' furniture.living_room.cabinet',
#   ' appliances.ironing_board',
#   ' appliances.ironing_board',
#   ' apparel.sock',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.tablet',
#   ' computers.peripherals.camera',
#   ' computers.components.cooler',
#   ' apparel.shirt',
#   ' computers.peripherals.scanner',
#   ' electronics.tablet',
#   ' computers.components.cooler',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' stationery.battery',
#   ' construction.tools.drill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' computers.components.cpu', ' computers.desktop'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cooler',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' appliances.environment.vacuum'],
#  [' computers.components.cpu',
#   ' stationery.cartrige',
#   ' furniture.universal.light',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.kitchen.blender',
#   ' construction.tools.generator',
#   ' electronics.audio.headphone',
#   ' electronics.audio.headphone',
#   ' apparel.trousers',
#   ' stationery.paper',
#   ' computers.components.cpu',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.cpu', ' electronics.clocks', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' kids.swing',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.personal.massager',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.cpu', ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' furniture.bedroom.pillow',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.keyboard',
#   ' computers.notebook',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.monitor',
#   ' electronics.video.tv',
#   ' furniture.living_room.sofa',
#   ' kids.toys',
#   ' appliances.environment.air_conditioner',
#   ' appliances.environment.climate',
#   ' appliances.kitchen.washer',
#   ' computers.components.cpu',
#   ' appliances.environment.air_conditioner',
#   ' appliances.personal.massager',
#   ' computers.desktop',
#   ' apparel.shirt',
#   ' furniture.bedroom.blanket',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' auto.accessories.radar',
#   ' appliances.steam_cleaner',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.components.cpu',
#   ' sport.bicycle',
#   ' appliances.iron',
#   ' kids.toys',
#   ' apparel.sock',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' apparel.trousers',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' furniture.living_room.chair',
#   ' appliances.iron',
#   ' kids.toys',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' apparel.glove',
#   ' country_yard.lawn_mower'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.iron',
#   ' electronics.audio.microphone',
#   ' appliances.kitchen.blender',
#   ' country_yard.cultivator',
#   ' appliances.kitchen.coffee_machine',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' construction.tools.screw',
#   ' appliances.kitchen.washer',
#   ' sport.bicycle',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.telephone',
#   ' country_yard.lawn_mower',
#   ' computers.components.cpu',
#   ' furniture.living_room.sofa',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.dishwasher',
#   ' construction.tools.saw',
#   ' appliances.kitchen.dishwasher',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' kids.toys',
#   ' accessories.bag',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' kids.fmcg.diapers',
#   ' electronics.video.projector',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' furniture.universal.light'],
#  [' computers.components.cpu',
# ...
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.power_supply',
#   ' computers.peripherals.monitor',
#   ' electronics.calculator',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.microwave',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' computers.notebook',
#   ' kids.bottles',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.scanner',
#   ' stationery.cartrige',
#   ' accessories.bag',
#   ' computers.components.motherboard',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' computers.components.videocards',
#   ' computers.peripherals.scanner',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.scanner',
#   ' furniture.bedroom.pillow',
#   ' appliances.environment.climate',
#   ' electronics.audio.microphone',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.toster',
#   ' construction.tools.light',
#   ' electronics.audio.microphone',
#   ' sport.trainer',
#   ' apparel.costume',
#   ' construction.tools.saw',
#   ' construction.tools.saw',
#   ' construction.tools.saw',
#   ' auto.accessories.compressor',
#   ' furniture.bedroom.bed',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' kids.skates',
#   ' auto.accessories.player',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' stationery.cartrige',
#   ' appliances.kitchen.kettle',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' appliances.environment.air_heater',
#   ' furniture.bedroom.bed',
#   ' appliances.environment.air_heater',
#   ' appliances.environment.air_heater',
#   ' country_yard.cultivator',
#   ' computers.notebook',
#   ' appliances.kitchen.grill',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.calculator',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' electronics.audio.subwoofer',
#   ' electronics.audio.subwoofer',
#   ' electronics.audio.subwoofer',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' furniture.universal.light',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' appliances.steam_cleaner',
#   ' kids.bottles',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' country_yard.cultivator',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' country_yard.lawn_mower',
#   ' kids.bottles',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.peripherals.mouse',
#   ' computers.components.cooler',
#   ' appliances.kitchen.grill',
#   ' electronics.audio.subwoofer',
#   ' computers.peripherals.scanner',
#   ' stationery.stapler',
#   ' computers.components.cooler',
#   ' computers.components.cooler',
#   ' computers.components.cooler',
#   ' electronics.tablet',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill'],
#  [' computers.peripherals.mouse',
#   ' computers.peripherals.printer',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' country_yard.lawn_mower',
#   ' construction.tools.drill'],
#  [' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' accessories.bag',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower'],
#  [' computers.peripherals.mouse',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' kids.bottles',
#   ' kids.bottles'],
#  [' computers.peripherals.mouse',
#   ' furniture.bedroom.pillow',
#   ' furniture.living_room.shelving',
#   ' appliances.environment.climate',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.kitchen.juicer',
#   ' kids.bottles',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.peripherals.mouse',
#   ' appliances.iron',
#   ' appliances.personal.massager',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' appliances.personal.massager',
#   ' appliances.personal.massager',
#   ' furniture.living_room.cabinet',
#   ' appliances.personal.hair_cutter',
#   ' electronics.telephone',
#   ' appliances.kitchen.juicer',
#   ' appliances.ironing_board',
#   ' medicine.tools.tonometer',
#   ' construction.tools.welding',
#   ' computers.peripherals.monitor',
#   ' computers.components.power_supply',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' kids.bottles',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' furniture.bedroom.pillow',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' construction.tools.light',
#   ' computers.components.videocards',
#   ' appliances.environment.climate',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' furniture.bedroom.pillow',
#   ' accessories.bag',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.joystick',
#   ' furniture.bedroom.pillow',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' computers.notebook',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' stationery.cartrige',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.mouse',
#   ' stationery.cartrige',
#   ' computers.components.memory',
#   ' appliances.environment.water_heater',
#   ' appliances.kitchen.juicer',
#   ' computers.peripherals.camera',
#   ' appliances.environment.climate',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.camera',
#   ' appliances.environment.water_heater',
#   ' furniture.bedroom.pillow',
#   ' furniture.bedroom.blanket',
#   ' computers.peripherals.camera',
#   ' electronics.audio.headphone',
#   ' electronics.clocks',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.camera',
#   ' computers.network.router',
#   ' computers.peripherals.camera',
#   ' sport.tennis',
#   ' computers.peripherals.camera',
#   ' country_yard.lawn_mower',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.microwave',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' kids.bottles',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' furniture.universal.light',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_grinder',
#   ' kids.toys',
#   ' apparel.shirt',
#   ' apparel.shoes',
#   ' apparel.shoes',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.cdrw',
#   ' computers.components.power_supply',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' kids.bottles'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.climate',
#   ' appliances.kitchen.blender',
#   ' computers.components.power_supply',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' kids.bottles',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' stationery.cartrige',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' stationery.cartrige',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.printer',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' auto.accessories.anti_freeze',
#   ' appliances.kitchen.blender',
#   ' country_yard.lawn_mower',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.kettle',
#   ' apparel.shoes',
#   ' apparel.shoes',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.iron',
#   ' electronics.tablet',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.videocards',
#   ' auto.accessories.compressor',
#   ' electronics.smartphone',
#   ' appliances.ironing_board',
#   ' electronics.tablet',
#   ' appliances.kitchen.blender',
#   ' auto.accessories.anti_freeze',
#   ' appliances.personal.hair_cutter',
#   ' appliances.personal.hair_cutter',
#   ' auto.accessories.compressor',
#   ' auto.accessories.compressor',
#   ' auto.accessories.player',
#   ' appliances.kitchen.washer',
#   ' auto.accessories.anti_freeze',
#   ' appliances.kitchen.hood',
#   ' auto.accessories.compressor',
#   ' construction.tools.heater',
#   ' construction.tools.drill',
#   ' furniture.living_room.chair',
#   ' auto.accessories.compressor',
#   ' auto.accessories.compressor',
#   ' auto.accessories.compressor',
#   ' appliances.kitchen.dishwasher',
#   ' sport.diving',
#   ' computers.components.motherboard',
#   ' computers.components.motherboard',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' country_yard.lawn_mower',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.fan',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' construction.tools.welding',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' kids.bottles',
#   ' appliances.environment.vacuum',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' furniture.universal.light'],
#  [' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' stationery.cartrige',
#   ' computers.peripherals.mouse',
#   ' electronics.telephone',
#   ' electronics.audio.headphone',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' construction.tools.welding',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' furniture.bedroom.pillow',
#   ' apparel.sock',
#   ' appliances.personal.hair_cutter',
#   ' construction.tools.drill',
#   ' construction.tools.heater',
#   ' construction.tools.welding',
#   ' computers.peripherals.monitor',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' sport.tennis',
#   ' electronics.calculator',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' construction.tools.drill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.diving',
#   ' electronics.smartphone'],
#  [' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' appliances.iron',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.mixer',
#   ' furniture.bedroom.pillow',
#   ' furniture.living_room.shelving',
#   ' computers.notebook',
#   ' medicine.tools.tonometer'],
#  ...]

# %% [markdown]
# Since The Apriori implementation at MLxtend receives a binary databse, we used "TransactionEncoder()" to transform the transactions list in binary database

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(click_transactions).transform(click_transactions)
binary_database2 = pd.DataFrame(trans_array, columns=tr_enc.columns_)
binary_database2
# Out:
#         accessories.bag   accessories.umbrella   apparel.costume  \
# 0                 False                  False             False
# 1                 False                  False             False
# 2                 False                  False             False
# 3                 False                  False             False
# 4                  True                  False             False
# ...                 ...                    ...               ...
# 95858             False                  False             False
# 95859             False                  False             False
# 95860             False                  False             False
# 95861             False                  False             False
# 95862             False                  False             False
#
#         apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0               False           False           False          False
# 1               False           False           False          False
# 2               False           False           False          False
# 3               False           False           False          False
# 4               False           False           False          False
# ...               ...             ...             ...            ...
# 95858           False           False           False          False
# 95859           False           False           False          False
# 95860           False           False           False          False
# 95861           False           False           False          False
# 95862           False           False           False          False
#
#         apparel.trousers   apparel.tshirt  \
# 0                  False            False
# 1                  False            False
# 2                  False            False
# 3                  False             True
# 4                  False             True
# ...                  ...              ...
# 95858              False            False
# 95859              False            False
# 95860              False            False
# 95861              False            False
# 95862              False            False
#
#         appliances.environment.air_conditioner  ...   sport.bicycle  \
# 0                                        False  ...           False
# 1                                         True  ...           False
# 2                                        False  ...           False
# 3                                        False  ...           False
# 4                                        False  ...           False
# ...                                        ...  ...             ...
# 95858                                    False  ...           False
# 95859                                    False  ...           False
# 95860                                    False  ...           False
# 95861                                    False  ...           False
# 95862                                    False  ...           False
#
#         sport.diving   sport.ski   sport.snowboard   sport.tennis  \
# 0              False       False             False          False
# 1              False        True             False           True
# 2              False       False             False          False
# 3              False       False              True          False
# 4              False       False             False           True
# ...              ...         ...               ...            ...
# 95858          False       False             False          False
# 95859          False       False             False          False
# 95860          False       False             False          False
# 95861          False       False             False          False
# 95862          False       False             False          False
#
#         sport.trainer   stationery.battery   stationery.cartrige  \
# 0               False                False                 False
# 1               False                False                  True
# 2               False                False                 False
# 3               False                False                 False
# 4               False                False                 False
# ...               ...                  ...                   ...
# 95858           False                False                 False
# 95859           False                False                 False
# 95860           False                False                 False
# 95861           False                False                 False
# 95862           False                False                 False
#
#         stationery.paper   stationery.stapler
# 0                  False                False
# 1                  False                False
# 2                  False                False
# 3                  False                False
# 4                  False                False
# ...                  ...                  ...
# 95858              False                False
# 95859              False                False
# 95860              False                False
# 95861              False                False
# 95862              False                False
#
# [95863 rows x 123 columns]

# %% [markdown]
# ## 1.2. Compute Frequent Itemsets

# %% [markdown]
# * Compute frequent itemsets considering a minimum support of X%.
# * Present frequent itemsets organized by length (number of items).
# * List frequent 1-itemsets, 2-itemsets, 3-itemsets, etc with support of at least Y%.
# * Change X and Y when it makes sense and discuss the results.

# %% [markdown]
# ### 1.2.1 Store Buys

# %%
frequent_itemsets = apriori(binary_database, min_support=0.1,  use_colnames=True)
frequent_itemsets
# Out:
#     support         itemsets
# 0  0.129602  ( sport.tennis)

# %% [markdown]
# **What are the most bought products?** The most bought product is sport.tennis , appearing approximatly 13% of all transactions.

# %%
frequent_itemsets = apriori(binary_database, min_support=0.01, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0   0.025672                                 ( accessories.bag)       1
# 1   0.030448                      ( appliances.environment.fan)       1
# 2   0.047336                   ( appliances.environment.vacuum)       1
# 3   0.012658             ( appliances.environment.water_heater)       1
# 4   0.024296                                 ( appliances.iron)       1
# 5   0.065977                      ( appliances.kitchen.blender)       1
# 6   0.050015                        ( appliances.kitchen.grill)       1
# 7   0.043822                 ( appliances.kitchen.meat_grinder)       1
# 8   0.017592                    ( appliances.kitchen.microwave)       1
# 9   0.024023                        ( appliances.kitchen.mixer)       1
# 10  0.061741                       ( appliances.kitchen.toster)       1
# 11  0.012793                       ( appliances.kitchen.washer)       1
# 12  0.016245                      ( appliances.personal.scales)       1
# 13  0.055894                        ( appliances.steam_cleaner)       1
# 14  0.011054                        ( computers.components.cpu)       1
# 15  0.023141                        ( computers.components.hdd)       1
# 16  0.083848                     ( computers.components.memory)       1
# 17  0.015120               ( computers.components.power_supply)       1
# 18  0.022500                 ( computers.components.videocards)       1
# 19  0.010090                                ( computers.ebooks)       1
# 20  0.041075                                ( computers.gaming)       1
# 21  0.041458                              ( computers.notebook)       1
# 22  0.010677                    ( computers.peripherals.camera)       1
# 23  0.014555                  ( computers.peripherals.joystick)       1
# 24  0.057407                   ( computers.peripherals.monitor)       1
# 25  0.019470                   ( computers.peripherals.printer)       1
# 26  0.017504                   ( computers.peripherals.scanner)       1
# 27  0.033199                        ( construction.tools.drill)       1
# 28  0.011038                        ( construction.tools.screw)       1
# 29  0.019209                      ( construction.tools.welding)       1
# 30  0.076500                         ( country_yard.lawn_mower)       1
# 31  0.013984                          ( electronics.calculator)       1
# 32  0.031428                              ( electronics.clocks)       1
# 33  0.019994                           ( electronics.telephone)       1
# 34  0.028768                            ( electronics.video.tv)       1
# 35  0.020456                                    ( kids.bottles)       1
# 36  0.054075                        ( medicine.tools.tonometer)       1
# 37  0.129602                                    ( sport.tennis)       1
# 38  0.012665                             ( stationery.cartrige)       1
# 39  0.011000  ( appliances.environment.fan,  computers.compo...       2
# 40  0.011519  ( country_yard.lawn_mower,  appliances.kitchen...       2
# 41  0.010859  ( appliances.kitchen.toster,  computers.compon...       2
# 42  0.012030        ( sport.tennis,  appliances.kitchen.toster)       2
# 43  0.010256  ( country_yard.lawn_mower,  appliances.steam_c...       2
# 44  0.014116      ( sport.tennis,  computers.components.memory)       2
# 45  0.019146          ( country_yard.lawn_mower,  sport.tennis)       2

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.01) & (frequent_itemsets['length'] == 2)]
frequent_itemsets.style.set_properties(subset=['itemsets'], **{'width-min': '50px'})
# Out:
# <style  type="text/css" >
# #T_70416_row0_col1,#T_70416_row1_col1,#T_70416_row2_col1,#T_70416_row3_col1,#T_70416_row4_col1,#T_70416_row5_col1,#T_70416_row6_col1{
#             width-min:  50px;
#         }</style><table id="T_70416_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >support</th>        <th class="col_heading level0 col1" >itemsets</th>        <th class="col_heading level0 col2" >length</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70416_level0_row0" class="row_heading level0 row0" >39</th>
#                         <td id="T_70416_row0_col0" class="data row0 col0" >0.011000</td>
#                         <td id="T_70416_row0_col1" class="data row0 col1" >frozenset({' appliances.environment.fan', ' computers.components.memory'})</td>
#                         <td id="T_70416_row0_col2" class="data row0 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_70416_level0_row1" class="row_heading level0 row1" >40</th>
#                         <td id="T_70416_row1_col0" class="data row1 col0" >0.011519</td>
#                         <td id="T_70416_row1_col1" class="data row1 col1" >frozenset({' country_yard.lawn_mower', ' appliances.kitchen.grill'})</td>
#                         <td id="T_70416_row1_col2" class="data row1 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_70416_level0_row2" class="row_heading level0 row2" >41</th>
#                         <td id="T_70416_row2_col0" class="data row2 col0" >0.010859</td>
#                         <td id="T_70416_row2_col1" class="data row2 col1" >frozenset({' appliances.kitchen.toster', ' computers.components.memory'})</td>
#                         <td id="T_70416_row2_col2" class="data row2 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_70416_level0_row3" class="row_heading level0 row3" >42</th>
#                         <td id="T_70416_row3_col0" class="data row3 col0" >0.012030</td>
#                         <td id="T_70416_row3_col1" class="data row3 col1" >frozenset({' sport.tennis', ' appliances.kitchen.toster'})</td>
#                         <td id="T_70416_row3_col2" class="data row3 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_70416_level0_row4" class="row_heading level0 row4" >43</th>
#                         <td id="T_70416_row4_col0" class="data row4 col0" >0.010256</td>
#                         <td id="T_70416_row4_col1" class="data row4 col1" >frozenset({' country_yard.lawn_mower', ' appliances.steam_cleaner'})</td>
#                         <td id="T_70416_row4_col2" class="data row4 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_70416_level0_row5" class="row_heading level0 row5" >44</th>
#                         <td id="T_70416_row5_col0" class="data row5 col0" >0.014116</td>
#                         <td id="T_70416_row5_col1" class="data row5 col1" >frozenset({' sport.tennis', ' computers.components.memory'})</td>
#                         <td id="T_70416_row5_col2" class="data row5 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_70416_level0_row6" class="row_heading level0 row6" >45</th>
#                         <td id="T_70416_row6_col0" class="data row6 col0" >0.019146</td>
#                         <td id="T_70416_row6_col1" class="data row6 col1" >frozenset({' country_yard.lawn_mower', ' sport.tennis'})</td>
#                         <td id="T_70416_row6_col2" class="data row6 col2" >2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Which products are bought together?**
#
# According to the obtained results, the following products are bought together:
#
# | |  |
# | --- | ---  |
# | appliances.environment.fan | computers.components.memory  |
# | appliances.kitchen.grill | country_yard.lawn_mower  |
# |  appliances.kitchen.toster | computers.components.memory  |
# |  sport.tennis | appliances.kitchen.toster  |
# | appliances.steam_cleaner| country_yard.lawn_mower  |
# | sport.tennis | computers.components.memory  |
# | sport.tennis | country_yard.lawn_mower  |

# %% [markdown]
# ### 1.2.2 Store Clicks

# %%
frequent_itemsets = apriori(binary_database2, min_support=0.2,  use_colnames=True)
frequent_itemsets
# Out:
#     support                     itemsets
# 0  0.216747  ( appliances.steam_cleaner)
# 1  0.219031   ( country_yard.lawn_mower)

# %% [markdown]
# **What are the most clicked products?** The most clicked products are appliances.steam_cleaner and country_yard.lawn_mower , both  appearing approximatly 21% of all transactions.

# %%
frequent_itemsets = apriori(binary_database2, min_support=0.05, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0   0.062819                                 ( accessories.bag)       1
# 1   0.144498                   ( appliances.environment.vacuum)       1
# 2   0.059971                                 ( appliances.iron)       1
# 3   0.050489                      ( appliances.kitchen.blender)       1
# 4   0.186214                        ( appliances.kitchen.grill)       1
# 5   0.052898                 ( appliances.kitchen.meat_grinder)       1
# 6   0.054348                        ( appliances.kitchen.mixer)       1
# 7   0.109865                       ( appliances.kitchen.toster)       1
# 8   0.216747                        ( appliances.steam_cleaner)       1
# 9   0.092580                     ( computers.components.memory)       1
# 10  0.077632                              ( computers.notebook)       1
# 11  0.102000                   ( computers.peripherals.monitor)       1
# 12  0.148034                        ( construction.tools.drill)       1
# 13  0.219031                         ( country_yard.lawn_mower)       1
# 14  0.075733                              ( electronics.clocks)       1
# 15  0.050791                            ( electronics.video.tv)       1
# 16  0.091506                                    ( kids.bottles)       1
# 17  0.104003                        ( medicine.tools.tonometer)       1
# 18  0.134463                                    ( sport.tennis)       1
# 19  0.074899  ( country_yard.lawn_mower,  appliances.kitchen...       2
# 20  0.065385  ( appliances.steam_cleaner,  construction.tool...       2
# 21  0.075107  ( country_yard.lawn_mower,  appliances.steam_c...       2
# 22  0.050510  ( country_yard.lawn_mower,  construction.tools...       2

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.05) & (frequent_itemsets['length'] == 2)]
frequent_itemsets.style.set_properties(subset=['itemsets'], **{'width-min': '50px'})
# Out:
# <style  type="text/css" >
# #T_606cc_row0_col1,#T_606cc_row1_col1,#T_606cc_row2_col1,#T_606cc_row3_col1{
#             width-min:  50px;
#         }</style><table id="T_606cc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >support</th>        <th class="col_heading level0 col1" >itemsets</th>        <th class="col_heading level0 col2" >length</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_606cc_level0_row0" class="row_heading level0 row0" >19</th>
#                         <td id="T_606cc_row0_col0" class="data row0 col0" >0.074899</td>
#                         <td id="T_606cc_row0_col1" class="data row0 col1" >frozenset({' country_yard.lawn_mower', ' appliances.kitchen.grill'})</td>
#                         <td id="T_606cc_row0_col2" class="data row0 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_606cc_level0_row1" class="row_heading level0 row1" >20</th>
#                         <td id="T_606cc_row1_col0" class="data row1 col0" >0.065385</td>
#                         <td id="T_606cc_row1_col1" class="data row1 col1" >frozenset({' appliances.steam_cleaner', ' construction.tools.drill'})</td>
#                         <td id="T_606cc_row1_col2" class="data row1 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_606cc_level0_row2" class="row_heading level0 row2" >21</th>
#                         <td id="T_606cc_row2_col0" class="data row2 col0" >0.075107</td>
#                         <td id="T_606cc_row2_col1" class="data row2 col1" >frozenset({' country_yard.lawn_mower', ' appliances.steam_cleaner'})</td>
#                         <td id="T_606cc_row2_col2" class="data row2 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_606cc_level0_row3" class="row_heading level0 row3" >22</th>
#                         <td id="T_606cc_row3_col0" class="data row3 col0" >0.050510</td>
#                         <td id="T_606cc_row3_col1" class="data row3 col1" >frozenset({' country_yard.lawn_mower', ' construction.tools.drill'})</td>
#                         <td id="T_606cc_row3_col2" class="data row3 col2" >2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Which products are clicked together?**
#
# According to the obtained results, the following products are clicked together:
#
# | |  |
# | --- | ---  |
# | appliances.kitchen.grill | country_yard.lawn_mower  |
# | appliances.steam_cleaner | construction.tools.drill'  |
# |  appliances.steam_cleaner |country_yard.lawn_mower |
# |  construction.tools.dril | ountry_yard.lawn_mower  |

# %% [markdown]
# ### 1.3. Generate Association Rules from Frequent Itemsets

# %% [markdown]
# * Generate association rules with a choosed value (C) for minimum confidence.
# * Generate association rules with a choosed value (L) for minimum lift.
# * Generate association rules with both confidence >= C% and lift >= L.
# * Change C and L when it makes sense and discuss the results.

# %% [markdown]
# ### 1.3.1 Store Buys

# %%
frequent_itemsets = apriori(binary_database, min_support=0.01, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules
# Out:
#                      antecedents                     consequents  \
# 0  ( appliances.environment.fan)  ( computers.components.memory)
# 1    ( appliances.kitchen.grill)      ( country_yard.lawn_mower)
# 2     ( country_yard.lawn_mower)                 ( sport.tennis)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.030448            0.083848  0.011000    0.361283  4.308768
# 1            0.050015            0.076500  0.011519    0.230301  3.010463
# 2            0.076500            0.129602  0.019146    0.250277  1.931120
#
#    leverage  conviction
# 0  0.008447    1.434362
# 1  0.007692    1.199819
# 2  0.009232    1.160959

# %% [markdown]
# * When people buy appliances.environment.fan, computers.components.memory appears in 36% of the transactions.
#
# * When people buy appliances.kitchen.grill, country_yard.lawn_mowe appears in 23% of the transactions.
#
# * When people buy country_yard.lawn_mower, sport.tennis appears in 25% of the transactions.
#
#
# In all the cases above, what confidence represents is that the consequent product has a X% of being purchased when the antecedent product is bought.

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
lift_rules
# Out:
#                        antecedents                     consequents  \
# 0    ( appliances.environment.fan)  ( computers.components.memory)
# 1   ( computers.components.memory)   ( appliances.environment.fan)
# 2       ( country_yard.lawn_mower)     ( appliances.kitchen.grill)
# 3      ( appliances.kitchen.grill)      ( country_yard.lawn_mower)
# 4     ( appliances.kitchen.toster)  ( computers.components.memory)
# 5   ( computers.components.memory)    ( appliances.kitchen.toster)
# 6                  ( sport.tennis)    ( appliances.kitchen.toster)
# 7     ( appliances.kitchen.toster)                 ( sport.tennis)
# 8       ( country_yard.lawn_mower)     ( appliances.steam_cleaner)
# 9      ( appliances.steam_cleaner)      ( country_yard.lawn_mower)
# 10                 ( sport.tennis)  ( computers.components.memory)
# 11  ( computers.components.memory)                 ( sport.tennis)
# 12      ( country_yard.lawn_mower)                 ( sport.tennis)
# 13                 ( sport.tennis)      ( country_yard.lawn_mower)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.030448            0.083848  0.011000    0.361283  4.308768
# 1             0.083848            0.030448  0.011000    0.131194  4.308768
# 2             0.076500            0.050015  0.011519    0.150569  3.010463
# 3             0.050015            0.076500  0.011519    0.230301  3.010463
# 4             0.061741            0.083848  0.010859    0.175881  2.097611
# 5             0.083848            0.061741  0.010859    0.129508  2.097611
# 6             0.129602            0.061741  0.012030    0.092825  1.503470
# 7             0.061741            0.129602  0.012030    0.194853  1.503470
# 8             0.076500            0.055894  0.010256    0.134067  2.398604
# 9             0.055894            0.076500  0.010256    0.183493  2.398604
# 10            0.129602            0.083848  0.014116    0.108914  1.298943
# 11            0.083848            0.129602  0.014116    0.168346  1.298943
# 12            0.076500            0.129602  0.019146    0.250277  1.931120
# 13            0.129602            0.076500  0.019146    0.147731  1.931120
#
#     leverage  conviction
# 0   0.008447    1.434362
# 1   0.008447    1.115959
# 2   0.007692    1.118377
# 3   0.007692    1.199819
# 4   0.005682    1.111674
# 5   0.005682    1.077850
# 6   0.004029    1.034265
# 7   0.004029    1.081042
# 8   0.005980    1.090276
# 9   0.005980    1.131038
# 10  0.003249    1.028130
# 11  0.003249    1.046586
# 12  0.009232    1.160959
# 13  0.009232    1.083578

# %% [markdown]
# Lift is how likely the consequent item is to be purchased when the antecedent item is purchased, while controlling for how popular consequent item is.
#
#
# We chose a lift value greater than 1 since that means that the consequent product is likely to be bought if the antecedent product is bought, while a value less than 1 means that consequent product is unlikely to be bought if the antecedent product is bought. A value equal to one means no association.
#
#
# **Can you find associations highliting that when people buy a product/set of products also buy other product(s)?**
#
#     As we can see in the table above, all the consequent items are likely to be bought if the antecedent is purchased.

# %% [markdown]
# ### 1.3.2 Store Clicks

# %%
frequent_itemsets = apriori(binary_database2, min_support=0.05, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules
# Out:
#                    antecedents                  consequents  \
# 0   ( country_yard.lawn_mower)  ( appliances.kitchen.grill)
# 1  ( appliances.kitchen.grill)   ( country_yard.lawn_mower)
# 2  ( appliances.steam_cleaner)  ( construction.tools.drill)
# 3  ( construction.tools.drill)  ( appliances.steam_cleaner)
# 4   ( country_yard.lawn_mower)  ( appliances.steam_cleaner)
# 5  ( appliances.steam_cleaner)   ( country_yard.lawn_mower)
# 6   ( country_yard.lawn_mower)  ( construction.tools.drill)
# 7  ( construction.tools.drill)   ( country_yard.lawn_mower)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.219031            0.186214  0.074899    0.341954  1.836351
# 1            0.186214            0.219031  0.074899    0.402218  1.836351
# 2            0.216747            0.148034  0.065385    0.301665  2.037808
# 3            0.148034            0.216747  0.065385    0.441688  2.037808
# 4            0.219031            0.216747  0.075107    0.342906  1.582058
# 5            0.216747            0.219031  0.075107    0.346520  1.582058
# 6            0.219031            0.148034  0.050510    0.230604  1.557778
# 7            0.148034            0.219031  0.050510    0.341202  1.557778
#
#    leverage  conviction
# 0  0.034112    1.236670
# 1  0.034112    1.306445
# 2  0.033299    1.219996
# 3  0.033299    1.402896
# 4  0.027633    1.191996
# 5  0.027633    1.195093
# 6  0.018085    1.107318
# 7  0.018085    1.185445

# %% [markdown]
# **Can you find associations between the clicked products?**
#
#     In all the cases above, what confidence represents is that the consequent product has a X% of being purchased when the antecedent product is bought.
#     In this case we can see that, for exemple 44% of the times that people clicks drills also click on cleaner(row 3)

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
lift_rules
# Out:
#                    antecedents                  consequents  \
# 0   ( country_yard.lawn_mower)  ( appliances.kitchen.grill)
# 1  ( appliances.kitchen.grill)   ( country_yard.lawn_mower)
# 2  ( appliances.steam_cleaner)  ( construction.tools.drill)
# 3  ( construction.tools.drill)  ( appliances.steam_cleaner)
# 4   ( country_yard.lawn_mower)  ( appliances.steam_cleaner)
# 5  ( appliances.steam_cleaner)   ( country_yard.lawn_mower)
# 6   ( country_yard.lawn_mower)  ( construction.tools.drill)
# 7  ( construction.tools.drill)   ( country_yard.lawn_mower)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.219031            0.186214  0.074899    0.341954  1.836351
# 1            0.186214            0.219031  0.074899    0.402218  1.836351
# 2            0.216747            0.148034  0.065385    0.301665  2.037808
# 3            0.148034            0.216747  0.065385    0.441688  2.037808
# 4            0.219031            0.216747  0.075107    0.342906  1.582058
# 5            0.216747            0.219031  0.075107    0.346520  1.582058
# 6            0.219031            0.148034  0.050510    0.230604  1.557778
# 7            0.148034            0.219031  0.050510    0.341202  1.557778
#
#    leverage  conviction
# 0  0.034112    1.236670
# 1  0.034112    1.306445
# 2  0.033299    1.219996
# 3  0.033299    1.402896
# 4  0.027633    1.191996
# 5  0.027633    1.195093
# 6  0.018085    1.107318
# 7  0.018085    1.185445

# %% [markdown]
# **Can you find associations highliting that when people click in a product/set of products also buy this product(s)?**
# In this case, due to the preprocessing that we gave to the data, all the results that are shown above reveal associations of people clicking in a product/set of products and also buying that/those product(s).

# %% [markdown]
# ### 1.4. Take a Look at Maximal Patterns: Compute Maximal Frequent Itemsets

# %%
FI_fpmax=fpmax(binary_database, min_support=0.1, use_colnames=True)
FI_fpmax
# Out:
#     support         itemsets
# 0  0.129602  ( sport.tennis)

# %% [markdown]
# ### 1.5. Conclusions

# %% [markdown]
# **What are the most interesting products?**
# **Can you find relevant associated categories?**

# %% [markdown]
# * From the transactions from store buys we can see that **the most bought** item is
# **sport.tennis** appering in 12% of all transactions.
#
#
# * The items that are bought together are with sport.tennis:
#  * **appliances.kitchen.toster,computers.components.memory,country_yard.lawn_mower**  each pair appering together in 1% of the transactions.
#
#
#
# * When people buy **country_yard.lawn_mower, sport.tennis** appears in 25% of the transactions.
#
#
# * The items bought with the bigest lift is:
#  * **appliances.environment.fan computers.components.memory** lift 4.308768
#
#
# * As for the sports tenis(that appears the most in all transactions )
# what we saw was that:
#  * sport.tennis	appliances.kitchen.toster lift:1.503470
#  * sport.tennis  computers.components.memory lift: 1.29894
#  * sport.tennis country_yard.lawn_mower lift: 1.931120
#
# Like said before with a lift > 1  that means that the consequent product is likely to be bought if the antecedent product is bought

# %% [markdown]
# As for the store clicks:
#
# * The most clicked items are:
#  * appliances.steam_cleaner
#  * country_yard.lawn_mower
#
# These two items are clicks in 20% of all sessions but has we saw before that doesn't mean that they are the most bought items
#
# * spots.tennis is the most bought item but we saw that is only clicked 13% in all sessions.
#
#
# * Comparing if in the same session two items are clicked together vs bogth together, we saw that:
#  * appliances.kitchen.grill	and country_yard.lawn_mower are in the same transaction 1% of the times, but are clicked together in a higher percentage 7%
#  * the same for appliances.steam_cleaner and country_yard.lawn_mower are in the same transaction 1% of the times, but are clicked together in a higher percentage 7%
#
#
# * When people click in appliances.kitchen.grill, country_yard.lawn_mower appears in 40% of the transactions. Which is high.
#
# * They also have a lift bigger than 1 that means that the country_yard.lawn_mower product is likely to be bought if the appliances.kitchen.grill product is bought.

# %% [markdown]
# # 2. Week vs Weekend Purchases

# %% [markdown]
# In this part of the project you should analyse the consumption patterns during the week vs during the weekeed.
#
# **In what follows keep the following question in mind and be creative!**
#
# 1. The most interesting products are the same during the week and the weekend?
# 2. What are the most bought products during the week? And during the weekend?
# 3. There are differences between the sets of products bought during the week and the weekend?
# 4. Can you find different associations highliting that when people click in a product/set of products also buy this product(s) during the week vs the weekend?
# 5. Discuss the results obtained for the week sessions vs weekend sessions.

# %% [markdown]
# ### 2.1. Load and Preprocess Data
#
#  **Product quantities should not be considered.**

# %% [markdown]
# ### 2.1.1Store Buys df
#
# We have to separate this df into 2 different df one with week days and the other with weekend days, to do that we had to handle the Timestamp collum

# %%
masterdf.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories                 Timestamp
# 0     2859734  214536500   electronics.tablet  2014-05-14T12:06:02.717Z
# 1     4276371  214536500   electronics.tablet  2014-06-04T13:44:10.725Z
# 2     4440056  214536500   electronics.tablet  2014-06-14T19:14:00.581Z
# 3       70532  214536506   electronics.tablet  2014-04-06T09:59:03.143Z
# 4      691119  214536506   electronics.tablet  2014-04-14T15:56:30.514Z

# %%
weeksdf = masterdf
time = weeksdf["Timestamp"].str.split("T", n = 1, expand = True)
weeksdf["Timestamp"] = time[0]
weeksdf.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories   Timestamp
# 0     2859734  214536500   electronics.tablet  2014-05-14
# 1     4276371  214536500   electronics.tablet  2014-06-04
# 2     4440056  214536500   electronics.tablet  2014-06-14
# 3       70532  214536506   electronics.tablet  2014-04-06
# 4      691119  214536506   electronics.tablet  2014-04-14

# %%
teste = weeksdf
teste["Timestamp"] = pd.to_datetime(teste['Timestamp'])
teste['Semana'] = teste['Timestamp'].dt.day_name()

buys_weeknd_df =  teste.loc[teste['Semana'].isin(['Saturday', 'Sunday'])] 
buys_weekday_df = teste.loc[~teste['Semana'].isin(['Saturday', 'Sunday'])]

# %% [markdown]
# ## Weekend

# %%
buys_weeknd_df
# Out:
#         Session_ID    Item_ID          Product_Categories  Timestamp    Semana
# 2          4440056  214536500          electronics.tablet 2014-06-14  Saturday
# 3            70532  214536506          electronics.tablet 2014-04-06    Sunday
# 5           405567  214662742     furniture.kitchen.table 2014-04-06    Sunday
# 6           763567  214662742     furniture.kitchen.table 2014-04-13    Sunday
# 7           842649  214662742     furniture.kitchen.table 2014-04-13    Sunday
# ...            ...        ...                         ...        ...       ...
# 679464     6724562  214789372                sport.tennis 2014-07-27    Sunday
# 679467     6940131  214816352    appliances.ironing_board 2014-07-27    Sunday
# 679475     6797042  214854759      electronics.calculator 2014-07-27    Sunday
# 679476     6711771  214851605   furniture.universal.light 2014-07-27    Sunday
# 679482     6829368  214851182   furniture.universal.light 2014-07-26  Saturday
#
# [267909 rows x 5 columns]

# %%
buy_weeknd_transactions= []

for i in list(buys_weeknd_df.Session_ID.unique()):
    buy_weeknd_transactions.append(buys_weeknd_df[buys_weeknd_df.Session_ID==i].Product_Categories.values.tolist())
    
buy_weeknd_transactions
# Out:
# [[' electronics.tablet', ' sport.tennis'],
#  [' electronics.tablet'],
#  [' furniture.kitchen.table', ' computers.components.memory'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv'],
#  [' electronics.smartphone', ' computers.components.memory'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.iron',
#   ' appliances.environment.water_heater',
#   ' construction.tools.heater'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' computers.peripherals.scanner'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators', ' medicine.tools.tonometer'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.motherboard'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [' electronics.video.tv',
#   ' furniture.living_room.cabinet',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.hood',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' country_yard.cultivator',
#   ' apparel.trousers'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' furniture.living_room.shelving',
#   ' appliances.kitchen.blender'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' auto.accessories.player'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' accessories.bag', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.steam_cooker'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.microwave'],
#  [' electronics.video.tv', ' furniture.living_room.shelving'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.kitchen.table',
#   ' computers.components.videocards'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.bedroom.blanket',
#   ' furniture.bedroom.blanket',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.mouse'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.toster'],
#  [' computers.components.cpu', ' medicine.tools.tonometer'],
#  [' computers.components.cpu', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' electronics.tablet',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.dishwasher',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' kids.toys'],
#  [' computers.components.cpu'],
#  [' computers.notebook', ' sport.ski'],
#  [' computers.notebook',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' apparel.trousers'],
#  [' computers.notebook',
#   ' auto.accessories.videoregister',
#   ' furniture.living_room.shelving',
#   ' electronics.video.projector',
#   ' apparel.trousers'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' construction.tools.screw'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.components.memory', ' sport.tennis'],
#  [' computers.notebook', ' apparel.shirt'],
#  [' computers.notebook'],
#  [' computers.notebook', ' electronics.video.tv'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook', ' computers.components.cooler'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.monitor',
#   ' appliances.iron',
#   ' appliances.kitchen.kettle'],
#  [' computers.peripherals.monitor', ' stationery.cartrige'],
#  [' computers.peripherals.monitor', ' stationery.battery'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' electronics.video.tv'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' appliances.kitchen.kettle'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' furniture.bedroom.pillow'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.ironing_board',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' appliances.iron'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' sport.tennis',
#   ' appliances.environment.climate'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.video.tv',
#   ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' furniture.bedroom.pillow',
#   ' construction.tools.screw'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' auto.accessories.videoregister'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' apparel.trousers'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' appliances.iron',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.air_conditioner',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.screw',
#   ' appliances.environment.fan',
#   ' construction.tools.screw',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' electronics.clocks',
#   ' computers.components.hdd'],
#  [' computers.components.memory', ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.ebooks',
#   ' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.printer'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.air_conditioner',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' electronics.calculator'],
#  [' computers.components.memory', ' auto.accessories.compressor'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.telephone',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.peripherals.camera',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' apparel.sock',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.dishwasher'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' computers.desktop'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.ebooks',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' stationery.cartrige'],
#  [' computers.components.memory',
#   ' auto.accessories.player',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' stationery.battery'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.headphone',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' computers.components.memory',
#   ' furniture.universal.light',
#   ' appliances.environment.fan',
#   ' computers.notebook',
#   ' construction.tools.drill',
#   ' construction.tools.welding',
#   ' computers.components.memory',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' apparel.tshirt',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.peripherals.mouse',
#   ' computers.components.cpu'],
#  [' computers.components.memory',
#   ' computers.peripherals.keyboard',
#   ' sport.tennis'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' auto.accessories.videoregister',
#   ' computers.components.cpu',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' construction.tools.heater',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' appliances.kitchen.fryer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' furniture.kitchen.chair',
#   ' computers.components.cpu',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' electronics.video.tv',
#   ' appliances.kitchen.juicer',
#   ' electronics.telephone',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' computers.peripherals.scanner',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.components.motherboard',
#   ' computers.peripherals.keyboard',
#   ' apparel.shoes',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.power_supply',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' furniture.living_room.chair',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' appliances.personal.scales',
#   ' construction.tools.generator'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' electronics.telephone',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' stationery.paper',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory', ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.notebook',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory', ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' country_yard.weather_station',
#   ' appliances.kitchen.microwave',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.heater'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.power_supply'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.peripherals.camera',
#   ' appliances.kitchen.blender',
#   ' accessories.bag',
#   ' computers.peripherals.camera',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.camera',
#   ' computers.gaming',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' stationery.cartrige', ' computers.gaming'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' stationery.cartrige'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' electronics.telephone',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' appliances.personal.hair_cutter',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.ebooks',
#   ' appliances.kitchen.washer',
#   ' furniture.bedroom.pillow',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' auto.accessories.player',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' furniture.kitchen.chair',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.fan',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' auto.accessories.videoregister',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.peripherals.printer',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' furniture.universal.light',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' auto.accessories.videoregister',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' auto.accessories.player',
#   ' electronics.clocks',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' computers.notebook'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' stationery.cartrige'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.environment.fan',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.printer'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.microwave'],
#  [' computers.components.memory',
#   ' country_yard.weather_station',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' country_yard.watering', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' medicine.tools.tonometer',
#   ' computers.notebook'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' country_yard.weather_station',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.climate',
#   ' apparel.shoes',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.sound_card',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' auto.accessories.radar',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.notebook',
#   ' computers.peripherals.printer',
#   ' sport.tennis'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' electronics.calculator'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.smartphone',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' medicine.tools.tonometer',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' electronics.clocks'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' computers.notebook'],
#  [' computers.components.memory', ' appliances.kitchen.washer'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' construction.tools.welding',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.fan',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' furniture.bedroom.pillow'],
#  [' computers.components.memory', ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' apparel.tshirt',
#   ' appliances.kitchen.hood',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.notebook'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' electronics.video.tv'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' furniture.bedroom.pillow'],
#  [' computers.components.memory', ' sport.tennis', ' appliances.iron'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.hdd',
#   ' computers.components.memory',
#   ' auto.accessories.compressor',
#   ' apparel.glove',
#   ' apparel.glove',
#   ' stationery.battery'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.living_room.shelving'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' country_yard.watering'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' country_yard.cultivator'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.air_conditioner',
#   ' appliances.environment.air_conditioner'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' country_yard.weather_station'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.iron'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.screw',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.hdd'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
# ...
#   ' furniture.bedroom.blanket'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' electronics.telephone',
#   ' electronics.telephone'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' construction.tools.welding',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.camera.photo',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' electronics.audio.subwoofer',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' furniture.kitchen.chair'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.audio.subwoofer',
#   ' electronics.audio.subwoofer',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' electronics.video.tv',
#   ' appliances.kitchen.coffee_machine',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' appliances.iron',
#   ' computers.peripherals.joystick',
#   ' computers.components.videocards',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' furniture.kitchen.table',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.bedroom.pillow',
#   ' electronics.telephone'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.components.memory',
#   ' furniture.kitchen.table',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.power_supply',
#   ' accessories.bag',
#   ' furniture.living_room.cabinet'],
#  [' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' stationery.battery',
#   ' kids.toys'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' accessories.bag',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender',
#   ' sport.bicycle'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' medicine.tools.tonometer',
#   ' electronics.telephone',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.videocards',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.audio.headphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.iron',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' computers.peripherals.camera',
#   ' furniture.bedroom.pillow',
#   ' construction.tools.welding',
#   ' computers.components.hdd',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' sport.tennis',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' electronics.telephone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' furniture.bedroom.pillow'],
#  [' computers.components.memory',
#   ' construction.tools.screw',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.microwave'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.components.memory',
#   ' electronics.video.tv',
#   ' furniture.bedroom.blanket',
#   ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.videocards',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.coffee_grinder',
#   ' appliances.kitchen.blender',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer'],
#  ...]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(buy_weeknd_transactions).transform(buy_weeknd_transactions)
buy_weeknd_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
buy_weeknd_binary_db
# Out:
#          accessories.bag   accessories.umbrella   apparel.costume  \
# 0                  False                  False             False
# 1                  False                  False             False
# 2                  False                  False             False
# 3                  False                  False             False
# 4                  False                  False             False
# ...                  ...                    ...               ...
# 116437             False                  False             False
# 116438             False                  False             False
# 116439             False                  False             False
# 116440             False                  False             False
# 116441             False                  False             False
#
#          apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0                False           False           False          False
# 1                False           False           False          False
# 2                False           False           False          False
# 3                False           False           False          False
# 4                False           False           False          False
# ...                ...             ...             ...            ...
# 116437           False           False           False          False
# 116438           False           False           False          False
# 116439           False           False           False          False
# 116440           False           False           False          False
# 116441           False           False           False          False
#
#          apparel.trousers   apparel.tshirt  \
# 0                   False            False
# 1                   False            False
# 2                   False            False
# 3                   False            False
# 4                   False            False
# ...                   ...              ...
# 116437              False            False
# 116438              False            False
# 116439              False            False
# 116440              False            False
# 116441              False            False
#
#          appliances.environment.air_conditioner  ...   sport.bicycle  \
# 0                                         False  ...           False
# 1                                         False  ...           False
# 2                                         False  ...           False
# 3                                         False  ...           False
# 4                                         False  ...           False
# ...                                         ...  ...             ...
# 116437                                    False  ...           False
# 116438                                    False  ...           False
# 116439                                    False  ...           False
# 116440                                    False  ...           False
# 116441                                    False  ...           False
#
#          sport.diving   sport.ski   sport.snowboard   sport.tennis  \
# 0               False       False             False           True
# 1               False       False             False          False
# 2               False       False             False          False
# 3               False       False             False          False
# 4               False       False             False          False
# ...               ...         ...               ...            ...
# 116437          False       False             False          False
# 116438          False       False             False          False
# 116439          False       False             False          False
# 116440          False       False             False          False
# 116441          False       False             False          False
#
#          sport.trainer   stationery.battery   stationery.cartrige  \
# 0                False                False                 False
# 1                False                False                 False
# 2                False                False                 False
# 3                False                False                 False
# 4                False                False                 False
# ...                ...                  ...                   ...
# 116437           False                False                 False
# 116438           False                False                 False
# 116439           False                False                 False
# 116440           False                False                 False
# 116441           False                False                 False
#
#          stationery.paper   stationery.stapler
# 0                   False                False
# 1                   False                False
# 2                   False                False
# 3                   False                False
# 4                   False                False
# ...                   ...                  ...
# 116437              False                False
# 116438              False                False
# 116439              False                False
# 116440              False                False
# 116441              False                False
#
# [116442 rows x 123 columns]

# %% [markdown]
# ## WeekDay

# %%
buys_weekday_df
# Out:
#         Session_ID    Item_ID          Product_Categories  Timestamp  \
# 0          2859734  214536500          electronics.tablet 2014-05-14
# 1          4276371  214536500          electronics.tablet 2014-06-04
# 4           691119  214536506          electronics.tablet 2014-04-14
# 8           573948  214662742     furniture.kitchen.table 2014-04-10
# 9           877203  214662742     furniture.kitchen.table 2014-04-14
# ...            ...        ...                         ...        ...
# 679483     6649378  214851182   furniture.universal.light 2014-07-28
# 679484     6649378  214851182   furniture.universal.light 2014-07-28
# 679485     7001599  214571152            stationery.paper 2014-07-24
# 679486     6961172  214571152            stationery.paper 2014-07-28
# 679487     6873084  214847137                sport.tennis 2014-07-23
#
#            Semana
# 0       Wednesday
# 1       Wednesday
# 4          Monday
# 8        Thursday
# 9          Monday
# ...           ...
# 679483     Monday
# 679484     Monday
# 679485   Thursday
# 679486     Monday
# 679487  Wednesday
#
# [411579 rows x 5 columns]

# %%
buy_weekday_transactions= []

for i in list(buys_weekday_df.Session_ID.unique()):
    buy_weekday_transactions.append(buys_weekday_df[buys_weekday_df.Session_ID==i].Product_Categories.values.tolist())
    
buy_weekday_transactions
# Out:
# [[' electronics.tablet'],
#  [' electronics.tablet', ' computers.peripherals.monitor'],
#  [' electronics.tablet',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' furniture.living_room.cabinet'],
#  [' furniture.kitchen.table', ' electronics.audio.dictaphone'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table', ' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table',
#   ' computers.components.videocards',
#   ' furniture.kitchen.table',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' computers.notebook'],
#  [' appliances.kitchen.refrigerators', ' appliances.sewing_machine'],
#  [' appliances.kitchen.refrigerators', ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators',
#   ' construction.tools.screw',
#   ' furniture.kitchen.table',
#   ' stationery.stapler',
#   ' appliances.kitchen.coffee_machine',
#   ' apparel.trousers',
#   ' construction.tools.heater',
#   ' construction.tools.saw',
#   ' construction.tools.heater',
#   ' computers.components.cpu',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.hdd',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' construction.tools.heater'],
#  [' appliances.kitchen.refrigerators', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.peripherals.camera',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.camera'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.environment.air_heater'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.components.memory'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' stationery.cartrige'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.peripherals.mouse'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' accessories.bag'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.mixer', ' electronics.tablet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.components.memory'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.telephone'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' computers.desktop',
#   ' computers.peripherals.mouse',
#   ' construction.tools.saw'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.clocks', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' furniture.living_room.cabinet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' auto.accessories.videoregister'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.cartrige',
#   ' computers.components.cpu'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.paper',
#   ' sport.tennis',
#   ' appliances.environment.fan'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' apparel.costume',
#   ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' apparel.shoes', ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' electronics.telephone',
#   ' appliances.iron'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' sport.bicycle',
#   ' construction.tools.generator'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.printer'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.notebook',
#   ' apparel.sock',
#   ' furniture.living_room.sofa'],
#  [' computers.components.cpu',
#   ' appliances.environment.water_heater',
#   ' computers.peripherals.scanner'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.kitchen.microwave'],
#  [' computers.components.cpu', ' computers.peripherals.monitor'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' construction.tools.welding',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' computers.notebook', ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.power_supply'],
#  [' computers.components.cpu',
#   ' appliances.environment.climate',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.peripherals.camera',
#   ' electronics.tablet',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.steam_cleaner'],
#  [' computers.components.cpu', ' appliances.kitchen.toster', ' sport.tennis'],
#  [' computers.components.cpu', ' accessories.bag', ' sport.tennis'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' furniture.bedroom.blanket'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' apparel.trousers',
#   ' apparel.trousers',
#   ' country_yard.watering',
#   ' country_yard.watering'],
#  [' computers.notebook',
#   ' electronics.audio.microphone',
#   ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' accessories.bag',
#   ' sport.bicycle',
#   ' accessories.bag'],
#  [' computers.notebook',
#   ' computers.peripherals.printer',
#   ' computers.components.motherboard',
#   ' electronics.telephone'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.peripherals.camera'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook', ' appliances.environment.fan'],
#  [' computers.notebook', ' appliances.environment.water_heater'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.telephone',
#   ' computers.components.memory',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' apparel.costume'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.hdd',
#   ' computers.peripherals.printer'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' apparel.tshirt', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook', ' apparel.shirt'],
#  [' computers.notebook', ' electronics.camera.video'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.gaming',
#   ' apparel.sock',
#   ' electronics.clocks'],
#  [' computers.notebook', ' computers.peripherals.scanner', ' apparel.costume'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.notebook',
#   ' furniture.living_room.chair',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.headphone',
#   ' apparel.glove',
#   ' construction.tools.heater',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' appliances.kitchen.toster'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.printer'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' accessories.bag'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' appliances.kitchen.kettle',
#   ' electronics.camera.photo',
#   ' computers.peripherals.mouse',
#   ' sport.ski',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' stationery.cartrige',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' stationery.battery'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.watering',
#   ' appliances.environment.vacuum',
#   ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.tablet'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.ebooks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.videocards',
#   ' accessories.bag'],
#  [' computers.components.memory', ' furniture.kitchen.table'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' appliances.environment.climate',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' electronics.camera.video',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' appliances.environment.climate'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.ebooks',
#   ' accessories.umbrella'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_grinder',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.camera.photo'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory', ' appliances.kitchen.mixer'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' appliances.environment.climate'],
#  [' computers.components.memory', ' accessories.umbrella'],
#  [' computers.components.memory', ' electronics.audio.headphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards'],
#  [' computers.components.memory', ' appliances.iron', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory', ' computers.components.videocards'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.ebooks',
#   ' computers.ebooks'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' construction.tools.welding',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.juicer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' construction.tools.screw',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.microwave',
#   ' auto.accessories.alarm'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.welding',
#   ' computers.components.memory',
#   ' construction.tools.generator',
#   ' apparel.trousers',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.ebooks',
#   ' appliances.kitchen.blender',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' electronics.audio.subwoofer',
#   ' auto.accessories.radar'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.telephone'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' construction.tools.heater'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' apparel.tshirt',
#   ' sport.tennis'],
#  [' computers.components.memory', ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.cultivator'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.scanner',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.network.router'],
#  [' computers.components.memory', ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.stapler',
#   ' computers.network.router',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.telephone',
#   ' sport.tennis',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.universal.light'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' auto.accessories.player',
#   ' construction.tools.welding'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory', ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' stationery.cartrige',
#   ' electronics.telephone',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' sport.tennis'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.ebooks'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.ebooks',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' furniture.living_room.sofa',
#   ' sport.tennis'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.cpu'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' electronics.audio.headphone',
#   ' appliances.environment.climate',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' sport.tennis',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.peripherals.mouse',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' construction.tools.screw',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' appliances.iron',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' computers.desktop',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' apparel.shirt',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' furniture.living_room.cabinet',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' appliances.environment.fan'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.cpu',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.bedroom.bed',
#   ' appliances.personal.hair_cutter',
#   ' computers.components.memory',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.microwave',
#   ' medicine.tools.tonometer',
#   ' computers.notebook'],
#  [' computers.components.memory', ' computers.notebook'],
#  [' computers.components.memory', ' computers.ebooks'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.cpu',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' apparel.shoes',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' apparel.trousers',
#   ' country_yard.lawn_mower',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.peripherals.monitor',
#   ' electronics.audio.subwoofer',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' kids.toys',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.audio.subwoofer',
#   ' sport.bicycle',
#   ' appliances.kitchen.coffee_machine',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.subwoofer',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.video.tv',
#   ' furniture.kitchen.table',
#   ' appliances.personal.hair_cutter',
#   ' country_yard.weather_station',
#   ' appliances.environment.fan',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' computers.components.cdrw',
#   ' computers.components.cdrw',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' accessories.bag'],
#  [' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.mouse'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' sport.tennis', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' auto.accessories.player',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.videocards',
#   ' appliances.kitchen.microwave',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' sport.diving',
#   ' furniture.living_room.shelving',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.juicer',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.fan',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory', ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.mixer',
#   ' electronics.audio.subwoofer',
#   ' electronics.audio.subwoofer',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' appliances.environment.fan',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' electronics.video.tv',
#   ' appliances.kitchen.microwave',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' electronics.calculator',
#   ' apparel.glove',
#   ' stationery.battery',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.personal.hair_cutter',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' computers.notebook',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer',
#   ' sport.tennis'],
#  [' computers.components.memory', ' furniture.kitchen.chair'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.iron',
#   ' furniture.living_room.chair',
#   ' appliances.iron',
#   ' auto.accessories.compressor',
#   ' computers.components.memory',
#   ' computers.components.cpu',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' electronics.audio.dictaphone',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.saw',
#   ' electronics.telephone',
#   ' country_yard.cultivator',
#   ' appliances.kitchen.grill',
#   ' sport.tennis',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' construction.tools.welding',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.components.videocards',
#   ' electronics.audio.subwoofer',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.kitchen.chair',
#   ' furniture.kitchen.chair',
#   ' construction.tools.heater',
#   ' construction.tools.heater',
# ...
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' auto.accessories.player'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' appliances.iron'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards'],
#  [' computers.components.memory', ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' medicine.tools.tonometer',
#   ' construction.tools.screw'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' apparel.trousers',
#   ' apparel.trousers'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' appliances.kitchen.coffee_grinder',
#   ' computers.components.power_supply'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.personal.scales',
#   ' computers.components.sound_card'],
#  [' computers.components.memory', ' furniture.living_room.chair'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv',
#   ' computers.components.memory',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.videocards'],
#  [' computers.components.memory',
#   ' computers.components.cdrw',
#   ' computers.components.motherboard'],
#  [' computers.components.memory',
#   ' electronics.video.tv',
#   ' computers.components.memory',
#   ' electronics.video.tv',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.welding',
#   ' computers.ebooks',
#   ' apparel.shoes',
#   ' computers.components.videocards'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' apparel.costume',
#   ' computers.components.videocards'],
#  [' computers.components.memory', ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' country_yard.weather_station'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.screw'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.smartphone',
#   ' electronics.smartphone',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' appliances.personal.scales'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.camera',
#   ' electronics.audio.acoustic'],
#  [' computers.components.memory',
#   ' computers.peripherals.printer',
#   ' computers.components.cpu'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' computers.components.power_supply'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' appliances.iron'],
#  [' computers.components.memory', ' furniture.living_room.chair'],
#  [' computers.components.memory', ' electronics.telephone'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' accessories.umbrella',
#   ' appliances.kitchen.dishwasher'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' electronics.calculator',
#   ' computers.components.cdrw',
#   ' electronics.calculator',
#   ' kids.toys',
#   ' construction.tools.heater'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' electronics.audio.subwoofer'],
#  [' computers.components.memory', ' furniture.living_room.chair'],
#  [' computers.components.memory', ' furniture.living_room.chair'],
#  [' computers.components.memory',
#   ' apparel.tshirt',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' kids.dolls',
#   ' kids.dolls'],
#  [' computers.components.memory', ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' apparel.trousers'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' electronics.video.tv'],
#  [' computers.components.memory', ' sport.tennis', ' accessories.bag'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.mixer'],
#  [' computers.components.memory', ' computers.peripherals.scanner'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.calculator'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_grinder',
#   ' appliances.iron',
#   ' computers.notebook',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.power_supply'],
#  [' computers.components.memory', ' country_yard.weather_station'],
#  [' computers.components.memory', ' computers.peripherals.printer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' accessories.bag'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.peripherals.printer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.cdrw',
#   ' construction.tools.screw'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' kids.carriage',
#   ' kids.carriage',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.printer',
#   ' computers.components.videocards',
#   ' computers.components.videocards'],
#  [' computers.components.memory', ' accessories.bag'],
#  [' computers.components.memory', ' appliances.kitchen.refrigerators'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.peripherals.printer'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.gaming',
#   ' computers.peripherals.printer'],
#  [' computers.components.memory', ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory', ' computers.components.cdrw'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.power_supply'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_machine',
#   ' computers.components.videocards',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' furniture.living_room.sofa'],
#  [' computers.components.memory', ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.microwave',
#   ' computers.components.memory',
#   ' construction.tools.screw',
#   ' construction.tools.screw',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_machine',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.desktop'],
#  [' computers.components.memory',
#   ' computers.network.router',
#   ' computers.components.memory',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' furniture.bathroom.toilet'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.dishwasher',
#   ' furniture.universal.light',
#   ' country_yard.cultivator',
#   ' accessories.bag'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_machine',
#   ' country_yard.cultivator'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' accessories.bag'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' apparel.shoes'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_machine',
#   ' electronics.calculator',
#   ' electronics.calculator'],
#  [' computers.components.memory', ' electronics.telephone'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.dishwasher',
#   ' electronics.calculator',
#   ' country_yard.weather_station'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' appliances.environment.fan',
#   ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.washer',
#   ' appliances.iron',
#   ' accessories.bag',
#   ' construction.tools.welding'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' computers.components.hdd',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' furniture.bedroom.blanket',
#   ' furniture.bedroom.blanket',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' appliances.iron'],
#  [' computers.components.memory', ' computers.components.power_supply'],
#  [' computers.components.memory',
#   ' electronics.video.tv',
#   ' country_yard.lawn_mower',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' furniture.living_room.chair',
#   ' country_yard.cultivator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' computers.peripherals.scanner'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory', ' sport.tennis', ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' sport.tennis', ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' accessories.bag'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' construction.tools.screw',
#   ' computers.peripherals.printer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.calculator',
#   ' computers.peripherals.printer'],
#  ...]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(buy_weekday_transactions).transform(buy_weekday_transactions)
buy_weekday_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
buy_weekday_binary_db
# Out:
#          accessories.bag   accessories.umbrella   apparel.costume  \
# 0                  False                  False             False
# 1                  False                  False             False
# 2                  False                  False             False
# 3                  False                  False             False
# 4                  False                  False             False
# ...                  ...                    ...               ...
# 201997             False                  False             False
# 201998             False                  False             False
# 201999             False                  False             False
# 202000             False                  False             False
# 202001             False                  False             False
#
#          apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0                False           False           False          False
# 1                False           False           False          False
# 2                False           False           False          False
# 3                False           False           False          False
# 4                False           False           False          False
# ...                ...             ...             ...            ...
# 201997           False           False           False          False
# 201998           False           False           False          False
# 201999           False           False           False          False
# 202000           False           False           False          False
# 202001           False           False           False          False
#
#          apparel.trousers   apparel.tshirt  \
# 0                   False            False
# 1                   False            False
# 2                   False            False
# 3                   False            False
# 4                   False            False
# ...                   ...              ...
# 201997              False            False
# 201998              False            False
# 201999              False            False
# 202000              False            False
# 202001              False            False
#
#          appliances.environment.air_conditioner  ...   sport.bicycle  \
# 0                                         False  ...           False
# 1                                         False  ...           False
# 2                                         False  ...           False
# 3                                         False  ...           False
# 4                                         False  ...           False
# ...                                         ...  ...             ...
# 201997                                    False  ...           False
# 201998                                    False  ...           False
# 201999                                    False  ...           False
# 202000                                    False  ...           False
# 202001                                    False  ...           False
#
#          sport.diving   sport.ski   sport.snowboard   sport.tennis  \
# 0               False       False             False          False
# 1               False       False             False          False
# 2               False       False             False          False
# 3               False       False             False          False
# 4               False       False             False          False
# ...               ...         ...               ...            ...
# 201997          False       False             False          False
# 201998          False       False             False          False
# 201999          False       False             False          False
# 202000          False       False             False          False
# 202001          False       False             False          False
#
#          sport.trainer   stationery.battery   stationery.cartrige  \
# 0                False                False                 False
# 1                False                False                 False
# 2                False                False                 False
# 3                False                False                 False
# 4                False                False                 False
# ...                ...                  ...                   ...
# 201997           False                False                 False
# 201998           False                False                 False
# 201999           False                False                 False
# 202000           False                False                 False
# 202001           False                False                 False
#
#          stationery.paper   stationery.stapler
# 0                   False                False
# 1                   False                False
# 2                   False                False
# 3                   False                False
# 4                   False                False
# ...                   ...                  ...
# 201997              False                False
# 201998              False                False
# 201999              False                False
# 202000              False                False
# 202001              False                False
#
# [202002 rows x 123 columns]

# %% [markdown]
# ### 2.1.2 Store Clicks df
#
# The same has to be done for the clicks df

# %%
clickprod_df.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories                 Timestamp
# 0     5737263  214536500   electronics.tablet  2014-07-03T21:16:08.804Z
# 1     5737263  214536500   electronics.tablet  2014-07-03T21:21:22.935Z
# 2     5702866  214536500   electronics.tablet  2014-07-06T18:34:10.251Z
# 3     6172052  214536500   electronics.tablet  2014-07-11T10:50:14.687Z
# 4     5879836  214536500   electronics.tablet  2014-07-10T18:54:15.150Z

# %%
weeksdf = clickprod_df
time = weeksdf["Timestamp"].str.split("T", n = 1, expand = True)
weeksdf["Timestamp"] = time[0]
weeksdf.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories   Timestamp
# 0     5737263  214536500   electronics.tablet  2014-07-03
# 1     5737263  214536500   electronics.tablet  2014-07-03
# 2     5702866  214536500   electronics.tablet  2014-07-06
# 3     6172052  214536500   electronics.tablet  2014-07-11
# 4     5879836  214536500   electronics.tablet  2014-07-10

# %%
teste = weeksdf
teste["Timestamp"] = pd.to_datetime(teste['Timestamp'])
teste['Semana'] = teste['Timestamp'].dt.day_name()

clicks_weeknd_df =  teste.loc[teste['Semana'].isin(['Saturday', 'Sunday'])] 
clicks_weekday_df = teste.loc[~teste['Semana'].isin(['Saturday', 'Sunday'])]

# %% [markdown]
# ## Weekend

# %%
clicks_weeknd_df
# Out:
#         Session_ID    Item_ID                  Product_Categories  Timestamp  \
# 2          5702866  214536500                  electronics.tablet 2014-07-06
# 6          5114188  214662742             furniture.kitchen.table 2014-06-22
# 9          5847857  214662742             furniture.kitchen.table 2014-07-06
# 13         6719109  214662742             furniture.kitchen.table 2014-07-26
# 15         6018787  214825110              electronics.smartphone 2014-07-12
# ...            ...        ...                                 ...        ...
# 606688     6751091  214854446              electronics.calculator 2014-07-26
# 606690     6781946  214855001         electronics.audio.subwoofer 2014-07-26
# 606691     6781946  214855001         electronics.audio.subwoofer 2014-07-26
# 606698     6643793  214817257   computers.components.power_supply 2014-07-26
# 606705     6857052  214846592             country_yard.lawn_mower 2014-07-27
#
#           Semana
# 2         Sunday
# 6         Sunday
# 9         Sunday
# 13      Saturday
# 15      Saturday
# ...          ...
# 606688  Saturday
# 606690  Saturday
# 606691  Saturday
# 606698  Saturday
# 606705    Sunday
#
# [261525 rows x 5 columns]

# %%
clicks_weeknd_transactions= []
for i in list(buys_weeknd_df.Session_ID.unique()):
    clicks_weeknd_transactions.append(clicks_weeknd_df[clicks_weeknd_df.Session_ID==i].Product_Categories.values.tolist())
    
clicks_weeknd_transactions
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.kitchen.fryer',
#   ' construction.tools.generator',
#   ' electronics.tablet',
#   ' construction.tools.heater',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' country_yard.watering',
#   ' country_yard.watering',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.camera',
#   ' kids.fmcg.diapers',
#   ' kids.toys',
#   ' kids.toys',
#   ' computers.gaming',
#   ' construction.tools.heater',
#   ' auto.accessories.videoregister',
#   ' computers.notebook',
#   ' construction.tools.generator',
#   ' stationery.cartrige',
#   ' computers.components.cooler',
#   ' construction.tools.saw',
#   ' construction.tools.heater',
#   ' electronics.tablet',
#   ' furniture.universal.light',
#   ' computers.components.cpu',
#   ' appliances.environment.air_conditioner',
#   ' construction.tools.generator',
#   ' appliances.kitchen.oven',
#   ' construction.tools.heater',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.dishwasher',
#   ' computers.components.cooler',
#   ' appliances.kitchen.kettle',
#   ' sport.tennis',
#   ' apparel.trousers'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.video.tv',
#   ' kids.toys',
#   ' kids.toys',
#   ' sport.bicycle',
#   ' sport.bicycle',
#   ' computers.components.cpu',
#   ' electronics.calculator',
#   ' computers.components.memory'],
#  [' computers.components.cpu', ' electronics.clocks'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.battery',
#   ' furniture.bedroom.pillow',
#   ' furniture.bedroom.pillow',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' electronics.telephone',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.environment.climate',
#   ' appliances.iron',
#   ' electronics.audio.acoustic',
#   ' stationery.cartrige',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.scanner',
#   ' apparel.shoes',
#   ' appliances.iron',
#   ' appliances.kitchen.hood',
#   ' computers.components.cdrw',
#   ' apparel.tshirt',
#   ' stationery.battery',
#   ' electronics.video.tv',
#   ' furniture.bedroom.pillow',
#   ' auto.accessories.player',
#   ' appliances.kitchen.hood',
#   ' construction.tools.welding',
#   ' computers.notebook',
#   ' sport.tennis',
#   ' electronics.calculator',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' appliances.steam_cleaner',
#   ' kids.bottles',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' computers.components.hdd',
#   ' appliances.environment.water_heater',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.meat_grinder',
#   ' auto.accessories.anti_freeze',
#   ' electronics.calculator',
#   ' sport.tennis',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' construction.tools.screw',
#   ' appliances.kitchen.mixer',
#   ' appliances.iron',
#   ' accessories.bag',
#   ' computers.components.power_supply',
#   ' sport.snowboard',
#   ' sport.snowboard',
#   ' computers.components.power_supply',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.fan',
#   ' computers.peripherals.printer',
#   ' appliances.personal.massager',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.juicer',
#   ' appliances.iron',
#   ' appliances.personal.hair_cutter',
#   ' auto.accessories.player',
#   ' kids.skates',
#   ' electronics.video.tv',
#   ' auto.accessories.player',
#   ' appliances.kitchen.hood',
#   ' auto.accessories.compressor',
#   ' sport.tennis',
#   ' construction.tools.heater',
#   ' appliances.kitchen.microwave',
#   ' construction.tools.heater',
#   ' electronics.calculator',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill',
#   ' furniture.universal.light',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' kids.bottles'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' computers.components.memory',
#   ' appliances.kitchen.juicer',
#   ' appliances.steam_cleaner',
#   ' furniture.universal.light',
#   ' appliances.kitchen.mixer',
#   ' kids.toys',
#   ' kids.toys',
#   ' accessories.bag',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' stationery.stapler',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' furniture.bedroom.pillow',
#   ' computers.notebook',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.printer',
#   ' appliances.kitchen.washer',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' computers.notebook',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' apparel.shoes',
#   ' electronics.telephone',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' accessories.bag',
#   ' computers.components.power_supply',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' appliances.iron',
#   ' computers.peripherals.printer',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' kids.toys',
#   ' sport.ski',
#   ' furniture.universal.light',
#   ' computers.ebooks',
#   ' stationery.paper',
#   ' stationery.paper',
#   ' stationery.paper',
#   ' stationery.paper',
#   ' construction.tools.screw',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.washer',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' appliances.kitchen.washer',
#   ' furniture.universal.light',
#   ' accessories.bag',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' accessories.bag',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' kids.toys',
#   ' apparel.shoes',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' furniture.universal.light',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' computers.components.power_supply',
#   ' computers.notebook',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' appliances.kitchen.toster',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.coffee_machine',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' sport.snowboard',
#   ' sport.snowboard',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' kids.bottles',
#   ' kids.bottles',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' appliances.kitchen.mixer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.universal.light',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' kids.bottles'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.iron',
#   ' appliances.environment.fan',
#   ' electronics.calculator',
#   ' sport.tennis',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' kids.bottles',
#   ' kids.bottles'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' furniture.living_room.chair',
#   ' electronics.telephone',
#   ' furniture.kitchen.table',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' appliances.environment.fan',
#   ' appliances.personal.hair_cutter',
#   ' apparel.shoes',
#   ' electronics.audio.subwoofer',
#   ' electronics.audio.subwoofer',
#   ' electronics.audio.subwoofer',
#   ' electronics.audio.subwoofer',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' electronics.calculator',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' kids.bottles',
#   ' kids.bottles',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' kids.toys',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.blender',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' stationery.cartrige',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.coffee_grinder',
#   ' appliances.environment.climate',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' auto.accessories.radar',
#   ' computers.peripherals.mouse',
#   ' furniture.living_room.chair',
#   ' appliances.kitchen.dishwasher',
#   ' construction.tools.welding',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' kids.bottles'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' accessories.bag',
#   ' accessories.bag',
#   ' construction.tools.heater',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' electronics.audio.microphone',
#   ' computers.components.power_supply',
#   ' sport.bicycle',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' construction.tools.heater',
#   ' apparel.glove',
#   ' computers.components.cdrw',
#   ' accessories.bag',
#   ' furniture.living_room.sofa',
#   ' electronics.audio.microphone',
#   ' apparel.shirt',
#   ' kids.swing',
#   ' electronics.audio.microphone',
#   ' apparel.glove',
#   ' kids.swing',
#   ' computers.network.router',
#   ' electronics.telephone',
#   ' accessories.bag',
#   ' appliances.kitchen.dishwasher',
#   ' construction.tools.heater',
#   ' apparel.glove',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.bicycle',
#   ' furniture.living_room.chair',
#   ' sport.snowboard',
#   ' construction.tools.welding',
#   ' sport.bicycle',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks'],
#  [' accessories.bag', ' accessories.bag'],
#  [],
#  [],
#  [],
#  [' computers.peripherals.keyboard',
#   ' computers.peripherals.keyboard',
#   ' appliances.kitchen.juicer',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' sport.diving',
#   ' construction.tools.drill',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' accessories.bag'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [' computers.peripherals.mouse',
#   ' stationery.cartrige',
#   ' electronics.video.tv',
#   ' sport.bicycle',
#   ' appliances.kitchen.juicer',
#   ' appliances.environment.climate',
#   ' accessories.bag',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' computers.notebook',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.peripherals.mouse',
#   ' appliances.iron',
#   ' computers.peripherals.scanner',
#   ' electronics.calculator',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster'],
#  [' computers.peripherals.mouse',
#   ' accessories.bag',
#   ' appliances.environment.climate',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' computers.components.memory',
#   ' kids.bottles',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill',
#   ' country_yard.lawn_mower'],
#  [' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' stationery.cartrige',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' furniture.living_room.chair',
#   ' country_yard.cultivator',
#   ' computers.components.power_supply',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.grill',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower'],
#  [' computers.peripherals.mouse', ' appliances.kitchen.toster'],
#  [' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse'],
#  [' computers.peripherals.keyboard',
#   ' computers.peripherals.mouse',
#   ' appliances.iron',
#   ' computers.components.videocards',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' kids.bottles',
#   ' appliances.kitchen.grill',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' kids.bottles',
#   ' appliances.steam_cleaner'],
#  [' computers.peripherals.mouse',
#   ' appliances.iron',
#   ' stationery.battery',
#   ' electronics.video.tv',
#   ' appliances.environment.climate',
#   ' electronics.telephone',
#   ' appliances.personal.massager',
#   ' appliances.personal.massager',
#   ' kids.toys',
#   ' stationery.cartrige',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.personal.massager',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(clicks_weeknd_transactions).transform(clicks_weeknd_transactions)
click_weeknd_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
click_weeknd_binary_db
# Out:
#          accessories.bag   accessories.umbrella   apparel.costume  \
# 0                  False                  False             False
# 1                  False                  False             False
# 2                  False                  False             False
# 3                  False                  False             False
# 4                  False                  False             False
# ...                  ...                    ...               ...
# 116437             False                  False             False
# 116438             False                  False             False
# 116439             False                  False             False
# 116440             False                  False             False
# 116441             False                  False             False
#
#          apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0                False           False           False          False
# 1                False           False           False          False
# 2                False           False           False          False
# 3                False           False           False          False
# 4                False           False           False          False
# ...                ...             ...             ...            ...
# 116437           False           False           False          False
# 116438           False           False           False          False
# 116439           False           False           False          False
# 116440           False           False           False          False
# 116441           False           False           False          False
#
#          apparel.trousers   apparel.tshirt  \
# 0                   False            False
# 1                   False            False
# 2                   False            False
# 3                   False            False
# 4                   False            False
# ...                   ...              ...
# 116437              False            False
# 116438              False            False
# 116439              False            False
# 116440              False            False
# 116441              False            False
#
#          appliances.environment.air_conditioner  ...   sport.bicycle  \
# 0                                         False  ...           False
# 1                                         False  ...           False
# 2                                         False  ...           False
# 3                                         False  ...           False
# 4                                         False  ...           False
# ...                                         ...  ...             ...
# 116437                                    False  ...           False
# 116438                                    False  ...           False
# 116439                                    False  ...           False
# 116440                                    False  ...           False
# 116441                                    False  ...           False
#
#          sport.diving   sport.ski   sport.snowboard   sport.tennis  \
# 0               False       False             False          False
# 1               False       False             False          False
# 2               False       False             False          False
# 3               False       False             False          False
# 4               False       False             False          False
# ...               ...         ...               ...            ...
# 116437          False       False             False          False
# 116438          False       False             False           True
# 116439          False       False             False           True
# 116440          False       False             False          False
# 116441          False       False             False          False
#
#          sport.trainer   stationery.battery   stationery.cartrige  \
# 0                False                False                 False
# 1                False                False                 False
# 2                False                False                 False
# 3                False                False                 False
# 4                False                False                 False
# ...                ...                  ...                   ...
# 116437           False                False                 False
# 116438           False                False                 False
# 116439           False                False                 False
# 116440           False                False                 False
# 116441           False                False                 False
#
#          stationery.paper   stationery.stapler
# 0                   False                False
# 1                   False                False
# 2                   False                False
# 3                   False                False
# 4                   False                False
# ...                   ...                  ...
# 116437              False                False
# 116438              False                False
# 116439              False                False
# 116440              False                False
# 116441              False                False
#
# [116442 rows x 123 columns]

# %% [markdown]
# ## WeekDay

# %%
clicks_weekday_df
# Out:
#         Session_ID    Item_ID              Product_Categories  Timestamp  \
# 0          5737263  214536500              electronics.tablet 2014-07-03
# 1          5737263  214536500              electronics.tablet 2014-07-03
# 3          6172052  214536500              electronics.tablet 2014-07-11
# 4          5879836  214536500              electronics.tablet 2014-07-10
# 5          5118543  214662742         furniture.kitchen.table 2014-06-23
# ...            ...        ...                             ...        ...
# 606703     6880237  214766420                 sport.snowboard 2014-07-25
# 606704     6860077  214712259   computers.peripherals.scanner 2014-07-23
# 606706     6883899  214822181         furniture.bathroom.bath 2014-07-23
# 606707     6883899  214823535     electronics.audio.subwoofer 2014-07-23
# 606708     6938531  214808205        computers.network.router 2014-07-24
#
#            Semana
# 0        Thursday
# 1        Thursday
# 3          Friday
# 4        Thursday
# 5          Monday
# ...           ...
# 606703     Friday
# 606704  Wednesday
# 606706  Wednesday
# 606707  Wednesday
# 606708   Thursday
#
# [345184 rows x 5 columns]

# %%
click_weekday_transactions= []
for i in list(clicks_weekday_df.Session_ID.unique()):
    click_weekday_transactions.append(clicks_weekday_df[clicks_weekday_df.Session_ID==i].Product_Categories.values.tolist())
    
click_weekday_transactions
# Out:
# [[' electronics.tablet',
#   ' electronics.tablet',
#   ' kids.swing',
#   ' appliances.environment.air_heater',
#   ' appliances.kitchen.washer',
#   ' kids.swing',
#   ' kids.swing',
#   ' kids.swing',
#   ' computers.components.videocards',
#   ' construction.tools.drill'],
#  [' electronics.tablet',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' computers.components.videocards'],
#  [' electronics.tablet',
#   ' computers.peripherals.mouse',
#   ' electronics.tablet',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' apparel.tshirt',
#   ' sport.snowboard',
#   ' country_yard.cultivator',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer'],
#  [' furniture.kitchen.table',
#   ' computers.components.motherboard',
#   ' computers.components.memory',
#   ' electronics.audio.headphone',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' apparel.tshirt',
#   ' furniture.bedroom.pillow',
#   ' furniture.kitchen.table',
#   ' electronics.calculator',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' kids.bottles'],
#  [' furniture.kitchen.table',
#   ' furniture.kitchen.table',
#   ' furniture.bedroom.pillow',
#   ' computers.components.memory',
#   ' construction.tools.light',
#   ' electronics.calculator',
#   ' furniture.kitchen.table',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' appliances.steam_cleaner'],
#  [' furniture.kitchen.table',
#   ' appliances.kitchen.blender',
#   ' accessories.bag',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.environment.climate',
#   ' construction.tools.light',
#   ' electronics.video.projector',
#   ' construction.tools.light',
#   ' auto.accessories.player',
#   ' appliances.kitchen.hood',
#   ' kids.toys',
#   ' furniture.kitchen.table',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' furniture.kitchen.table',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.light',
#   ' computers.peripherals.camera',
#   ' furniture.kitchen.table',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' appliances.environment.vacuum',
#   ' construction.tools.drill'],
#  [' furniture.kitchen.table',
#   ' appliances.kitchen.coffee_grinder',
#   ' appliances.environment.climate',
#   ' computers.components.videocards',
#   ' computers.peripherals.printer',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' electronics.audio.headphone',
#   ' construction.tools.light',
#   ' computers.peripherals.printer',
#   ' apparel.tshirt',
#   ' furniture.kitchen.table',
#   ' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' furniture.kitchen.table',
#   ' computers.components.motherboard',
#   ' electronics.audio.headphone',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' construction.tools.screw',
#   ' construction.tools.light',
#   ' appliances.iron',
#   ' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.refrigerators',
#   ' electronics.camera.photo',
#   ' electronics.camera.photo',
#   ' computers.network.router',
#   ' stationery.battery',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.camera',
#   ' appliances.kitchen.juicer',
#   ' furniture.living_room.cabinet',
#   ' construction.tools.screw',
#   ' kids.fmcg.diapers',
#   ' stationery.paper',
#   ' electronics.audio.subwoofer',
#   ' electronics.calculator',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' appliances.personal.scales', ' sport.ski'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' stationery.paper',
#   ' apparel.glove',
#   ' apparel.glove'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.ebooks',
#   ' kids.toys',
#   ' construction.tools.light',
#   ' furniture.living_room.sofa',
#   ' electronics.telephone',
#   ' apparel.shoes',
#   ' electronics.audio.microphone',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' appliances.kitchen.microwave',
#   ' apparel.sock',
#   ' electronics.smartphone',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.microwave',
#   ' computers.components.hdd'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' furniture.living_room.chair',
#   ' appliances.personal.scales'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' accessories.bag'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.clocks',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.clocks',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.clocks'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' furniture.kitchen.chair',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' kids.bottles',
#   ' kids.bottles'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.peripherals.scanner',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' sport.trainer',
#   ' computers.components.videocards'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.iron',
#   ' computers.components.hdd',
#   ' computers.components.cdrw',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.environment.vacuum',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' construction.tools.screw',
#   ' auto.accessories.radar',
#   ' auto.accessories.radar',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv', ' computers.components.memory'],
#  [' electronics.video.tv', ' electronics.video.tv', ' computers.notebook'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.printer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.camera',
#   ' electronics.clocks'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' sport.trainer',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' computers.components.power_supply',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' apparel.sock',
#   ' furniture.kitchen.chair'],
#  [' electronics.video.tv',
#   ' electronics.camera.photo',
#   ' medicine.tools.tonometer',
#   ' auto.accessories.compressor',
#   ' medicine.tools.tonometer',
#   ' furniture.kitchen.chair',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' kids.bottles'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' kids.toys',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.scanner',
#   ' electronics.video.tv',
#   ' computers.peripherals.mouse',
#   ' apparel.shirt',
#   ' appliances.kitchen.grill',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' apparel.shoes',
#   ' apparel.shoes',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.coffee_machine',
#   ' electronics.video.tv',
#   ' appliances.environment.climate',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' appliances.kitchen.microwave',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.audio.headphone',
#   ' apparel.shoes',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.iron',
#   ' stationery.battery',
#   ' appliances.kitchen.coffee_machine',
#   ' stationery.battery',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' electronics.video.tv',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster',
#   ' kids.bottles',
#   ' appliances.kitchen.grill',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' apparel.shoes',
#   ' kids.skates',
#   ' stationery.stapler',
#   ' appliances.iron',
#   ' construction.tools.heater',
#   ' appliances.kitchen.kettle',
#   ' furniture.kitchen.chair',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.climate',
#   ' furniture.bedroom.blanket',
#   ' apparel.shoes',
#   ' furniture.bedroom.pillow',
#   ' sport.tennis',
#   ' computers.components.power_supply',
#   ' kids.bottles'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' sport.ski',
#   ' sport.ski',
#   ' sport.ski',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.personal.scales',
#   ' sport.ski',
#   ' computers.components.cpu',
#   ' sport.ski'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.battery',
#   ' apparel.tshirt',
#   ' computers.notebook',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill'],
#  [' computers.components.cpu',
#   ' electronics.audio.dictaphone',
#   ' appliances.environment.water_heater',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' furniture.living_room.sofa',
#   ' furniture.living_room.sofa'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' kids.swing',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.tablet',
#   ' computers.peripherals.camera',
#   ' computers.components.cooler',
#   ' apparel.shirt',
#   ' computers.peripherals.scanner',
#   ' electronics.tablet',
#   ' computers.components.cooler',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' stationery.battery',
#   ' construction.tools.drill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' computers.components.cpu', ' computers.desktop'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cooler',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' appliances.environment.vacuum'],
#  [' computers.components.cpu',
#   ' stationery.cartrige',
#   ' furniture.universal.light',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.keyboard',
#   ' computers.notebook',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.monitor',
#   ' electronics.video.tv',
#   ' furniture.living_room.sofa',
#   ' kids.toys',
#   ' appliances.environment.air_conditioner',
#   ' appliances.environment.climate',
#   ' appliances.kitchen.washer',
#   ' computers.components.cpu',
#   ' appliances.environment.air_conditioner',
#   ' appliances.personal.massager',
#   ' computers.desktop',
#   ' apparel.shirt',
#   ' furniture.bedroom.blanket',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' auto.accessories.radar',
#   ' appliances.steam_cleaner',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.components.cpu',
#   ' sport.bicycle',
#   ' appliances.iron',
#   ' kids.toys',
#   ' apparel.sock',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' apparel.trousers',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' furniture.living_room.chair',
#   ' appliances.iron',
#   ' kids.toys',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' apparel.glove',
#   ' country_yard.lawn_mower'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.iron',
#   ' electronics.audio.microphone',
#   ' appliances.kitchen.blender',
#   ' country_yard.cultivator',
#   ' appliances.kitchen.coffee_machine',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' construction.tools.screw',
#   ' appliances.kitchen.washer',
#   ' sport.bicycle',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.telephone',
#   ' country_yard.lawn_mower',
#   ' computers.components.cpu',
#   ' furniture.living_room.sofa',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.dishwasher',
#   ' construction.tools.saw',
#   ' appliances.kitchen.dishwasher',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' kids.toys',
#   ' accessories.bag',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' kids.fmcg.diapers',
#   ' electronics.video.projector',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' furniture.universal.light'],
#  [' computers.components.cpu',
#   ' electronics.tablet',
#   ' auto.accessories.anti_freeze',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' electronics.calculator',
#   ' electronics.clocks'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' furniture.bedroom.pillow'],
#  [' appliances.kitchen.kettle', ' sport.tennis'],
#  [' appliances.kitchen.kettle', ' appliances.kitchen.kettle'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' computers.components.power_supply',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' construction.tools.screw',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.iron',
#   ' computers.components.videocards',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.iron',
#   ' appliances.environment.air_conditioner',
#   ' electronics.telephone',
#   ' appliances.kitchen.juicer',
#   ' accessories.bag',
#   ' furniture.kitchen.chair',
#   ' construction.tools.welding',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.living_room.shelving',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' stationery.cartrige',
#   ' appliances.iron',
#   ' appliances.kitchen.mixer',
#   ' appliances.iron',
#   ' appliances.environment.climate',
#   ' computers.peripherals.monitor',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' construction.tools.screw',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' sport.bicycle',
#   ' appliances.personal.massager',
#   ' appliances.personal.massager',
#   ' sport.bicycle',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' furniture.bedroom.pillow',
#   ' furniture.universal.light',
#   ' apparel.tshirt',
#   ' country_yard.weather_station',
#   ' electronics.telephone',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.kitchen.steam_cooker',
#   ' furniture.bedroom.pillow',
#   ' electronics.telephone',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.toster',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' electronics.audio.headphone',
#   ' appliances.kitchen.mixer',
#   ' electronics.calculator',
#   ' apparel.tshirt',
#   ' furniture.bedroom.pillow',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' construction.tools.welding',
#   ' appliances.environment.vacuum',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower',
#   ' construction.tools.drill',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' computers.components.cdrw',
#   ' auto.accessories.compressor',
#   ' stationery.battery',
#   ' computers.peripherals.scanner',
#   ' computers.notebook',
#   ' appliances.environment.climate',
#   ' apparel.shoes',
#   ' appliances.environment.air_conditioner',
#   ' appliances.kitchen.toster',
#   ' kids.toys',
#   ' auto.accessories.radar',
#   ' computers.notebook',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' apparel.shoes',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.meat_grinder',
#   ' apparel.shoes',
#   ' appliances.personal.hair_cutter',
#   ' appliances.kitchen.washer',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.steam_cleaner',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.hood',
#   ' electronics.video.tv',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' stationery.cartrige',
#   ' accessories.bag',
#   ' appliances.kitchen.washer',
#   ' accessories.bag',
#   ' appliances.ironing_board',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.toster',
#   ' electronics.calculator',
#   ' stationery.battery',
#   ' stationery.battery',
#   ' computers.components.power_supply',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' auto.accessories.videoregister',
#   ' appliances.kitchen.hood',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.power_supply',
#   ' computers.components.cdrw',
#   ' auto.accessories.compressor',
#   ' appliances.personal.hair_cutter',
#   ' furniture.living_room.chair',
#   ' stationery.battery',
#   ' stationery.battery',
#   ' electronics.video.tv',
#   ' auto.accessories.radar',
#   ' computers.components.power_supply',
#   ' appliances.personal.hair_cutter',
#   ' electronics.clocks',
#   ' country_yard.cultivator',
#   ' computers.components.power_supply',
#   ' furniture.bedroom.pillow',
#   ' stationery.battery',
#   ' furniture.bedroom.bed',
#   ' appliances.ironing_board',
#   ' electronics.audio.headphone',
#   ' computers.components.power_supply',
#   ' electronics.audio.headphone',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.dishwasher',
#   ' auto.accessories.compressor',
#   ' computers.components.power_supply',
#   ' appliances.ironing_board',
#   ' country_yard.weather_station',
#   ' stationery.stapler',
#   ' construction.tools.screw',
#   ' electronics.clocks',
#   ' furniture.bedroom.pillow',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' appliances.personal.hair_cutter',
#   ' appliances.personal.massager',
#   ' computers.components.cooler',
#   ' appliances.kitchen.kettle',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.steam_cleaner',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' appliances.steam_cleaner',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' kids.bottles'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' electronics.audio.subwoofer',
#   ' electronics.calculator',
#   ' computers.components.memory',
#   ' computers.components.hdd',
#   ' computers.components.hdd',
#   ' computers.components.hdd',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' computers.components.hdd',
#   ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' apparel.tshirt',
#   ' computers.ebooks',
#   ' stationery.battery',
#   ' appliances.kitchen.blender',
#   ' auto.accessories.player',
#   ' computers.ebooks',
#   ' construction.tools.welding',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.climate',
#   ' electronics.telephone',
#   ' electronics.telephone',
#   ' computers.components.cdrw',
#   ' construction.tools.welding',
#   ' sport.tennis',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' sport.tennis',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' electronics.audio.subwoofer',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.iron',
#   ' appliances.kitchen.juicer',
#   ' construction.tools.welding',
#   ' appliances.kitchen.blender',
#   ' sport.tennis',
#   ' computers.components.power_supply',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' computers.peripherals.printer',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.washer',
#   ' electronics.video.tv',
#   ' auto.accessories.anti_freeze',
#   ' auto.accessories.anti_freeze',
#   ' apparel.tshirt',
#   ' furniture.living_room.sofa',
#   ' appliances.environment.air_conditioner',
#   ' appliances.environment.climate',
#   ' auto.accessories.anti_freeze',
#   ' auto.accessories.anti_freeze',
#   ' kids.toys',
#   ' country_yard.cultivator',
#   ' construction.tools.welding',
#   ' sport.tennis',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.kitchen.table',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.iron',
#   ' furniture.living_room.chair',
#   ' appliances.environment.water_heater',
#   ' sport.diving',
#   ' apparel.tshirt',
#   ' electronics.audio.headphone',
#   ' apparel.trousers',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' computers.components.cooler',
#   ' appliances.kitchen.dishwasher',
#   ' electronics.video.tv',
#   ' kids.toys',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' appliances.kitchen.washer',
#   ' appliances.iron',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.water_heater',
#   ' furniture.bedroom.pillow',
#   ' appliances.personal.massager',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.toster',
#   ' apparel.sock',
#   ' electronics.clocks',
#   ' construction.tools.welding',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.notebook',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' stationery.cartrige',
#   ' apparel.tshirt',
#   ' furniture.bedroom.pillow',
#   ' furniture.bedroom.pillow',
#   ' appliances.environment.climate',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' apparel.shoes',
#   ' appliances.kitchen.washer',
#   ' electronics.telephone',
#   ' auto.accessories.player',
#   ' furniture.bedroom.pillow',
#   ' kids.skates',
#   ' construction.tools.heater',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.heater',
#   ' computers.ebooks',
#   ' kids.skates',
#   ' construction.tools.heater',
#   ' construction.tools.heater',
#   ' construction.tools.heater',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' sport.bicycle',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.ironing_board',
#   ' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' appliances.kitchen.washer',
#   ' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' appliances.environment.water_heater',
#   ' construction.tools.screw',
#   ' appliances.kitchen.meat_grinder',
#   ' apparel.tshirt',
#   ' appliances.ironing_board',
#   ' construction.tools.heater',
#   ' construction.tools.welding',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' computers.peripherals.monitor',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' kids.bottles',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' apparel.tshirt',
#   ' electronics.calculator',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' accessories.bag',
#   ' furniture.bedroom.pillow',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' construction.tools.welding',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.grill',
#   ' kids.bottles'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.fan',
#   ' electronics.audio.subwoofer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' electronics.audio.acoustic',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.cdrw',
#   ' apparel.tshirt',
#   ' apparel.tshirt',
#   ' kids.toys',
#   ' stationery.battery',
#   ' apparel.sock',
#   ' appliances.personal.hair_cutter',
#   ' country_yard.weather_station',
#   ' apparel.trousers',
#   ' apparel.trousers',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' furniture.living_room.cabinet',
#   ' electronics.video.tv',
#   ' computers.components.videocards',
#   ' furniture.kitchen.table',
#   ' appliances.iron',
#   ' computers.peripherals.mouse',
#   ' electronics.audio.subwoofer',
#   ' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.screw',
#   ' kids.swing',
#   ' electronics.video.tv',
#   ' electronics.telephone',
#   ' kids.swing',
#   ' kids.swing',
#   ' furniture.bedroom.pillow',
#   ' country_yard.cultivator',
#   ' appliances.environment.climate',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' construction.tools.welding',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.kitchen.mixer',
#   ' kids.toys',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.steam_cooker',
#   ' apparel.tshirt',
#   ' furniture.living_room.cabinet',
#   ' stationery.battery',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.mixer',
#   ' kids.toys',
#   ' appliances.personal.massager',
#   ' construction.tools.pump',
#   ' construction.tools.pump',
#   ' construction.tools.pump',
#   ' construction.tools.pump',
#   ' construction.tools.pump',
#   ' construction.tools.pump',
#   ' country_yard.watering',
#   ' construction.tools.pump',
#   ' country_yard.weather_station',
#   ' stationery.cartrige',
#   ' construction.tools.pump',
#   ' computers.peripherals.joystick',
#   ' construction.tools.welding',
#   ' apparel.shirt',
#   ' apparel.shirt',
#   ' apparel.shirt',
#   ' computers.peripherals.monitor',
#   ' apparel.shirt',
#   ' sport.tennis',
#   ' appliances.environment.vacuum',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' furniture.bedroom.pillow',
#   ' appliances.environment.water_heater',
#   ' stationery.battery',
#   ' electronics.telephone',
#   ' auto.accessories.compressor',
#   ' apparel.shoes',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' computers.components.memory',
#   ' kids.bottles',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' electronics.calculator',
#   ' computers.peripherals.scanner',
#   ' furniture.living_room.cabinet',
#   ' stationery.battery',
#   ' furniture.bedroom.pillow',
#   ' furniture.bedroom.pillow',
#   ' electronics.calculator',
#   ' construction.tools.welding',
#   ' appliances.kitchen.washer',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.washer',
#   ' appliances.iron',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.peripherals.printer',
#   ' computers.components.memory',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' apparel.tshirt',
#   ' auto.accessories.radar',
#   ' construction.tools.generator',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' furniture.living_room.cabinet',
#   ' furniture.living_room.cabinet',
#   ' apparel.glove',
#   ' appliances.kitchen.grill',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.cdrw',
#   ' stationery.battery',
#   ' stationery.battery',
#   ' electronics.video.tv',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' electronics.calculator',
#   ' apparel.tshirt',
#   ' electronics.audio.headphone',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' auto.accessories.videoregister',
#   ' furniture.bedroom.pillow',
#   ' furniture.bedroom.pillow',
#   ' auto.accessories.compressor',
#   ' appliances.kitchen.blender',
#   ' sport.tennis',
#   ' kids.dolls',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.kitchen.table',
#   ' computers.peripherals.printer',
#   ' computers.components.memory',
#   ' electronics.video.tv',
# ...
#   ' computers.components.cdrw',
#   ' computers.components.cdrw',
#   ' furniture.bedroom.pillow',
#   ' computers.components.motherboard',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' apparel.shirt',
#   ' electronics.camera.video',
#   ' appliances.kitchen.dishwasher',
#   ' computers.components.hdd',
#   ' apparel.tshirt',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.dishwasher',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' appliances.personal.massager',
#   ' appliances.kitchen.kettle',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.camera',
#   ' construction.tools.drill',
#   ' furniture.living_room.sofa'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' sport.bicycle'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.scanner',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.keyboard'],
#  [' appliances.kitchen.mixer', ' computers.peripherals.keyboard'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' computers.peripherals.monitor'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' apparel.costume', ' apparel.costume'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' electronics.video.tv'],
#  [' appliances.kitchen.mixer', ' computers.components.memory'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' country_yard.cultivator'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' country_yard.watering',
#   ' country_yard.watering'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' computers.peripherals.keyboard',
#   ' construction.tools.screw'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.components.hdd',
#   ' computers.components.hdd'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.fryer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' country_yard.weather_station'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' auto.accessories.compressor',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.mixer',
#   ' computers.components.hdd',
#   ' apparel.tshirt',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.fryer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.blender'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' computers.peripherals.keyboard'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.keyboard'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.grill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.meat_grinder',
#   ' apparel.trousers',
#   ' construction.tools.pump',
#   ' appliances.environment.water_heater',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.camera',
#   ' furniture.living_room.sofa',
#   ' electronics.telephone',
#   ' computers.components.hdd',
#   ' appliances.personal.massager',
#   ' appliances.personal.massager',
#   ' appliances.kitchen.steam_cooker',
#   ' electronics.calculator',
#   ' electronics.video.tv',
#   ' appliances.kitchen.coffee_machine',
#   ' furniture.bedroom.pillow',
#   ' country_yard.weather_station',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' electronics.video.projector',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' kids.bottles'],
#  [' appliances.kitchen.mixer',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' computers.peripherals.keyboard',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.keyboard',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' furniture.living_room.sofa',
#   ' computers.peripherals.scanner',
#   ' apparel.tshirt',
#   ' apparel.tshirt'],
#  [' appliances.kitchen.mixer', ' kids.bottles', ' kids.bottles'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' computers.peripherals.keyboard'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.keyboard',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' computers.peripherals.mouse',
#   ' appliances.environment.vacuum'],
#  [' appliances.kitchen.mixer',
#   ' computers.components.hdd',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' computers.peripherals.scanner'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.fryer'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.keyboard',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' computers.components.hdd',
#   ' computers.components.hdd',
#   ' computers.components.hdd'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' auto.accessories.radar',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' computers.peripherals.keyboard'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' medicine.tools.tonometer',
#   ' auto.accessories.compressor',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.mixer',
#   ' sport.tennis'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' computers.peripherals.keyboard',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.keyboard'],
#  [' appliances.kitchen.mixer',
#   ' electronics.audio.subwoofer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.microwave',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' computers.peripherals.scanner'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' appliances.kitchen.mixer',
#   ' construction.tools.screw',
#   ' construction.tools.screw',
#   ' construction.tools.screw',
#   ' construction.tools.screw',
#   ' apparel.glove',
#   ' appliances.environment.vacuum',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  ...]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(click_weekday_transactions).transform(click_weekday_transactions)
click_weekday_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
click_weekday_binary_db
# Out:
#         accessories.bag   accessories.umbrella   apparel.costume  \
# 0                 False                  False             False
# 1                 False                  False             False
# 2                 False                  False             False
# 3                  True                  False             False
# 4                 False                  False             False
# ...                 ...                    ...               ...
# 56667             False                  False             False
# 56668             False                  False             False
# 56669             False                  False             False
# 56670             False                  False             False
# 56671             False                  False             False
#
#         apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0               False           False           False          False
# 1               False           False           False          False
# 2               False           False           False          False
# 3               False           False           False          False
# 4               False           False           False          False
# ...               ...             ...             ...            ...
# 56667           False           False           False          False
# 56668           False           False           False          False
# 56669           False           False           False          False
# 56670           False           False           False          False
# 56671           False           False           False          False
#
#         apparel.trousers   apparel.tshirt  \
# 0                  False            False
# 1                  False            False
# 2                  False             True
# 3                  False             True
# 4                  False            False
# ...                  ...              ...
# 56667              False            False
# 56668              False            False
# 56669              False            False
# 56670              False            False
# 56671              False            False
#
#         appliances.environment.air_conditioner  ...   sport.bicycle  \
# 0                                        False  ...           False
# 1                                        False  ...           False
# 2                                        False  ...           False
# 3                                        False  ...           False
# 4                                        False  ...           False
# ...                                        ...  ...             ...
# 56667                                    False  ...           False
# 56668                                    False  ...           False
# 56669                                    False  ...           False
# 56670                                    False  ...           False
# 56671                                    False  ...           False
#
#         sport.diving   sport.ski   sport.snowboard   sport.tennis  \
# 0              False       False             False          False
# 1              False       False             False          False
# 2              False       False              True          False
# 3              False       False             False           True
# 4              False       False             False          False
# ...              ...         ...               ...            ...
# 56667          False       False             False          False
# 56668          False       False             False          False
# 56669          False       False             False          False
# 56670          False       False             False          False
# 56671          False       False             False          False
#
#         sport.trainer   stationery.battery   stationery.cartrige  \
# 0               False                False                 False
# 1               False                False                 False
# 2               False                False                 False
# 3               False                False                 False
# 4               False                False                 False
# ...               ...                  ...                   ...
# 56667           False                False                 False
# 56668           False                False                 False
# 56669           False                False                 False
# 56670           False                False                 False
# 56671           False                False                 False
#
#         stationery.paper   stationery.stapler
# 0                  False                False
# 1                  False                False
# 2                  False                False
# 3                  False                False
# 4                  False                False
# ...                  ...                  ...
# 56667              False                False
# 56668              False                False
# 56669              False                False
# 56670              False                False
# 56671              False                False
#
# [56672 rows x 123 columns]

# %% [markdown]
# ### 2.2. Compute Frequent Itemsets

# %% [markdown]
# * Compute frequent itemsets considering a minimum support of X%.
# * Present frequent itemsets organized by length (number of items).
# * List frequent 1-itemsets, 2-itemsets, 3-itemsets, etc with support of at least Y%.
# * Change X and Y when it makes sense and discuss the results.

# %% [markdown]
# ### 2.2.1 Buys Week Day

# %%
frequent_itemsets = apriori(buy_weekday_binary_db, min_support=0.1,  use_colnames=True)
frequent_itemsets
# Out:
#     support         itemsets
# 0  0.114855  ( sport.tennis)

# %% [markdown]
# What are the most bought products in the weekdays? The most bought product is sport.tennis , appearing approximatly 11% of all transactions.

# %%
frequent_itemsets = apriori(buy_weekday_binary_db, min_support=0.01, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                       itemsets  length
# 0   0.027237                             ( accessories.bag)       1
# 1   0.024416                  ( appliances.environment.fan)       1
# 2   0.040851               ( appliances.environment.vacuum)       1
# 3   0.013455         ( appliances.environment.water_heater)       1
# 4   0.026094                             ( appliances.iron)       1
# 5   0.064574                  ( appliances.kitchen.blender)       1
# 6   0.043509                    ( appliances.kitchen.grill)       1
# 7   0.045212             ( appliances.kitchen.meat_grinder)       1
# 8   0.016851                ( appliances.kitchen.microwave)       1
# 9   0.022678                    ( appliances.kitchen.mixer)       1
# 10  0.053133                   ( appliances.kitchen.toster)       1
# 11  0.013728                   ( appliances.kitchen.washer)       1
# 12  0.016539                  ( appliances.personal.scales)       1
# 13  0.048579                    ( appliances.steam_cleaner)       1
# 14  0.011025                    ( computers.components.cpu)       1
# 15  0.023505                    ( computers.components.hdd)       1
# 16  0.074420                 ( computers.components.memory)       1
# 17  0.014336           ( computers.components.power_supply)       1
# 18  0.023327             ( computers.components.videocards)       1
# 19  0.010391                            ( computers.ebooks)       1
# 20  0.054801                            ( computers.gaming)       1
# 21  0.040069                          ( computers.notebook)       1
# 22  0.011436                ( computers.peripherals.camera)       1
# 23  0.014980              ( computers.peripherals.joystick)       1
# 24  0.053792               ( computers.peripherals.monitor)       1
# 25  0.019866               ( computers.peripherals.printer)       1
# 26  0.018084               ( computers.peripherals.scanner)       1
# 27  0.028554                    ( construction.tools.drill)       1
# 28  0.011238                    ( construction.tools.screw)       1
# 29  0.019767                  ( construction.tools.welding)       1
# 30  0.064866                     ( country_yard.lawn_mower)       1
# 31  0.014163                      ( electronics.calculator)       1
# 32  0.029797                          ( electronics.clocks)       1
# 33  0.019124                       ( electronics.telephone)       1
# 34  0.031158                        ( electronics.video.tv)       1
# 35  0.018648                                ( kids.bottles)       1
# 36  0.051509                    ( medicine.tools.tonometer)       1
# 37  0.114855                                ( sport.tennis)       1
# 38  0.013401                         ( stationery.cartrige)       1
# 39  0.011535  ( sport.tennis,  computers.components.memory)       2
# 40  0.014376      ( country_yard.lawn_mower,  sport.tennis)       2

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.01) & (frequent_itemsets['length'] == 2)]
frequent_itemsets
# Out:
#      support                                       itemsets  length
# 39  0.011535  ( sport.tennis,  computers.components.memory)       2
# 40  0.014376      ( country_yard.lawn_mower,  sport.tennis)       2

# %% [markdown]
# **Which products are bought together on weekdays?**
#
# According to the obtained results, the following products are bought together on weekdays:
#
# | |  |
# | --- | ---  |
# | sport.tennis |  computers.components.memory  |
# | country_yard.lawn_mower | sport.tennis  |

# %% [markdown]
# ### 2.2.2 Buys Weekend

# %%
frequent_itemsets = apriori(buy_weeknd_binary_db, min_support=0.15,  use_colnames=True)
frequent_itemsets
# Out:
#     support         itemsets
# 0  0.155185  ( sport.tennis)

# %% [markdown]
# What are the most bought products in the weekend? The most bought product is again sport.tennis , appearing approximatly 15% of all transactions.

# %%
frequent_itemsets = apriori(buy_weeknd_binary_db, min_support=0.01, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0   0.022956                                 ( accessories.bag)       1
# 1   0.040913                      ( appliances.environment.fan)       1
# 2   0.058587                   ( appliances.environment.vacuum)       1
# 3   0.011276             ( appliances.environment.water_heater)       1
# 4   0.021178                                 ( appliances.iron)       1
# 5   0.068412                      ( appliances.kitchen.blender)       1
# 6   0.061301                        ( appliances.kitchen.grill)       1
# 7   0.041411                 ( appliances.kitchen.meat_grinder)       1
# 8   0.018876                    ( appliances.kitchen.microwave)       1
# 9   0.026356                        ( appliances.kitchen.mixer)       1
# 10  0.076673                       ( appliances.kitchen.toster)       1
# 11  0.011173                       ( appliances.kitchen.washer)       1
# 12  0.015733                      ( appliances.personal.scales)       1
# 13  0.068584                        ( appliances.steam_cleaner)       1
# 14  0.011104                        ( computers.components.cpu)       1
# 15  0.022509                        ( computers.components.hdd)       1
# 16  0.100204                     ( computers.components.memory)       1
# 17  0.016480               ( computers.components.power_supply)       1
# 18  0.021066                 ( computers.components.videocards)       1
# 19  0.017262                                ( computers.gaming)       1
# 20  0.043867                              ( computers.notebook)       1
# 21  0.013818                  ( computers.peripherals.joystick)       1
# 22  0.063680                   ( computers.peripherals.monitor)       1
# 23  0.018782                   ( computers.peripherals.printer)       1
# 24  0.016497                   ( computers.peripherals.scanner)       1
# 25  0.041257                        ( construction.tools.drill)       1
# 26  0.010692                        ( construction.tools.screw)       1
# 27  0.018241                      ( construction.tools.welding)       1
# 28  0.096683                         ( country_yard.lawn_mower)       1
# 29  0.013672                          ( electronics.calculator)       1
# 30  0.034257                              ( electronics.clocks)       1
# 31  0.021504                           ( electronics.telephone)       1
# 32  0.024622                            ( electronics.video.tv)       1
# 33  0.023591                                    ( kids.bottles)       1
# 34  0.058527                        ( medicine.tools.tonometer)       1
# 35  0.155185                                    ( sport.tennis)       1
# 36  0.011388                             ( stationery.cartrige)       1
# 37  0.017090  ( appliances.environment.fan,  computers.compo...       2
# 38  0.010031  ( appliances.environment.vacuum,  appliances.k...       2
# 39  0.013088  ( appliances.kitchen.blender,  computers.compo...       2
# 40  0.015536  ( country_yard.lawn_mower,  appliances.kitchen...       2
# 41  0.014462  ( appliances.kitchen.toster,  computers.compon...       2
# 42  0.011980  ( appliances.kitchen.toster,  computers.periph...       2
# 43  0.016102        ( sport.tennis,  appliances.kitchen.toster)       2
# 44  0.012315  ( appliances.steam_cleaner,  construction.tool...       2
# 45  0.014909  ( country_yard.lawn_mower,  appliances.steam_c...       2
# 46  0.018593      ( sport.tennis,  computers.components.memory)       2
# 47  0.011413    ( sport.tennis,  computers.peripherals.monitor)       2
# 48  0.027421          ( country_yard.lawn_mower,  sport.tennis)       2

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.01) & (frequent_itemsets['length'] == 2)]
frequent_itemsets.style.set_properties(subset=['itemsets'], **{'width-min': '50px'})
# Out:
# <style  type="text/css" >
# #T_86dd3_row0_col1,#T_86dd3_row1_col1,#T_86dd3_row2_col1,#T_86dd3_row3_col1,#T_86dd3_row4_col1,#T_86dd3_row5_col1,#T_86dd3_row6_col1,#T_86dd3_row7_col1,#T_86dd3_row8_col1,#T_86dd3_row9_col1,#T_86dd3_row10_col1,#T_86dd3_row11_col1{
#             width-min:  50px;
#         }</style><table id="T_86dd3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >support</th>        <th class="col_heading level0 col1" >itemsets</th>        <th class="col_heading level0 col2" >length</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86dd3_level0_row0" class="row_heading level0 row0" >37</th>
#                         <td id="T_86dd3_row0_col0" class="data row0 col0" >0.017090</td>
#                         <td id="T_86dd3_row0_col1" class="data row0 col1" >frozenset({' appliances.environment.fan', ' computers.components.memory'})</td>
#                         <td id="T_86dd3_row0_col2" class="data row0 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row1" class="row_heading level0 row1" >38</th>
#                         <td id="T_86dd3_row1_col0" class="data row1 col0" >0.010031</td>
#                         <td id="T_86dd3_row1_col1" class="data row1 col1" >frozenset({' appliances.environment.vacuum', ' appliances.kitchen.grill'})</td>
#                         <td id="T_86dd3_row1_col2" class="data row1 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row2" class="row_heading level0 row2" >39</th>
#                         <td id="T_86dd3_row2_col0" class="data row2 col0" >0.013088</td>
#                         <td id="T_86dd3_row2_col1" class="data row2 col1" >frozenset({' appliances.kitchen.blender', ' computers.components.memory'})</td>
#                         <td id="T_86dd3_row2_col2" class="data row2 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row3" class="row_heading level0 row3" >40</th>
#                         <td id="T_86dd3_row3_col0" class="data row3 col0" >0.015536</td>
#                         <td id="T_86dd3_row3_col1" class="data row3 col1" >frozenset({' country_yard.lawn_mower', ' appliances.kitchen.grill'})</td>
#                         <td id="T_86dd3_row3_col2" class="data row3 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row4" class="row_heading level0 row4" >41</th>
#                         <td id="T_86dd3_row4_col0" class="data row4 col0" >0.014462</td>
#                         <td id="T_86dd3_row4_col1" class="data row4 col1" >frozenset({' appliances.kitchen.toster', ' computers.components.memory'})</td>
#                         <td id="T_86dd3_row4_col2" class="data row4 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row5" class="row_heading level0 row5" >42</th>
#                         <td id="T_86dd3_row5_col0" class="data row5 col0" >0.011980</td>
#                         <td id="T_86dd3_row5_col1" class="data row5 col1" >frozenset({' appliances.kitchen.toster', ' computers.peripherals.monitor'})</td>
#                         <td id="T_86dd3_row5_col2" class="data row5 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row6" class="row_heading level0 row6" >43</th>
#                         <td id="T_86dd3_row6_col0" class="data row6 col0" >0.016102</td>
#                         <td id="T_86dd3_row6_col1" class="data row6 col1" >frozenset({' sport.tennis', ' appliances.kitchen.toster'})</td>
#                         <td id="T_86dd3_row6_col2" class="data row6 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row7" class="row_heading level0 row7" >44</th>
#                         <td id="T_86dd3_row7_col0" class="data row7 col0" >0.012315</td>
#                         <td id="T_86dd3_row7_col1" class="data row7 col1" >frozenset({' appliances.steam_cleaner', ' construction.tools.drill'})</td>
#                         <td id="T_86dd3_row7_col2" class="data row7 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row8" class="row_heading level0 row8" >45</th>
#                         <td id="T_86dd3_row8_col0" class="data row8 col0" >0.014909</td>
#                         <td id="T_86dd3_row8_col1" class="data row8 col1" >frozenset({' country_yard.lawn_mower', ' appliances.steam_cleaner'})</td>
#                         <td id="T_86dd3_row8_col2" class="data row8 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row9" class="row_heading level0 row9" >46</th>
#                         <td id="T_86dd3_row9_col0" class="data row9 col0" >0.018593</td>
#                         <td id="T_86dd3_row9_col1" class="data row9 col1" >frozenset({' sport.tennis', ' computers.components.memory'})</td>
#                         <td id="T_86dd3_row9_col2" class="data row9 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row10" class="row_heading level0 row10" >47</th>
#                         <td id="T_86dd3_row10_col0" class="data row10 col0" >0.011413</td>
#                         <td id="T_86dd3_row10_col1" class="data row10 col1" >frozenset({' sport.tennis', ' computers.peripherals.monitor'})</td>
#                         <td id="T_86dd3_row10_col2" class="data row10 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_86dd3_level0_row11" class="row_heading level0 row11" >48</th>
#                         <td id="T_86dd3_row11_col0" class="data row11 col0" >0.027421</td>
#                         <td id="T_86dd3_row11_col1" class="data row11 col1" >frozenset({' country_yard.lawn_mower', ' sport.tennis'})</td>
#                         <td id="T_86dd3_row11_col2" class="data row11 col2" >2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 2.2.3 Clicks WeekDay

# %%
frequent_itemsets = apriori(click_weekday_binary_db, min_support=0.2,  use_colnames=True)
frequent_itemsets
# Out:
#     support                     itemsets
# 0  0.200752  ( appliances.steam_cleaner)
# 1  0.203046   ( country_yard.lawn_mower)

# %% [markdown]
# What are the most clicked products in the weekdays? The most clicked product are appliances.steam_cleaner and   country_yard.lawn_mowe , appearing approximatly 20% of all transactions.

# %%
frequent_itemsets = apriori(click_weekday_binary_db, min_support=0.05, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0   0.064565                                 ( accessories.bag)       1
# 1   0.126941                   ( appliances.environment.vacuum)       1
# 2   0.058671                                 ( appliances.iron)       1
# 3   0.051895                      ( appliances.kitchen.blender)       1
# 4   0.173348                        ( appliances.kitchen.grill)       1
# 5   0.053254                 ( appliances.kitchen.meat_grinder)       1
# 6   0.101602                       ( appliances.kitchen.toster)       1
# 7   0.200752                        ( appliances.steam_cleaner)       1
# 8   0.090521                     ( computers.components.memory)       1
# 9   0.074569                              ( computers.notebook)       1
# 10  0.100385                   ( computers.peripherals.monitor)       1
# 11  0.134158                        ( construction.tools.drill)       1
# 12  0.203046                         ( country_yard.lawn_mower)       1
# 13  0.071729                              ( electronics.clocks)       1
# 14  0.052301                            ( electronics.video.tv)       1
# 15  0.087680                                    ( kids.bottles)       1
# 16  0.108696                        ( medicine.tools.tonometer)       1
# 17  0.133540                                    ( sport.tennis)       1
# 18  0.067511  ( country_yard.lawn_mower,  appliances.kitchen...       2
# 19  0.057418  ( appliances.steam_cleaner,  construction.tool...       2
# 20  0.065994  ( country_yard.lawn_mower,  appliances.steam_c...       2

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.05) & (frequent_itemsets['length'] == 2)]
frequent_itemsets.style.set_properties(subset=['itemsets'], **{'width-min': '50px'})
# Out:
# <style  type="text/css" >
# #T_af131_row0_col1,#T_af131_row1_col1,#T_af131_row2_col1{
#             width-min:  50px;
#         }</style><table id="T_af131_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >support</th>        <th class="col_heading level0 col1" >itemsets</th>        <th class="col_heading level0 col2" >length</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_af131_level0_row0" class="row_heading level0 row0" >18</th>
#                         <td id="T_af131_row0_col0" class="data row0 col0" >0.067511</td>
#                         <td id="T_af131_row0_col1" class="data row0 col1" >frozenset({' country_yard.lawn_mower', ' appliances.kitchen.grill'})</td>
#                         <td id="T_af131_row0_col2" class="data row0 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_af131_level0_row1" class="row_heading level0 row1" >19</th>
#                         <td id="T_af131_row1_col0" class="data row1 col0" >0.057418</td>
#                         <td id="T_af131_row1_col1" class="data row1 col1" >frozenset({' appliances.steam_cleaner', ' construction.tools.drill'})</td>
#                         <td id="T_af131_row1_col2" class="data row1 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_af131_level0_row2" class="row_heading level0 row2" >20</th>
#                         <td id="T_af131_row2_col0" class="data row2 col0" >0.065994</td>
#                         <td id="T_af131_row2_col1" class="data row2 col1" >frozenset({' country_yard.lawn_mower', ' appliances.steam_cleaner'})</td>
#                         <td id="T_af131_row2_col2" class="data row2 col2" >2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Which products are clicked together on weekdays?**
#
# According to the obtained results, the following products are clicked together on weekdays:
#
# | |  |
# | --- | ---  |
# |  appliances.kitchen.gril |  computers.components.memory  |
# | construction.tools.drill | appliances.steam_cleaner  |
# | country_yard.lawn_mower | appliances.steam_cleaner  |

# %% [markdown]
# ### 2.2.4 Clicks Weekend

# %%
frequent_itemsets = apriori(click_weeknd_binary_db, min_support=0.08,  use_colnames=True)
frequent_itemsets
# Out:
#     support                     itemsets
# 0  0.080718  ( appliances.steam_cleaner)
# 1  0.081465   ( country_yard.lawn_mower)

# %% [markdown]
# What are the most clicked products in the weekend? The most clicked product are  appliances.steam_cleaner and country_yard.lawn_mower , appearing approximatly 8% of all transactions.

# %%
frequent_itemsets = apriori(click_weeknd_binary_db, min_support=0.01, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0   0.020302                                 ( accessories.bag)       1
# 1   0.010366                      ( appliances.environment.fan)       1
# 2   0.057144                   ( appliances.environment.vacuum)       1
# 3   0.020791                                 ( appliances.iron)       1
# 4   0.016283                      ( appliances.kitchen.blender)       1
# 5   0.068893                        ( appliances.kitchen.grill)       1
# 6   0.017605                 ( appliances.kitchen.meat_grinder)       1
# 7   0.014059                    ( appliances.kitchen.microwave)       1
# 8   0.021341                        ( appliances.kitchen.mixer)       1
# 9   0.040973                       ( appliances.kitchen.toster)       1
# 10  0.080718                        ( appliances.steam_cleaner)       1
# 11  0.016798                        ( computers.components.hdd)       1
# 12  0.032136                     ( computers.components.memory)       1
# 13  0.013260               ( computers.components.power_supply)       1
# 14  0.027593                              ( computers.notebook)       1
# 15  0.035099                   ( computers.peripherals.monitor)       1
# 16  0.010409                   ( computers.peripherals.printer)       1
# 17  0.013552                   ( computers.peripherals.scanner)       1
# 18  0.056526                        ( construction.tools.drill)       1
# 19  0.081465                         ( country_yard.lawn_mower)       1
# 20  0.013320                          ( electronics.calculator)       1
# 21  0.027413                              ( electronics.clocks)       1
# 22  0.016351                            ( electronics.video.tv)       1
# 23  0.010941                       ( furniture.universal.light)       1
# 24  0.032609                                    ( kids.bottles)       1
# 25  0.032694                        ( medicine.tools.tonometer)       1
# 26  0.045671                                    ( sport.tennis)       1
# 27  0.019263  ( appliances.environment.vacuum,  appliances.k...       2
# 28  0.016377  ( appliances.environment.vacuum,  appliances.k...       2
# 29  0.012478  ( appliances.environment.vacuum,  appliances.s...       2
# 30  0.013612  ( country_yard.lawn_mower,  appliances.environ...       2
# 31  0.010555    ( appliances.environment.vacuum,  sport.tennis)       2
# 32  0.015295  ( appliances.kitchen.grill,  appliances.kitche...       2
# 33  0.017691  ( appliances.kitchen.grill,  appliances.steam_...       2
# 34  0.010366  ( appliances.kitchen.grill,  computers.periphe...       2
# 35  0.015321  ( appliances.kitchen.grill,  construction.tool...       2
# 36  0.028761  ( country_yard.lawn_mower,  appliances.kitchen...       2
# 37  0.011345  ( medicine.tools.tonometer,  appliances.kitche...       2
# 38  0.015364         ( appliances.kitchen.grill,  sport.tennis)       2
# 39  0.012186  ( appliances.kitchen.toster,  appliances.steam...       2
# 40  0.010254  ( appliances.kitchen.toster,  computers.compon...       2
# 41  0.012933  ( country_yard.lawn_mower,  appliances.kitchen...       2
# 42  0.025850  ( appliances.steam_cleaner,  construction.tool...       2
# 43  0.029697  ( country_yard.lawn_mower,  appliances.steam_c...       2
# 44  0.010598         ( kids.bottles,  appliances.steam_cleaner)       2
# 45  0.011001  ( medicine.tools.tonometer,  appliances.steam_...       2
# 46  0.012624         ( sport.tennis,  appliances.steam_cleaner)       2
# 47  0.020027  ( country_yard.lawn_mower,  construction.tools...       2
# 48  0.011422  ( country_yard.lawn_mower,  medicine.tools.ton...       2
# 49  0.016351          ( country_yard.lawn_mower,  sport.tennis)       2
# 50  0.010503  ( country_yard.lawn_mower,  appliances.kitchen...       3

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.02) & (frequent_itemsets['length'] == 2)]
frequent_itemsets.style.set_properties(subset=['itemsets'], **{'width-min': '50px'})
# Out:
# <style  type="text/css" >
# #T_e462f_row0_col1,#T_e462f_row1_col1,#T_e462f_row2_col1,#T_e462f_row3_col1{
#             width-min:  50px;
#         }</style><table id="T_e462f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >support</th>        <th class="col_heading level0 col1" >itemsets</th>        <th class="col_heading level0 col2" >length</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e462f_level0_row0" class="row_heading level0 row0" >36</th>
#                         <td id="T_e462f_row0_col0" class="data row0 col0" >0.028761</td>
#                         <td id="T_e462f_row0_col1" class="data row0 col1" >frozenset({' country_yard.lawn_mower', ' appliances.kitchen.grill'})</td>
#                         <td id="T_e462f_row0_col2" class="data row0 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_e462f_level0_row1" class="row_heading level0 row1" >42</th>
#                         <td id="T_e462f_row1_col0" class="data row1 col0" >0.025850</td>
#                         <td id="T_e462f_row1_col1" class="data row1 col1" >frozenset({' appliances.steam_cleaner', ' construction.tools.drill'})</td>
#                         <td id="T_e462f_row1_col2" class="data row1 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_e462f_level0_row2" class="row_heading level0 row2" >43</th>
#                         <td id="T_e462f_row2_col0" class="data row2 col0" >0.029697</td>
#                         <td id="T_e462f_row2_col1" class="data row2 col1" >frozenset({' country_yard.lawn_mower', ' appliances.steam_cleaner'})</td>
#                         <td id="T_e462f_row2_col2" class="data row2 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_e462f_level0_row3" class="row_heading level0 row3" >47</th>
#                         <td id="T_e462f_row3_col0" class="data row3 col0" >0.020027</td>
#                         <td id="T_e462f_row3_col1" class="data row3 col1" >frozenset({' country_yard.lawn_mower', ' construction.tools.drill'})</td>
#                         <td id="T_e462f_row3_col2" class="data row3 col2" >2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Which products are clicked together on weekends?**
#
# According to the obtained results, the following products are clicked together on weeknds:
#
# | |  |
# | --- | ---  |
# |  appliances.kitchen.gril |  country_yard.lawn_mower |
# | construction.tools.drill | appliances.steam_cleaner  |
# | country_yard.lawn_mower | appliances.steam_cleaner  |
# | construction.tools.drill |country_yard.lawn_mower  |

# %% [markdown]
# ### 2.3. Generate Association Rules from Frequent Itemsets

# %% [markdown]
# * Generate association rules with a choosed value (C) for minimum confidence.
# * Generate association rules with a choosed value (L) for minimum lift.
# * Generate association rules with both confidence >= C% and lift >= L.
# * Change C and L when it makes sense and discuss the results.

# %% [markdown]
# ### 2.3.1 Buys Week Day

# %%
frequent_itemsets = apriori(buy_weekday_binary_db, min_support=0.01, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules
# Out:
#                   antecedents      consequents  antecedent support  \
# 0  ( country_yard.lawn_mower)  ( sport.tennis)            0.064866
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.114855  0.014376    0.221629  1.929634  0.006926    1.137175

# %% [markdown]
# * When people buy country_yard.lawn_mower, sport.tennis appears in 22% of the transactions.

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
lift_rules
# Out:
#                       antecedents                     consequents  \
# 0                 ( sport.tennis)  ( computers.components.memory)
# 1  ( computers.components.memory)                 ( sport.tennis)
# 2      ( country_yard.lawn_mower)                 ( sport.tennis)
# 3                 ( sport.tennis)      ( country_yard.lawn_mower)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.114855            0.074420  0.011535    0.100427  1.349458
# 1            0.074420            0.114855  0.011535    0.154992  1.349458
# 2            0.064866            0.114855  0.014376    0.221629  1.929634
# 3            0.114855            0.064866  0.014376    0.125167  1.929634
#
#    leverage  conviction
# 0  0.002987    1.028910
# 1  0.002987    1.047499
# 2  0.006926    1.137175
# 3  0.006926    1.068929

# %% [markdown]
# ### 2.3.2 Buys Weekend

# %%
frequent_itemsets = apriori(buy_weeknd_binary_db, min_support=0.01, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
rules
# Out:
#                      antecedents                     consequents  \
# 0  ( appliances.environment.fan)  ( computers.components.memory)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0            0.040913            0.100204  0.01709    0.417716  4.168642
#
#    leverage  conviction
# 0   0.01299    1.545287

# %% [markdown]
# * When people buy appliances.environment.fan, computers.components.memory appears in 42% of the transactions.

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=3.0)
lift_rules
# Out:
#                       antecedents                     consequents  \
# 0   ( appliances.environment.fan)  ( computers.components.memory)
# 1  ( computers.components.memory)   ( appliances.environment.fan)
# 2     ( appliances.steam_cleaner)     ( construction.tools.drill)
# 3     ( construction.tools.drill)     ( appliances.steam_cleaner)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.040913            0.100204  0.017090    0.417716  4.168642
# 1            0.100204            0.040913  0.017090    0.170552  4.168642
# 2            0.068584            0.041257  0.012315    0.179564  4.352377
# 3            0.041257            0.068584  0.012315    0.298501  4.352377
#
#    leverage  conviction
# 0  0.012990    1.545287
# 1  0.012990    1.156295
# 2  0.009486    1.168578
# 3  0.009486    1.327752

# %% [markdown]
# ### 2.3.3 Clicks WeekDay

# %%
frequent_itemsets = apriori(click_weekday_binary_db, min_support=0.05, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
rules
# Out:
#                    antecedents                  consequents  \
# 0  ( construction.tools.drill)  ( appliances.steam_cleaner)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.134158            0.200752  0.057418    0.427989  2.131932
#
#    leverage  conviction
# 0  0.030486     1.39726

# %% [markdown]
# * When people clicks construction.tools.drill, appliances.steam_cleaner appears in 42% of the transactions.

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
lift_rules
# Out:
#                    antecedents                  consequents  \
# 0   ( country_yard.lawn_mower)  ( appliances.kitchen.grill)
# 1  ( appliances.kitchen.grill)   ( country_yard.lawn_mower)
# 2  ( appliances.steam_cleaner)  ( construction.tools.drill)
# 3  ( construction.tools.drill)  ( appliances.steam_cleaner)
# 4   ( country_yard.lawn_mower)  ( appliances.steam_cleaner)
# 5  ( appliances.steam_cleaner)   ( country_yard.lawn_mower)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.203046            0.173348  0.067511    0.332493  1.918064
# 1            0.173348            0.203046  0.067511    0.389454  1.918064
# 2            0.200752            0.134158  0.057418    0.286016  2.131932
# 3            0.134158            0.200752  0.057418    0.427989  2.131932
# 4            0.203046            0.200752  0.065994    0.325020  1.619013
# 5            0.200752            0.203046  0.065994    0.328733  1.619013
#
#    leverage  conviction
# 0  0.032314    1.238417
# 1  0.032314    1.305315
# 2  0.030486    1.212690
# 3  0.030486    1.397260
# 4  0.025232    1.184106
# 5  0.025232    1.187240

# %% [markdown]
# ### 2.3.4 Clicks Weekend

# %%
frequent_itemsets = apriori(click_weeknd_binary_db, min_support=0.02, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
rules
# Out:
#                    antecedents                  consequents  \
# 0  ( appliances.kitchen.grill)   ( country_yard.lawn_mower)
# 1  ( construction.tools.drill)  ( appliances.steam_cleaner)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.068893            0.081465  0.028761    0.417477  5.124589
# 1            0.056526            0.080718  0.025850    0.457308  5.665479
#
#    leverage  conviction
# 0  0.023149    1.576821
# 1  0.021287    1.693928

# %% [markdown]
# * When people click appliances.kitchen.grill, country_yard.lawn_mower appears in 42% of the transactions.
#
# * When people click construction.tools.drill, appliances.steam_cleaner appears in 45% of the transactions.

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=5.0)
lift_rules
# Out:
#                    antecedents                  consequents  \
# 0   ( country_yard.lawn_mower)  ( appliances.kitchen.grill)
# 1  ( appliances.kitchen.grill)   ( country_yard.lawn_mower)
# 2  ( appliances.steam_cleaner)  ( construction.tools.drill)
# 3  ( construction.tools.drill)  ( appliances.steam_cleaner)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.081465            0.068893  0.028761    0.353047  5.124589
# 1            0.068893            0.081465  0.028761    0.417477  5.124589
# 2            0.080718            0.056526  0.025850    0.320247  5.665479
# 3            0.056526            0.080718  0.025850    0.457308  5.665479
#
#    leverage  conviction
# 0  0.023149    1.439219
# 1  0.023149    1.576821
# 2  0.021287    1.387966
# 3  0.021287    1.693928

# %% [markdown]
# ### 2.4. Conclusions

# %% [markdown]
# #### Buys Week Day
# * From the transactions from store buys we can see that **the most bought** item is
# **sport.tennis** appering in 11% of all transactions.
#
#
# * The items that are bought together are with sport.tennis:
#  * **computers.components.memory,country_yard.lawn_mower**  each pair appering together in 1% of the transactions.
#
#
#
# * When people buy country_yard.lawn_mower, sport.tennis appears in 22% of the transactions.
#
#
# * As for the sports tenis(that appears the most in all transactions )
# what we saw was that:
#  * sport.tennis  computers.components.memory lift:1.349458
#  * sport.tennis country_yard.lawn_mower lift: 1.929634
#
# Like said before with a lift > 1  that means that the consequent product is likely to be bought if the antecedent product is bought

# %% [markdown]
# #### Buys Weekend
# * From the transactions from store buys we can see that **the most bought** item is
# **sport.tennis** appering in 15% of all transactions.
#  * the same most bought item is sport.tennis, in the week appears in 11% vs 15%. If it is week or weekend **sport.tennis** is always the most bought item, but it is slitly more bought in the weekend than weekdays
#
#
# * The items that are bought together are with sport.tennis:
#  * **computers.components.memory,country_yard.lawn_mower**  each pair appering together in 3% of the transactions. (in the weekday this pair appears in 1%)
#
#
#
# * When people buy appliances.environment.fan, computers.components.memory appears in 42% of the transactions.
#
#
# * As for the lift we saw many items with a lift greater than 1 (Like said before with a lift > 1  that means that the consequent product is likely to be bought if the antecedent product is bought). The items bought a lift greater than 4 are:
#  * **appliances.environment.fan computers.components.memory**
#  * **construction.tools.drill appliances.steam_cleaner**

# %% [markdown]
# #### Clicks Week Day
# * From the transactions from store clicks we can see that **the most clicked** item are
# **appliances.steam_cleaner and country_yard.lawn_mower** appering in 20% of all transactions.
#
#
# * The items that are clicked together are :
#  * **appliances.kitchen.gril	,computers.components.memory** appering together in 7% of the transactions.
#  * **construction.tools.drillappliances	,appliances.steam_cleaner** appering together in 6% of the transactions.
#  * **country_yard.lawn_mower	,appliances.steam_cleaner** appering together in 7% of the transactions.
#
#
# * When people click construction.tools.drill, appliances.steam_cleaner appears in 42% of the transactions.
#
# * The transaction clicked with the biggest lift is:
#  *  construction.tools.drill  appliances.steam_cleaner lift:2.131932 (Like said before with a lift > 1  that means that the consequent product is likely to be bought if the antecedent product is bought)

# %% [markdown]
# #### Clicks Weekend
# * From the transactions from store clicks we can see that **the most clicked** item are
# **appliances.steam_cleaner and country_yard.lawn_mower** appering in 8% of all transactions.
#  * This two items are the same most clicked in the weekdays. But on the weekday they appear in 20% of the sessions and in the weekends they appear in only 8%
#
# * The items that are clicked together are :
#  * **construction.tools.drillappliances	,appliances.steam_cleaner** appering together in 3% of the transactions.(in the weekday this pair appears in 6%)
#  * **country_yard.lawn_mower	,appliances.steam_cleaner** appering together in 3% of the transactions.(in the weekday this pair appears in 7%)
#
#
#
#
#
# * When people click appliances.kitchen.grill, country_yard.lawn_mower appears in 42% of the transactions.
# * When people click construction.tools.drill, appliances.steam_cleaner appears in 45% of the transactions.
#
# * As for the lift we saw many items with a lift greater than 1 (Like said before with a lift > 1  that means that the consequent product is likely to be bought if the antecedent product is bought). The items bought a lift greater than 5 are:
#  * **appliances.kitchen.grill country_yard.lawn_mower**
#  * **construction.tools.drill appliances.steam_cleaner**

# %% [markdown]
# # 3. [Only Groups of 3] Spring vs Summer Purchases

# %% [markdown]
# In this part of the project you should analyse the consumption patterns during the Spring months (April and May) vs Summer months (June and July).
#
# **In what follows keep the following question in mind and be creative!**
#
# 1. The most interesting products are the same during the Spring and the Summer?
# 2. What are the most bought products during the Spring? And during the Summer?
# 3. There are differences between the sets of products bought during the Spring and the Summer?
# 4. Can you find different associations highliting that when people click in a product/set of products also buy this product(s) during the Spring vs the Summer?
# 5. Discuss the results obtained for the Spring sessions vs Summer sessions.

# %% [markdown]
# ### 3.1. Load and Preprocess Data
#
#  **Product quantities should not be considered.**

# %% [markdown]
# ### 3.1.1Store Buys df
#
# We have to separate this df into 2 different df one with summer months and the other with Spring months

# %%
masterdf.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories  Timestamp     Semana
# 0     2859734  214536500   electronics.tablet 2014-05-14  Wednesday
# 1     4276371  214536500   electronics.tablet 2014-06-04  Wednesday
# 2     4440056  214536500   electronics.tablet 2014-06-14   Saturday
# 3       70532  214536506   electronics.tablet 2014-04-06     Sunday
# 4      691119  214536506   electronics.tablet 2014-04-14     Monday

# %%
time = masterdf["Timestamp"].astype(str).str.split("-", n = 2, expand = True)
masterdf["Timestamp"] = time[1]
masterdf.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories Timestamp     Semana
# 0     2859734  214536500   electronics.tablet        05  Wednesday
# 1     4276371  214536500   electronics.tablet        06  Wednesday
# 2     4440056  214536500   electronics.tablet        06   Saturday
# 3       70532  214536506   electronics.tablet        04     Sunday
# 4      691119  214536506   electronics.tablet        04     Monday

# %%
teste = masterdf
teste = teste.drop("Semana",axis=1)
buys_spring_df =  teste.loc[teste['Timestamp'].isin(['04', '05'])] 
buys_summer_df = teste.loc[teste['Timestamp'].isin(['06', '07'])]

# %% [markdown]
# ### 3.1.2 Buys Spring

# %%
buys_spring_df.head(10)
# Out:
#     Session_ID    Item_ID        Product_Categories Timestamp
# 0      2859734  214536500        electronics.tablet        05
# 3        70532  214536506        electronics.tablet        04
# 4       691119  214536506        electronics.tablet        04
# 5       405567  214662742   furniture.kitchen.table        04
# 6       763567  214662742   furniture.kitchen.table        04
# 7       842649  214662742   furniture.kitchen.table        04
# 8       573948  214662742   furniture.kitchen.table        04
# 9       877203  214662742   furniture.kitchen.table        04
# 10      655821  214662742   furniture.kitchen.table        04
# 11     1002166  214662742   furniture.kitchen.table        04

# %%
buy_spring_transactions= []

for i in list(buys_spring_df.Session_ID.unique()):
    buy_spring_transactions.append(buys_spring_df[buys_spring_df.Session_ID==i].Product_Categories.values.tolist())
    
buy_spring_transactions
# Out:
# [[' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' furniture.living_room.cabinet'],
#  [' furniture.kitchen.table', ' computers.components.memory'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv'],
#  [' furniture.kitchen.table', ' electronics.audio.dictaphone'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table', ' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' electronics.smartphone', ' computers.components.memory'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.iron',
#   ' appliances.environment.water_heater',
#   ' construction.tools.heater'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' computers.peripherals.scanner'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' computers.notebook'],
#  [' appliances.kitchen.refrigerators', ' appliances.sewing_machine'],
#  [' appliances.kitchen.refrigerators', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.motherboard'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.water_heater'],
#  [' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.peripherals.camera',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.camera'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.living_room.cabinet',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.hood',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' country_yard.cultivator',
#   ' apparel.trousers'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.environment.air_heater'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.components.memory'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' furniture.living_room.shelving',
#   ' appliances.kitchen.blender'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' stationery.cartrige'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.peripherals.mouse'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' auto.accessories.player'],
#  [' electronics.video.tv', ' electronics.video.tv', ' accessories.bag'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' accessories.bag', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.mixer', ' electronics.tablet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.components.memory'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.telephone'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' computers.desktop',
#   ' computers.peripherals.mouse',
#   ' construction.tools.saw'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.steam_cooker'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.clocks', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' furniture.living_room.cabinet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.microwave'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' auto.accessories.videoregister'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' furniture.living_room.shelving'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.cartrige',
#   ' computers.components.cpu'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.paper',
#   ' sport.tennis',
#   ' appliances.environment.fan'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.kitchen.table',
#   ' computers.components.videocards'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' apparel.costume',
#   ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.bedroom.blanket',
#   ' furniture.bedroom.blanket',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' electronics.telephone',
#   ' appliances.iron'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' sport.bicycle',
#   ' construction.tools.generator'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.printer'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.mouse'],
#  [' computers.components.cpu',
#   ' computers.notebook',
#   ' apparel.sock',
#   ' furniture.living_room.sofa'],
#  [' computers.components.cpu',
#   ' appliances.environment.water_heater',
#   ' computers.peripherals.scanner'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.kitchen.microwave'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.cpu', ' medicine.tools.tonometer'],
#  [' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.notebook', ' sport.ski'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' apparel.trousers'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' auto.accessories.videoregister',
#   ' furniture.living_room.shelving',
#   ' electronics.video.projector',
#   ' apparel.trousers'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook', ' furniture.bedroom.blanket'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' apparel.trousers',
#   ' apparel.trousers',
#   ' country_yard.watering',
#   ' country_yard.watering'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.audio.microphone',
#   ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' accessories.bag',
#   ' sport.bicycle',
#   ' accessories.bag'],
#  [' computers.notebook',
#   ' computers.peripherals.printer',
#   ' computers.components.motherboard',
#   ' electronics.telephone'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.peripherals.camera'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' construction.tools.screw'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook', ' appliances.environment.fan'],
#  [' computers.notebook', ' appliances.environment.water_heater'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.telephone',
#   ' computers.components.memory',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' apparel.costume'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.hdd',
#   ' computers.peripherals.printer'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.components.memory', ' sport.tennis'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' apparel.tshirt', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' apparel.shirt'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook', ' apparel.shirt'],
#  [' computers.notebook', ' electronics.camera.video'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.gaming',
#   ' apparel.sock',
#   ' electronics.clocks'],
#  [' computers.notebook', ' computers.peripherals.scanner', ' apparel.costume'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.notebook',
#   ' furniture.living_room.chair',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.headphone',
#   ' apparel.glove',
#   ' construction.tools.heater',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster'],
#  [' computers.notebook', ' electronics.video.tv'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.monitor',
#   ' appliances.iron',
#   ' appliances.kitchen.kettle'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' stationery.cartrige'],
#  [' computers.peripherals.monitor', ' stationery.battery'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' appliances.kitchen.toster'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.printer'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' accessories.bag'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' stationery.cartrige',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' furniture.bedroom.pillow'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.ironing_board',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' appliances.iron'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' sport.tennis',
#   ' appliances.environment.climate'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.video.tv',
#   ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' furniture.bedroom.pillow',
#   ' construction.tools.screw'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' auto.accessories.videoregister'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' stationery.battery'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.watering',
#   ' appliances.environment.vacuum',
#   ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' apparel.trousers'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.tablet'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' appliances.iron',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.air_conditioner',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.screw',
#   ' appliances.environment.fan',
#   ' construction.tools.screw',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.fan'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.ebooks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.videocards',
#   ' accessories.bag'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' furniture.kitchen.table'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' electronics.clocks',
#   ' computers.components.hdd'],
#  [' computers.components.memory', ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.ebooks',
#   ' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' appliances.environment.climate',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' electronics.camera.video',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' appliances.environment.climate'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.ebooks',
#   ' accessories.umbrella'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_grinder',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.printer'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.camera.photo'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory', ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.air_conditioner',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' auto.accessories.compressor'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' appliances.environment.climate'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' accessories.umbrella'],
#  [' computers.components.memory', ' electronics.audio.headphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards'],
#  [' computers.components.memory', ' appliances.iron', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow'],
#  [' computers.components.memory', ' computers.components.videocards'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.telephone',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.peripherals.camera',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' apparel.sock',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.dishwasher'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.ebooks',
#   ' computers.ebooks'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' computers.notebook',
#   ' medicine.tools.tonometer',
#   ' computers.desktop'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.peripherals.joystick'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' construction.tools.welding',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.juicer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' construction.tools.screw',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.microwave',
#   ' auto.accessories.alarm'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.welding',
#   ' computers.components.memory',
#   ' construction.tools.generator',
#   ' apparel.trousers',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' computers.ebooks',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.ebooks',
#   ' appliances.kitchen.blender',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' electronics.audio.subwoofer',
#   ' auto.accessories.radar'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.environment.fan'],
#  [' computers.components.memory', ' stationery.cartrige'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.telephone'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' auto.accessories.player',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' appliances.environment.fan'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' stationery.battery'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.headphone',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' computers.components.memory',
#   ' furniture.universal.light',
#   ' appliances.environment.fan',
#   ' computers.notebook',
#   ' construction.tools.drill',
#   ' construction.tools.welding',
#   ' computers.components.memory',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.memory', ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' construction.tools.heater'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' apparel.tshirt',
#   ' sport.tennis'],
#  [' computers.components.memory', ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.cultivator'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.scanner',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' computers.network.router'],
#  [' computers.components.memory',
#   ' apparel.tshirt',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.stapler',
#   ' computers.network.router',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.telephone',
#   ' sport.tennis',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.universal.light'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' auto.accessories.player',
#   ' construction.tools.welding'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory', ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' stationery.cartrige',
#   ' electronics.telephone',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' sport.tennis'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' computers.ebooks'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.ebooks',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' furniture.living_room.sofa',
#   ' sport.tennis'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' computers.components.cpu'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
# ...
#   ' construction.tools.generator',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.calculator',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' kids.toys',
#   ' electronics.video.tv',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.living_room.shelving',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' electronics.video.tv',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' computers.notebook',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.grill',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.steam_cooker',
#   ' electronics.video.tv',
#   ' furniture.kitchen.table',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' computers.ebooks'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.notebook'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' electronics.video.tv'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' furniture.bedroom.pillow'],
#  [' computers.components.memory', ' sport.tennis', ' appliances.iron'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.hdd',
#   ' computers.components.memory',
#   ' auto.accessories.compressor',
#   ' apparel.glove',
#   ' apparel.glove',
#   ' stationery.battery'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' electronics.calculator'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.living_room.shelving'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' electronics.smartphone'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' country_yard.watering'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.power_supply'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' country_yard.cultivator'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.air_conditioner',
#   ' appliances.environment.air_conditioner'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.audio.subwoofer',
#   ' electronics.audio.subwoofer',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' furniture.living_room.cabinet'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' stationery.cartrige',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.printer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' country_yard.weather_station'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.iron'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' construction.tools.screw',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.hdd',
#   ' computers.components.memory',
#   ' sport.ski'],
#  [' computers.components.memory',
#   ' construction.tools.welding',
#   ' computers.ebooks',
#   ' appliances.kitchen.mixer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  ...]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(buy_spring_transactions).transform(buy_spring_transactions)
buy_spring_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
buy_spring_binary_db
# Out:
#          accessories.bag   accessories.umbrella   apparel.costume  \
# 0                  False                  False             False
# 1                  False                  False             False
# 2                  False                  False             False
# 3                  False                  False             False
# 4                  False                  False             False
# ...                  ...                    ...               ...
# 179586             False                  False             False
# 179587             False                  False             False
# 179588             False                  False             False
# 179589             False                  False             False
# 179590             False                  False             False
#
#          apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0                False           False           False          False
# 1                False           False           False          False
# 2                False           False           False          False
# 3                False           False           False          False
# 4                False           False           False          False
# ...                ...             ...             ...            ...
# 179586           False           False           False          False
# 179587           False           False           False          False
# 179588           False           False           False          False
# 179589           False           False           False          False
# 179590           False           False           False          False
#
#          apparel.trousers   apparel.tshirt  \
# 0                   False            False
# 1                   False            False
# 2                   False            False
# 3                   False            False
# 4                   False            False
# ...                   ...              ...
# 179586              False            False
# 179587              False            False
# 179588              False            False
# 179589              False            False
# 179590              False            False
#
#          appliances.environment.air_conditioner  ...   sport.bicycle  \
# 0                                         False  ...           False
# 1                                         False  ...           False
# 2                                         False  ...           False
# 3                                         False  ...           False
# 4                                         False  ...           False
# ...                                         ...  ...             ...
# 179586                                    False  ...           False
# 179587                                    False  ...           False
# 179588                                    False  ...           False
# 179589                                    False  ...           False
# 179590                                    False  ...           False
#
#          sport.diving   sport.ski   sport.snowboard   sport.tennis  \
# 0               False       False             False          False
# 1               False       False             False          False
# 2               False       False             False          False
# 3               False       False             False          False
# 4               False       False             False          False
# ...               ...         ...               ...            ...
# 179586          False       False             False          False
# 179587          False       False             False           True
# 179588          False       False             False          False
# 179589          False       False             False          False
# 179590          False       False             False          False
#
#          sport.trainer   stationery.battery   stationery.cartrige  \
# 0                False                False                 False
# 1                False                False                 False
# 2                False                False                 False
# 3                False                False                 False
# 4                False                False                 False
# ...                ...                  ...                   ...
# 179586           False                False                 False
# 179587           False                False                 False
# 179588           False                False                 False
# 179589           False                False                 False
# 179590           False                False                 False
#
#          stationery.paper   stationery.stapler
# 0                   False                False
# 1                   False                False
# 2                   False                False
# 3                   False                False
# 4                   False                False
# ...                   ...                  ...
# 179586              False                False
# 179587              False                False
# 179588              False                False
# 179589              False                False
# 179590              False                False
#
# [179591 rows x 123 columns]

# %% [markdown]
# ### 3.1.2 Buys Summer

# %%
buys_summer_df.head(10)
# Out:
#     Session_ID    Item_ID                 Product_Categories Timestamp
# 1      4276371  214536500                 electronics.tablet        06
# 2      4440056  214536500                 electronics.tablet        06
# 16     6355708  214662742            furniture.kitchen.table        07
# 25     3770444  214757390   appliances.kitchen.refrigerators        06
# 26     4040279  214757390   appliances.kitchen.refrigerators        06
# 27     4343874  214757390   appliances.kitchen.refrigerators        06
# 28     4468136  214757390   appliances.kitchen.refrigerators        06
# 78     3703813  214551617         appliances.personal.scales        06
# 79     4212793  214551617         appliances.personal.scales        06
# 80     4212793  214551617         appliances.personal.scales        06

# %%
buy_summer_transactions= []

for i in list(buys_summer_df.Session_ID.unique()):
    buy_summer_transactions.append(buys_summer_df[buys_summer_df.Session_ID==i].Product_Categories.values.tolist())
    
buy_summer_transactions
# Out:
# [[' electronics.tablet', ' computers.peripherals.monitor'],
#  [' electronics.tablet', ' sport.tennis'],
#  [' furniture.kitchen.table',
#   ' computers.components.videocards',
#   ' furniture.kitchen.table',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators', ' medicine.tools.tonometer'],
#  [' appliances.kitchen.refrigerators', ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators',
#   ' construction.tools.screw',
#   ' furniture.kitchen.table',
#   ' stationery.stapler',
#   ' appliances.kitchen.coffee_machine',
#   ' apparel.trousers',
#   ' construction.tools.heater',
#   ' construction.tools.saw',
#   ' construction.tools.heater',
#   ' computers.components.cpu',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.hdd',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' construction.tools.heater'],
#  [' appliances.personal.scales', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' apparel.shoes', ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.toster'],
#  [' computers.components.cpu', ' computers.peripherals.monitor'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' construction.tools.welding',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.notebook', ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.power_supply'],
#  [' computers.components.cpu',
#   ' appliances.environment.climate',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' electronics.tablet',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.dishwasher',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' kids.toys'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.peripherals.camera',
#   ' electronics.tablet',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.steam_cleaner'],
#  [' computers.components.cpu', ' appliances.kitchen.toster', ' sport.tennis'],
#  [' computers.components.cpu', ' accessories.bag', ' sport.tennis'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.components.cooler'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.peripherals.monitor'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' electronics.video.tv'],
#  [' appliances.kitchen.kettle',
#   ' electronics.camera.photo',
#   ' computers.peripherals.mouse',
#   ' sport.ski',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' appliances.kitchen.washer'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' furniture.kitchen.chair',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.personal.hair_cutter',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' construction.tools.welding',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' furniture.living_room.sofa',
#   ' sport.tennis',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.blender',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.juicer',
#   ' appliances.environment.air_conditioner',
#   ' electronics.telephone',
#   ' computers.desktop',
#   ' electronics.camera.video',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' furniture.bedroom.pillow',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' kids.toys',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' construction.tools.screw',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' appliances.personal.massager',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' computers.notebook',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.environment.climate',
#   ' computers.components.videocards',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks'],
#  [' computers.components.memory', ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' construction.tools.welding',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower',
#   ' country_yard.cultivator'],
#  [' computers.components.memory', ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.washer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.fan',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' furniture.bedroom.pillow'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory', ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory', ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' kids.bottles',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' stationery.battery',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' furniture.living_room.shelving',
#   ' electronics.calculator',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' apparel.tshirt',
#   ' appliances.kitchen.hood',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' electronics.video.tv',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' sport.tennis', ' electronics.clocks'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.printer'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.environment.water_heater',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' auto.accessories.anti_freeze',
#   ' electronics.calculator',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' sport.snowboard',
#   ' sport.snowboard',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' construction.tools.drill'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' appliances.personal.massager',
#   ' electronics.video.tv',
#   ' construction.tools.heater',
#   ' electronics.calculator',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' construction.tools.welding',
#   ' electronics.smartphone',
#   ' apparel.shirt',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.notebook',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' computers.components.power_supply',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory', ' computers.peripherals.printer'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' furniture.living_room.chair',
#   ' construction.tools.welding',
#   ' appliances.environment.fan'],
#  [' computers.components.memory', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.mixer',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' electronics.calculator'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' furniture.living_room.chair'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' appliances.iron',
#   ' electronics.tablet',
#   ' computers.peripherals.mouse',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.power_supply',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.personal.hair_cutter',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' construction.tools.screw',
#   ' apparel.shoes',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' computers.peripherals.printer',
#   ' construction.tools.drill',
#   ' electronics.clocks'],
#  [' computers.components.memory', ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' computers.notebook'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.camera',
#   ' apparel.sock',
#   ' computers.notebook',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' construction.tools.pump',
#   ' construction.tools.pump'],
#  [' computers.components.memory',
#   ' appliances.personal.scales',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.mixer',
#   ' kids.toys',
#   ' stationery.stapler',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.monitor'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' electronics.smartphone',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' computers.peripherals.mouse',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' sport.tennis'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' appliances.environment.vacuum'],
#  [' computers.components.memory', ' appliances.iron'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory', ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' construction.tools.screw',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' electronics.smartphone',
#   ' electronics.smartphone',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' electronics.tablet',
#   ' furniture.universal.light',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.components.power_supply',
#   ' appliances.iron',
#   ' computers.components.power_supply',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.peripherals.printer',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' computers.notebook',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' stationery.paper',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' accessories.bag',
#   ' kids.skates',
#   ' kids.bottles',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' country_yard.weather_station',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.environment.water_heater',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' computers.peripherals.printer'],
#  [' computers.components.memory',
#   ' furniture.universal.light',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.environment.water_heater',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory', ' kids.bottles'],
#  [' computers.components.memory',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.ironing_board',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.scanner',
#   ' kids.toys',
#   ' sport.diving',
#   ' electronics.calculator',
#   ' computers.peripherals.monitor',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' appliances.personal.massager',
#   ' computers.notebook',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' appliances.ironing_board',
#   ' stationery.paper',
#   ' stationery.paper',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' kids.toys',
#   ' electronics.calculator',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' computers.notebook',
#   ' appliances.kitchen.toster',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' kids.bottles',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' kids.bottles',
#   ' kids.bottles'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' kids.bottles'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' sport.snowboard',
#   ' computers.peripherals.monitor',
#   ' kids.bottles'],
#  [' computers.components.memory', ' computers.desktop'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory', ' construction.tools.drill'],
#  [' computers.components.memory', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' kids.bottles'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' kids.bottles'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.iron',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' electronics.telephone',
#   ' accessories.bag',
#   ' appliances.personal.hair_cutter',
#   ' electronics.audio.subwoofer',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' country_yard.weather_station',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.components.cdrw',
#   ' sport.tennis',
#   ' kids.bottles'],
#  [' computers.components.memory',
#   ' kids.bottles',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' country_yard.weather_station', ' appliances.kitchen.fryer'],
#  [' country_yard.weather_station',
#   ' computers.network.router',
#   ' sport.tennis'],
#  [' country_yard.weather_station', ' computers.components.memory'],
#  [' appliances.kitchen.blender'],
#  [' appliances.kitchen.blender', ' computers.components.hdd'],
#  [' appliances.kitchen.blender'],
#  [' appliances.kitchen.blender', ' appliances.iron'],
#  [' appliances.kitchen.blender', ' accessories.umbrella'],
#  [' appliances.kitchen.blender', ' kids.toys'],
#  [' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' appliances.kitchen.blender',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.blender',
#   ' construction.tools.drill',
#   ' electronics.smartphone'],
#  [' appliances.kitchen.blender'],
#  [' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.videocards',
#   ' appliances.steam_cleaner'],
#  [' appliances.kitchen.blender',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.blender',
#   ' appliances.kitchen.fryer',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.blender', ' electronics.video.tv'],
#  [' appliances.kitchen.blender',
#   ' computers.peripherals.scanner',
#   ' auto.accessories.compressor',
#   ' computers.components.cdrw',
#   ' computers.notebook',
#   ' apparel.shirt',
#   ' apparel.glove',
#   ' country_yard.lawn_mower',
#   ' appliances.environment.vacuum',
#   ' furniture.universal.light',
#   ' furniture.universal.light'],
#  [' accessories.bag',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.microphone',
#   ' computers.components.cpu',
#   ' apparel.sock'],
#  [' accessories.bag', ' furniture.living_room.sofa'],
#  [' accessories.bag',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill'],
#  [' accessories.bag', ' electronics.video.tv', ' construction.tools.screw'],
#  [' accessories.bag'],
#  [' accessories.bag',
#   ' appliances.kitchen.fryer',
#   ' construction.tools.heater'],
#  [' accessories.bag',
#   ' computers.components.cooler',
#   ' computers.peripherals.monitor'],
#  [' accessories.bag',
#   ' construction.tools.heater',
#   ' computers.network.router',
#   ' electronics.telephone',
#   ' accessories.bag',
#   ' construction.tools.welding',
#   ' sport.bicycle',
#   ' electronics.clocks'],
#  [' accessories.bag',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.dishwasher'],
#  [' accessories.bag'],
#  [' accessories.bag', ' appliances.environment.water_heater'],
#  [' accessories.bag', ' construction.tools.heater'],
#  [' accessories.bag', ' appliances.iron', ' computers.peripherals.monitor'],
#  [' computers.peripherals.keyboard',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.grill'],
#  [' computers.peripherals.keyboard',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill'],
#  [' computers.peripherals.keyboard',
#   ' sport.diving',
#   ' electronics.telephone',
#   ' sport.tennis',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower'],
#  [' computers.peripherals.keyboard',
#   ' appliances.iron',
#   ' furniture.living_room.chair',
#   ' electronics.calculator',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.peripherals.keyboard'],
#  [' computers.peripherals.printer', ' appliances.iron'],
#  [' computers.peripherals.printer',
#   ' appliances.iron',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.monitor'],
#  [' accessories.bag',
#   ' appliances.kitchen.juicer',
#   ' computers.ebooks',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' accessories.bag', ' construction.tools.light'],
#  [' accessories.bag'],
#  [' accessories.bag',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.coffee_grinder',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.power_supply',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.toster',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' accessories.bag', ' appliances.kitchen.toster'],
#  [' accessories.bag',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.environment.fan',
#   ' appliances.environment.vacuum',
#   ' appliances.steam_cleaner'],
#  [' computers.peripherals.mouse'],
#  [' computers.peripherals.mouse', ' computers.desktop'],
#  [' computers.peripherals.mouse',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer'],
#  [' computers.peripherals.mouse',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.telephone',
#   ' computers.notebook'],
#  [' computers.peripherals.mouse',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.monitor',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' computers.components.memory'],
#  [' computers.peripherals.mouse',
#   ' electronics.calculator',
#   ' computers.components.power_supply'],
#  [' computers.peripherals.mouse',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill'],
#  [' computers.peripherals.mouse', ' computers.peripherals.monitor'],
#  [' computers.peripherals.mouse',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' computers.peripherals.mouse'],
#  [' computers.peripherals.mouse',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' computers.peripherals.mouse',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.peripherals.mouse',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.grill'],
#  [' computers.peripherals.mouse',
#   ' electronics.calculator',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster'],
#  [' computers.peripherals.mouse',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' construction.tools.drill',
#   ' country_yard.lawn_mower'],
#  [' computers.peripherals.mouse',
#   ' country_yard.cultivator',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.steam_cleaner'],
#  [' computers.peripherals.mouse', ' appliances.kitchen.toster'],
#  [' computers.peripherals.mouse',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill'],
#  [' computers.peripherals.mouse'],
#  [' computers.peripherals.mouse',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.steam_cleaner',
#   ' kids.bottles',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' kids.bottles'],
#  [' computers.peripherals.mouse', ' appliances.kitchen.toster'],
#  [' computers.peripherals.mouse',
#   ' auto.accessories.radar',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' computers.peripherals.mouse',
#   ' appliances.environment.climate',
#   ' kids.toys',
#   ' medicine.tools.tonometer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' construction.tools.welding',
#   ' computers.components.power_supply',
#   ' sport.tennis'],
#  [' computers.components.memory', ' sport.tennis', ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower'],
#  [' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' appliances.iron', ' computers.desktop'],
#  [' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.mixer',
#   ' computers.components.power_supply',
#   ' computers.components.memory',
#   ' appliances.environment.fan',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' electronics.clocks'],
#  [' appliances.iron', ' sport.tennis', ' computers.peripherals.monitor'],
#  [' appliances.iron', ' sport.tennis', ' medicine.tools.tonometer'],
#  [' appliances.iron'],
#  [' appliances.iron',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' medicine.tools.tonometer'],
#  [' appliances.iron',
#   ' appliances.environment.fan',
#   ' medicine.tools.tonometer'],
#  [' appliances.iron'],
#  [' appliances.iron', ' appliances.iron'],
#  [' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.mixer',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' appliances.iron'],
#  [' appliances.iron', ' medicine.tools.tonometer'],
#  [' appliances.iron', ' appliances.environment.vacuum'],
#  [' appliances.iron',
#   ' auto.accessories.player',
#   ' computers.components.power_supply',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.microwave',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill'],
#  [' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' kids.bottles'],
#  [' appliances.iron',
#   ' appliances.iron',
#   ' computers.peripherals.keyboard',
#   ' furniture.living_room.shelving',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.grill'],
#  [' appliances.iron',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster'],
#  [' appliances.iron',
#   ' computers.components.videocards',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower'],
#  [' appliances.iron', ' appliances.kitchen.grill'],
#  [' appliances.iron', ' appliances.iron', ' construction.tools.drill'],
#  [' appliances.iron', ' sport.tennis'],
#  [' accessories.bag',
#   ' accessories.bag',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.components.videocards',
#   ' computers.components.videocards'],
#  [' accessories.bag'],
#  [' accessories.bag'],
#  [' accessories.bag', ' appliances.environment.water_heater'],
#  [' accessories.bag', ' electronics.clocks', ' computers.notebook'],
#  [' accessories.bag', ' appliances.steam_cleaner'],
#  [' accessories.bag'],
#  [' accessories.bag',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks'],
#  [' accessories.bag', ' appliances.kitchen.grill'],
#  [' accessories.bag', ' computers.components.memory'],
#  [' accessories.bag',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum'],
#  [' accessories.bag'],
#  [' accessories.bag', ' accessories.bag', ' stationery.stapler'],
#  [' accessories.bag'],
#  [' accessories.bag', ' construction.tools.heater'],
#  [' accessories.bag'],
#  [' accessories.bag',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' accessories.bag'],
#  [' accessories.bag'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' appliances.kitchen.mixer', ' computers.peripherals.printer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' electronics.video.tv'],
#  [' appliances.kitchen.mixer', ' auto.accessories.videoregister'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' electronics.audio.microphone'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.toster'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' sport.diving',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' apparel.sock'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' auto.accessories.videoregister'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' auto.accessories.videoregister'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' electronics.smartphone',
#   ' construction.tools.welding',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' appliances.kitchen.toster'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.washer'],
#  [' appliances.kitchen.mixer',
#   ' auto.accessories.videoregister',
#   ' computers.components.power_supply',
#   ' computers.peripherals.monitor'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' computers.components.cooler'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' sport.tennis', ' sport.tennis'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' auto.accessories.videoregister'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' electronics.clocks'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' computers.components.power_supply'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' auto.accessories.player'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.environment.vacuum'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
# ...
#  [' appliances.kitchen.mixer', ' computers.ebooks'],
#  [' appliances.kitchen.mixer', ' computers.components.memory'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.ironing_board'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' furniture.living_room.sofa'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.subwoofer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' sport.tennis'],
#  [' appliances.kitchen.mixer', ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer', ' construction.tools.heater'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' auto.accessories.videoregister'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' stationery.battery'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.components.motherboard',
#   ' computers.components.motherboard',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.printer',
#   ' computers.components.hdd',
#   ' computers.components.hdd',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.printer',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer',
#   ' computers.peripherals.camera',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer', ' electronics.telephone'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' electronics.telephone', ' kids.fmcg.diapers'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.blender'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.grill'],
#  [' appliances.kitchen.mixer', ' computers.components.memory'],
#  [' appliances.kitchen.mixer',
#   ' auto.accessories.compressor',
#   ' appliances.environment.water_heater',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.peripherals.printer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet'],
#  [' appliances.kitchen.mixer',
#   ' computers.components.memory',
#   ' appliances.environment.fan'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' computers.notebook'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.environment.vacuum'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.blender'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.steam_cleaner'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' kids.fmcg.diapers'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.sewing_machine'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.environment.climate'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.generator',
#   ' construction.tools.generator'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' kids.bottles',
#   ' furniture.bedroom.blanket',
#   ' appliances.kitchen.grill'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' kids.bottles'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' electronics.audio.headphone'],
#  [' electronics.audio.headphone',
#   ' electronics.audio.headphone',
#   ' kids.toys',
#   ' kids.toys',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' electronics.audio.headphone'],
#  [' electronics.audio.headphone'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' construction.tools.screw'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' country_yard.watering'],
#  [' computers.components.memory', ' furniture.living_room.shelving'],
#  [' computers.components.memory'],
#  [' computers.components.memory', ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.bedroom.pillow',
#   ' furniture.bedroom.bed',
#   ' medicine.tools.tonometer'],
#  [' computers.components.memory', ' computers.peripherals.printer'],
#  [' computers.components.memory', ' appliances.kitchen.blender'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' furniture.kitchen.chair',
#   ' furniture.kitchen.chair',
#   ' sport.tennis'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' appliances.kitchen.meat_grinder', ' computers.peripherals.printer'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' appliances.personal.scales'],
#  [' appliances.kitchen.meat_grinder',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.peripherals.keyboard'],
#  [' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' sport.tennis'],
#  [' appliances.kitchen.meat_grinder', ' computers.components.memory'],
#  [' appliances.kitchen.meat_grinder', ' appliances.personal.scales'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' auto.accessories.videoregister'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' accessories.bag'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' construction.tools.pump',
#   ' country_yard.weather_station',
#   ' country_yard.weather_station'],
#  [' appliances.kitchen.meat_grinder', ' computers.notebook'],
#  [' appliances.kitchen.meat_grinder', ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' apparel.costume'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder',
#   ' stationery.battery',
#   ' furniture.bedroom.pillow'],
#  [' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.juicer',
#   ' appliances.steam_cleaner'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.kitchen.grill'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' appliances.kitchen.grill'],
#  [' appliances.kitchen.meat_grinder', ' furniture.bedroom.blanket'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' computers.peripherals.mouse'],
#  [' appliances.kitchen.meat_grinder',
#   ' sport.ski',
#   ' appliances.kitchen.toster'],
#  [' appliances.kitchen.meat_grinder', ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.meat_grinder',
#   ' country_yard.weather_station',
#   ' kids.bottles'],
#  [' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' sport.tennis'],
#  [' appliances.kitchen.meat_grinder',
#   ' computers.peripherals.joystick',
#   ' sport.tennis'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder', ' sport.tennis'],
#  [' appliances.kitchen.meat_grinder', ' appliances.kitchen.grill'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.meat_grinder'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' computers.notebook',
#   ' appliances.environment.air_conditioner'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' kids.fmcg.diapers'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.washer',
#   ' appliances.environment.fan'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' computers.peripherals.scanner'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' construction.tools.drill'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer',
#   ' appliances.kitchen.steam_cooker',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.camera',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer', ' computers.peripherals.keyboard'],
#  [' appliances.kitchen.mixer', ' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  [' appliances.kitchen.mixer'],
#  ...]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(buy_summer_transactions).transform(buy_summer_transactions)
buy_summer_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
buy_summer_binary_db
# Out:
#          accessories.bag   accessories.umbrella   apparel.costume  \
# 0                  False                  False             False
# 1                  False                  False             False
# 2                  False                  False             False
# 3                  False                  False             False
# 4                  False                  False             False
# ...                  ...                    ...               ...
# 138848             False                  False             False
# 138849             False                  False             False
# 138850             False                  False             False
# 138851             False                  False             False
# 138852             False                  False             False
#
#          apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0                False           False           False          False
# 1                False           False           False          False
# 2                False           False           False          False
# 3                False           False           False          False
# 4                False           False           False          False
# ...                ...             ...             ...            ...
# 138848           False           False           False          False
# 138849           False           False           False          False
# 138850           False           False           False          False
# 138851           False           False           False          False
# 138852           False           False           False          False
#
#          apparel.trousers   apparel.tshirt  \
# 0                   False            False
# 1                   False            False
# 2                   False            False
# 3                   False            False
# 4                   False            False
# ...                   ...              ...
# 138848              False            False
# 138849              False            False
# 138850              False            False
# 138851              False            False
# 138852              False            False
#
#          appliances.environment.air_conditioner  ...   sport.bicycle  \
# 0                                         False  ...           False
# 1                                         False  ...           False
# 2                                         False  ...           False
# 3                                         False  ...           False
# 4                                         False  ...           False
# ...                                         ...  ...             ...
# 138848                                    False  ...           False
# 138849                                    False  ...           False
# 138850                                    False  ...           False
# 138851                                    False  ...           False
# 138852                                    False  ...           False
#
#          sport.diving   sport.ski   sport.snowboard   sport.tennis  \
# 0               False       False             False          False
# 1               False       False             False           True
# 2               False       False             False          False
# 3               False       False             False          False
# 4               False       False             False          False
# ...               ...         ...               ...            ...
# 138848          False       False             False          False
# 138849          False       False             False          False
# 138850          False       False             False          False
# 138851          False       False             False          False
# 138852          False       False             False          False
#
#          sport.trainer   stationery.battery   stationery.cartrige  \
# 0                False                False                 False
# 1                False                False                 False
# 2                False                False                 False
# 3                False                False                 False
# 4                False                False                 False
# ...                ...                  ...                   ...
# 138848           False                False                 False
# 138849           False                False                 False
# 138850           False                False                 False
# 138851           False                False                 False
# 138852           False                False                 False
#
#          stationery.paper   stationery.stapler
# 0                   False                False
# 1                   False                False
# 2                   False                False
# 3                   False                False
# 4                   False                False
# ...                   ...                  ...
# 138848              False                False
# 138849              False                False
# 138850              False                False
# 138851              False                False
# 138852              False                False
#
# [138853 rows x 123 columns]

# %% [markdown]
# ### 3.1.3 Clicks Summer

# %%
clickprod_df.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories  Timestamp    Semana
# 0     5737263  214536500   electronics.tablet 2014-07-03  Thursday
# 1     5737263  214536500   electronics.tablet 2014-07-03  Thursday
# 2     5702866  214536500   electronics.tablet 2014-07-06    Sunday
# 3     6172052  214536500   electronics.tablet 2014-07-11    Friday
# 4     5879836  214536500   electronics.tablet 2014-07-10  Thursday

# %%
time = clickprod_df["Timestamp"].astype(str).str.split("-", n = 2, expand = True)
clickprod_df["Timestamp"] = time[1]
clickprod_df.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories Timestamp    Semana
# 0     5737263  214536500   electronics.tablet        07  Thursday
# 1     5737263  214536500   electronics.tablet        07  Thursday
# 2     5702866  214536500   electronics.tablet        07    Sunday
# 3     6172052  214536500   electronics.tablet        07    Friday
# 4     5879836  214536500   electronics.tablet        07  Thursday

# %%
teste = clickprod_df
teste = teste.drop("Semana",axis=1)
clicks_spring_df =  teste.loc[teste['Timestamp'].isin(['04', '05'])] 
clicks_summer_df = teste.loc[teste['Timestamp'].isin(['06', '07'])]

# %%
clicks_summer_df
# Out:
#         Session_ID    Item_ID              Product_Categories Timestamp
# 0          5737263  214536500              electronics.tablet        07
# 1          5737263  214536500              electronics.tablet        07
# 2          5702866  214536500              electronics.tablet        07
# 3          6172052  214536500              electronics.tablet        07
# 4          5879836  214536500              electronics.tablet        07
# ...            ...        ...                             ...       ...
# 606704     6860077  214712259   computers.peripherals.scanner        07
# 606705     6857052  214846592         country_yard.lawn_mower        07
# 606706     6883899  214822181         furniture.bathroom.bath        07
# 606707     6883899  214823535     electronics.audio.subwoofer        07
# 606708     6938531  214808205        computers.network.router        07
#
# [606709 rows x 4 columns]

# %%
click_summer_transactions= []

for i in list(clicks_summer_df.Session_ID[:500].unique()):
    click_summer_transactions.append(clicks_summer_df[clicks_summer_df.Session_ID==i].Product_Categories.values.tolist())
    
click_summer_transactions
# Out:
# [[' electronics.tablet',
#   ' electronics.tablet',
#   ' kids.swing',
#   ' appliances.environment.air_heater',
#   ' appliances.kitchen.washer',
#   ' kids.swing',
#   ' kids.swing',
#   ' kids.swing',
#   ' computers.components.videocards',
#   ' construction.tools.drill'],
#  [' electronics.tablet',
#   ' kids.swing',
#   ' electronics.tablet',
#   ' appliances.kitchen.steam_cooker',
#   ' furniture.living_room.shelving',
#   ' furniture.living_room.chair',
#   ' construction.tools.generator',
#   ' furniture.kitchen.chair',
#   ' construction.tools.pump',
#   ' appliances.environment.air_conditioner',
#   ' construction.tools.pump',
#   ' furniture.kitchen.chair',
#   ' furniture.kitchen.chair',
#   ' construction.tools.pump',
#   ' furniture.living_room.chair',
#   ' sport.ski',
#   ' stationery.cartrige',
#   ' computers.components.videocards',
#   ' furniture.living_room.shelving',
#   ' appliances.environment.vacuum',
#   ' kids.fmcg.diapers',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' electronics.tablet',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' computers.components.videocards'],
#  [' electronics.tablet',
#   ' computers.peripherals.mouse',
#   ' electronics.tablet',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' apparel.tshirt',
#   ' sport.snowboard',
#   ' country_yard.cultivator',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer'],
#  [' furniture.kitchen.table',
#   ' computers.components.motherboard',
#   ' computers.components.memory',
#   ' electronics.audio.headphone',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' apparel.tshirt',
#   ' furniture.bedroom.pillow',
#   ' furniture.kitchen.table',
#   ' electronics.calculator',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' kids.bottles'],
#  [' furniture.kitchen.table',
#   ' computers.components.cpu',
#   ' computers.peripherals.keyboard',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' accessories.bag',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.mixer',
#   ' furniture.living_room.cabinet',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.toster',
#   ' apparel.shoes',
#   ' appliances.sewing_machine',
#   ' computers.peripherals.scanner',
#   ' construction.tools.generator',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' computers.components.power_supply',
#   ' electronics.tablet',
#   ' appliances.kitchen.coffee_machine',
#   ' computers.components.power_supply',
#   ' auto.accessories.videoregister',
#   ' furniture.bedroom.pillow',
#   ' furniture.living_room.shelving',
#   ' electronics.audio.headphone',
#   ' electronics.telephone',
#   ' computers.components.power_supply',
#   ' appliances.personal.hair_cutter',
#   ' kids.toys',
#   ' auto.accessories.anti_freeze',
#   ' furniture.kitchen.table',
#   ' electronics.video.tv',
#   ' computers.components.cpu',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' furniture.kitchen.table',
#   ' furniture.kitchen.table',
#   ' furniture.bedroom.pillow',
#   ' computers.components.memory',
#   ' construction.tools.light',
#   ' electronics.calculator',
#   ' furniture.kitchen.table',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' electronics.clocks',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' appliances.steam_cleaner'],
#  [' furniture.kitchen.table',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.mouse',
#   ' computers.components.videocards',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' electronics.audio.microphone',
#   ' furniture.bedroom.bed',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' appliances.iron',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.printer',
#   ' appliances.personal.hair_cutter',
#   ' computers.gaming',
#   ' furniture.bedroom.bed',
#   ' appliances.kitchen.mixer',
#   ' electronics.clocks',
#   ' kids.skates',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.bicycle',
#   ' sport.bicycle',
#   ' appliances.kitchen.dishwasher',
#   ' furniture.kitchen.table',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' apparel.glove',
#   ' apparel.glove',
#   ' electronics.clocks',
#   ' computers.components.cooler',
#   ' furniture.bedroom.bed',
#   ' furniture.bedroom.bed',
#   ' electronics.smartphone',
#   ' electronics.smartphone',
#   ' appliances.environment.climate',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.iron'],
#  [' furniture.kitchen.table',
#   ' appliances.kitchen.blender',
#   ' accessories.bag',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.environment.climate',
#   ' construction.tools.light',
#   ' electronics.video.projector',
#   ' construction.tools.light',
#   ' auto.accessories.player',
#   ' appliances.kitchen.hood',
#   ' kids.toys',
#   ' furniture.kitchen.table',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' furniture.kitchen.table',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.light',
#   ' computers.peripherals.camera',
#   ' furniture.kitchen.table',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' appliances.environment.vacuum',
#   ' construction.tools.drill'],
#  [' furniture.kitchen.table',
#   ' appliances.kitchen.coffee_grinder',
#   ' appliances.environment.climate',
#   ' computers.components.videocards',
#   ' computers.peripherals.printer',
#   ' computers.components.memory',
#   ' computers.peripherals.mouse',
#   ' electronics.audio.headphone',
#   ' construction.tools.light',
#   ' computers.peripherals.printer',
#   ' apparel.tshirt',
#   ' furniture.kitchen.table',
#   ' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' furniture.kitchen.table',
#   ' accessories.bag',
#   ' stationery.cartrige',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.juicer',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.coffee_machine',
#   ' electronics.audio.headphone',
#   ' country_yard.weather_station',
#   ' country_yard.weather_station',
#   ' appliances.personal.scales',
#   ' furniture.bedroom.pillow',
#   ' appliances.kitchen.toster',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' furniture.kitchen.table',
#   ' computers.components.motherboard',
#   ' electronics.audio.headphone',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' construction.tools.screw',
#   ' construction.tools.light',
#   ' appliances.iron',
#   ' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower'],
#  [' electronics.smartphone',
#   ' computers.peripherals.scanner',
#   ' furniture.kitchen.table',
#   ' construction.tools.drill',
#   ' computers.components.cpu',
#   ' electronics.audio.subwoofer',
#   ' electronics.calculator',
#   ' kids.toys',
#   ' kids.toys',
#   ' kids.toys',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.refrigerators',
#   ' kids.fmcg.diapers',
#   ' electronics.camera.video',
#   ' computers.ebooks',
#   ' appliances.sewing_machine',
#   ' computers.notebook',
#   ' furniture.living_room.cabinet',
#   ' furniture.living_room.cabinet',
#   ' furniture.universal.light',
#   ' electronics.camera.video',
#   ' appliances.environment.fan',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light'],
#  [' appliances.kitchen.refrigerators', ' sport.tennis'],
#  [' appliances.kitchen.refrigerators',
#   ' electronics.camera.photo',
#   ' electronics.camera.photo',
#   ' computers.network.router',
#   ' stationery.battery',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.camera',
#   ' appliances.kitchen.juicer',
#   ' furniture.living_room.cabinet',
#   ' construction.tools.screw',
#   ' kids.fmcg.diapers',
#   ' stationery.paper',
#   ' electronics.audio.subwoofer',
#   ' electronics.calculator',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.mixer',
#   ' appliances.personal.hair_cutter',
#   ' appliances.kitchen.microwave'],
#  [' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' computers.desktop',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' medicine.tools.tonometer'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' furniture.kitchen.chair',
#   ' appliances.environment.air_heater',
#   ' construction.tools.pump',
#   ' furniture.kitchen.chair',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' medicine.tools.tonometer'],
#  [' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [' appliances.personal.scales', ' sport.ski'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.network.router',
#   ' appliances.steam_cleaner'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.components.hdd',
#   ' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' computers.peripherals.mouse',
#   ' computers.components.cdrw',
#   ' furniture.living_room.chair',
#   ' computers.ebooks',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.juicer',
#   ' furniture.living_room.shelving',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' stationery.paper',
#   ' apparel.glove',
#   ' apparel.glove'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.mouse',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.ebooks',
#   ' kids.toys',
#   ' construction.tools.light',
#   ' furniture.living_room.sofa',
#   ' electronics.telephone',
#   ' apparel.shoes',
#   ' electronics.audio.microphone',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' appliances.kitchen.microwave',
#   ' apparel.sock',
#   ' electronics.smartphone',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.microwave',
#   ' computers.components.hdd'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' furniture.living_room.chair',
#   ' appliances.personal.scales'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' accessories.bag'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.personal.hair_cutter',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.clocks',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.clocks',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.clocks'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' furniture.kitchen.chair',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.toster',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.microwave',
#   ' appliances.environment.water_heater',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' computers.peripherals.printer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' apparel.tshirt',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.personal.hair_cutter',
#   ' computers.components.hdd',
#   ' appliances.kitchen.mixer',
#   ' computers.components.videocards',
#   ' apparel.tshirt',
#   ' appliances.kitchen.steam_cooker',
#   ' furniture.bedroom.pillow',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' kids.bottles',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' kids.bottles',
#   ' kids.bottles'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' computers.peripherals.scanner',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' sport.trainer',
#   ' computers.components.videocards'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.iron',
#   ' computers.components.hdd',
#   ' computers.components.cdrw',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.environment.vacuum',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' construction.tools.screw',
#   ' auto.accessories.radar',
#   ' auto.accessories.radar',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv', ' computers.components.memory'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.toster',
#   ' construction.tools.heater',
#   ' construction.tools.heater',
#   ' computers.network.router',
#   ' construction.tools.heater',
#   ' construction.tools.heater',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' construction.tools.heater',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.grill',
#   ' medicine.tools.tonometer',
#   ' construction.tools.drill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv', ' electronics.video.tv', ' computers.notebook'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.printer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.camera',
#   ' electronics.clocks'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.audio.dictaphone',
#   ' electronics.video.tv',
#   ' computers.peripherals.joystick',
#   ' electronics.video.tv',
#   ' appliances.personal.scales',
#   ' construction.tools.heater',
#   ' electronics.calculator',
#   ' apparel.sock',
#   ' auto.accessories.videoregister',
#   ' construction.tools.screw',
#   ' medicine.tools.tonometer',
#   ' country_yard.weather_station',
#   ' auto.accessories.radar',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' construction.tools.heater',
#   ' electronics.telephone',
#   ' furniture.kitchen.chair',
#   ' electronics.audio.microphone',
#   ' apparel.trousers',
#   ' sport.snowboard',
#   ' computers.components.videocards',
#   ' sport.tennis',
#   ' sport.diving',
#   ' computers.peripherals.monitor',
#   ' kids.fmcg.diapers',
#   ' electronics.smartphone',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' construction.tools.drill'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' sport.trainer',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' computers.components.power_supply',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' apparel.sock',
#   ' furniture.kitchen.chair'],
#  [' electronics.video.tv',
#   ' electronics.camera.photo',
#   ' medicine.tools.tonometer',
#   ' auto.accessories.compressor',
#   ' medicine.tools.tonometer',
#   ' furniture.kitchen.chair',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' kids.bottles'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.meat_grinder',
#   ' apparel.tshirt'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' appliances.personal.scales'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.iron',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.scanner',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' furniture.bedroom.pillow',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' furniture.universal.light',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.telephone',
#   ' electronics.telephone',
#   ' furniture.bathroom.toilet',
#   ' appliances.ironing_board',
#   ' furniture.bathroom.toilet',
#   ' electronics.video.tv',
#   ' computers.components.videocards',
#   ' appliances.kitchen.fryer',
#   ' computers.components.power_supply',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' kids.toys',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.scanner',
#   ' electronics.video.tv',
#   ' computers.peripherals.mouse',
#   ' apparel.shirt',
#   ' appliances.kitchen.grill',
#   ' computers.notebook',
#   ' computers.notebook'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.hood',
#   ' auto.accessories.anti_freeze',
#   ' furniture.bedroom.bed',
#   ' stationery.stapler',
#   ' accessories.bag',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.dishwasher',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.monitor',
#   ' sport.snowboard',
#   ' auto.accessories.radar',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' apparel.shoes',
#   ' apparel.shoes',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' appliances.iron',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' kids.toys',
#   ' medicine.tools.tonometer',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' computers.components.memory',
#   ' furniture.living_room.shelving',
#   ' stationery.battery',
#   ' stationery.battery',
#   ' sport.snowboard',
#   ' auto.accessories.videoregister',
#   ' electronics.calculator',
#   ' furniture.living_room.cabinet',
#   ' electronics.video.tv',
#   ' electronics.clocks',
#   ' auto.accessories.radar',
#   ' computers.gaming',
#   ' computers.gaming',
#   ' country_yard.cultivator',
#   ' furniture.living_room.chair',
#   ' country_yard.weather_station',
#   ' computers.ebooks',
#   ' country_yard.lawn_mower',
#   ' stationery.stapler',
#   ' sport.snowboard',
#   ' sport.snowboard',
#   ' apparel.glove',
#   ' electronics.calculator',
#   ' appliances.kitchen.washer',
#   ' stationery.stapler',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.dishwasher',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.peripherals.monitor',
#   ' medicine.tools.tonometer',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.coffee_machine',
#   ' electronics.video.tv',
#   ' appliances.environment.climate',
#   ' computers.components.videocards',
#   ' computers.components.videocards',
#   ' appliances.kitchen.microwave',
#   ' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.audio.headphone',
#   ' apparel.shoes',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.iron',
#   ' stationery.battery',
#   ' appliances.kitchen.coffee_machine',
#   ' stationery.battery',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' kids.bottles',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill'],
#  [' electronics.video.tv',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.network.router',
#   ' computers.network.router',
#   ' computers.network.router',
#   ' construction.tools.screw',
#   ' furniture.bedroom.bed',
#   ' auto.accessories.anti_freeze',
#   ' appliances.kitchen.dishwasher',
#   ' electronics.clocks',
#   ' construction.tools.screw',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' construction.components.faucet',
#   ' construction.components.faucet',
#   ' construction.components.faucet'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.notebook',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.audio.dictaphone',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' appliances.environment.water_heater',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer'],
#  [' electronics.video.tv',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.toster',
#   ' kids.bottles',
#   ' appliances.kitchen.grill',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.personal.scales',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' computers.components.cdrw',
#   ' electronics.calculator',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.juicer',
#   ' country_yard.lawn_mower',
#   ' electronics.clocks',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' kids.bottles',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' electronics.calculator'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.fryer'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' computers.peripherals.joystick',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' apparel.shoes',
#   ' kids.skates',
#   ' stationery.stapler',
#   ' appliances.iron',
#   ' construction.tools.heater',
#   ' appliances.kitchen.kettle',
#   ' furniture.kitchen.chair',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.climate',
#   ' furniture.bedroom.blanket',
#   ' apparel.shoes',
#   ' furniture.bedroom.pillow',
#   ' sport.tennis',
#   ' computers.components.power_supply',
#   ' kids.bottles'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.smartphone',
#   ' appliances.kitchen.mixer'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' electronics.video.tv',
#   ' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv',
#   ' apparel.costume',
#   ' apparel.costume',
#   ' apparel.costume',
#   ' apparel.costume',
#   ' apparel.costume',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' furniture.living_room.chair',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' apparel.sock',
#   ' computers.ebooks',
#   ' furniture.bedroom.blanket',
#   ' country_yard.cultivator'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' stationery.cartrige',
#   ' sport.ski',
#   ' sport.ski',
#   ' sport.ski',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.personal.scales',
#   ' sport.ski',
#   ' computers.components.cpu',
#   ' sport.ski'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.audio.subwoofer',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.water_heater',
#   ' apparel.trousers',
#   ' computers.peripherals.monitor',
#   ' furniture.bedroom.bed',
#   ' appliances.kitchen.fryer',
#   ' appliances.environment.water_heater',
#   ' computers.peripherals.monitor',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' stationery.battery',
#   ' apparel.tshirt',
#   ' computers.notebook',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill'],
#  [' computers.components.cpu',
#   ' electronics.audio.dictaphone',
#   ' appliances.environment.water_heater',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' furniture.living_room.sofa',
#   ' furniture.living_room.sofa'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.kitchen.fryer',
#   ' construction.tools.generator',
#   ' electronics.tablet',
#   ' construction.tools.heater',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.coffee_machine',
#   ' country_yard.watering',
#   ' country_yard.watering',
#   ' appliances.kitchen.mixer',
#   ' computers.peripherals.camera',
#   ' kids.fmcg.diapers',
#   ' kids.toys',
#   ' kids.toys',
#   ' computers.gaming',
#   ' construction.tools.heater',
#   ' auto.accessories.videoregister',
#   ' computers.notebook',
#   ' construction.tools.generator',
#   ' stationery.cartrige',
#   ' computers.components.cooler',
#   ' construction.tools.saw',
#   ' construction.tools.heater',
#   ' electronics.tablet',
#   ' furniture.universal.light',
#   ' computers.components.cpu',
#   ' appliances.environment.air_conditioner',
#   ' construction.tools.generator',
#   ' appliances.kitchen.oven',
#   ' construction.tools.heater',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.dishwasher',
#   ' computers.components.cooler',
#   ' appliances.kitchen.kettle',
#   ' sport.tennis',
#   ' apparel.trousers'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.video.tv',
#   ' kids.toys',
#   ' kids.toys',
#   ' sport.bicycle',
#   ' sport.bicycle',
#   ' computers.components.cpu',
#   ' electronics.calculator',
#   ' computers.components.memory'],
#  [' computers.components.cpu',
#   ' kids.swing',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' furniture.living_room.cabinet',
#   ' appliances.ironing_board',
#   ' appliances.ironing_board',
#   ' apparel.sock',
#   ' computers.notebook',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.tablet',
#   ' computers.peripherals.camera',
#   ' computers.components.cooler',
#   ' apparel.shirt',
#   ' computers.peripherals.scanner',
#   ' electronics.tablet',
#   ' computers.components.cooler',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' construction.tools.welding',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' stationery.battery',
#   ' construction.tools.drill',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' computers.components.cpu', ' computers.desktop'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cooler',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' appliances.environment.vacuum'],
#  [' computers.components.cpu',
#   ' stationery.cartrige',
#   ' furniture.universal.light',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.kitchen.blender',
#   ' construction.tools.generator',
#   ' electronics.audio.headphone',
#   ' electronics.audio.headphone',
#   ' apparel.trousers',
#   ' stationery.paper',
#   ' computers.components.cpu',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' furniture.universal.light',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.cpu', ' electronics.clocks', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' kids.swing',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.personal.massager',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.cpu', ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' furniture.bedroom.pillow',
#   ' electronics.calculator',
#   ' electronics.calculator',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.fryer',
#   ' computers.peripherals.keyboard',
#   ' computers.peripherals.keyboard',
#   ' computers.notebook',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.monitor',
#   ' electronics.video.tv',
#   ' furniture.living_room.sofa',
#   ' kids.toys',
#   ' appliances.environment.air_conditioner',
#   ' appliances.environment.climate',
#   ' appliances.kitchen.washer',
#   ' computers.components.cpu',
#   ' appliances.environment.air_conditioner',
#   ' appliances.personal.massager',
#   ' computers.desktop',
#   ' apparel.shirt',
#   ' furniture.bedroom.blanket',
#   ' medicine.tools.tonometer',
#   ' electronics.clocks',
#   ' auto.accessories.radar',
#   ' appliances.steam_cleaner',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.components.cpu',
#   ' sport.bicycle',
#   ' appliances.iron',
#   ' kids.toys',
#   ' apparel.sock',
#   ' sport.tennis',
#   ' computers.peripherals.monitor',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' apparel.trousers',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' furniture.living_room.chair',
#   ' appliances.iron',
#   ' kids.toys',
#   ' computers.components.cpu',
#   ' electronics.clocks',
#   ' apparel.glove',
#   ' country_yard.lawn_mower'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' appliances.iron',
#   ' electronics.audio.microphone',
#   ' appliances.kitchen.blender',
#   ' country_yard.cultivator',
#   ' appliances.kitchen.coffee_machine',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' construction.tools.screw',
#   ' appliances.kitchen.washer',
#   ' sport.bicycle',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.telephone',
#   ' country_yard.lawn_mower',
#   ' computers.components.cpu',
#   ' furniture.living_room.sofa',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.dishwasher',
#   ' construction.tools.saw',
#   ' appliances.kitchen.dishwasher',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' kids.toys',
#   ' accessories.bag',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' computers.components.cpu',
#   ' kids.fmcg.diapers',
#   ' electronics.video.projector',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' furniture.universal.light'],
#  [' computers.components.cpu',
# ...
#   ' accessories.bag',
#   ' electronics.tablet',
#   ' computers.components.power_supply',
#   ' computers.notebook',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' furniture.living_room.sofa',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.iron',
#   ' computers.peripherals.mouse',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' furniture.kitchen.table',
#   ' electronics.telephone',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.trainer',
#   ' electronics.audio.headphone',
#   ' auto.accessories.radar',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' computers.peripherals.mouse',
#   ' computers.components.power_supply',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.grill',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' medicine.tools.tonometer',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.washer',
#   ' computers.components.cooler',
#   ' construction.tools.pump',
#   ' electronics.video.projector',
#   ' country_yard.weather_station',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.personal.massager',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' computers.peripherals.scanner',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.washer',
#   ' furniture.universal.light',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' accessories.bag',
#   ' computers.components.power_supply',
#   ' sport.snowboard',
#   ' computers.peripherals.printer',
#   ' sport.snowboard',
#   ' sport.snowboard',
#   ' sport.snowboard',
#   ' computers.components.power_supply',
#   ' sport.snowboard',
#   ' sport.snowboard',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' furniture.universal.light',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' kids.bottles',
#   ' kids.bottles',
#   ' kids.bottles',
#   ' kids.bottles',
#   ' kids.bottles',
#   ' kids.bottles',
#   ' kids.bottles',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.peripherals.camera',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' computers.peripherals.camera',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.meat_grinder',
#   ' kids.toys',
#   ' appliances.kitchen.mixer',
#   ' apparel.tshirt',
#   ' apparel.tshirt',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.camera',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' kids.bottles',
#   ' appliances.environment.vacuum',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' stationery.cartrige',
#   ' appliances.personal.hair_cutter',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' electronics.audio.acoustic',
#   ' construction.tools.screw',
#   ' appliances.kitchen.mixer',
#   ' appliances.iron',
#   ' appliances.personal.hair_cutter',
#   ' appliances.kitchen.meat_grinder',
#   ' auto.accessories.compressor',
#   ' computers.peripherals.keyboard',
#   ' apparel.shirt',
#   ' construction.tools.light',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' apparel.trousers',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.meat_grinder',
#   ' kids.skates',
#   ' computers.components.power_supply',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' sport.tennis',
#   ' computers.peripherals.printer',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' kids.bottles'],
#  [' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.iron',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' apparel.shoes',
#   ' computers.ebooks',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.juicer',
#   ' appliances.iron',
#   ' appliances.iron',
#   ' appliances.personal.scales',
#   ' auto.accessories.player',
#   ' construction.tools.heater',
#   ' construction.tools.heater',
#   ' appliances.kitchen.fryer',
#   ' furniture.kitchen.table',
#   ' construction.tools.drill',
#   ' stationery.paper',
#   ' appliances.kitchen.microwave',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' sport.bicycle',
#   ' sport.bicycle',
#   ' sport.bicycle',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' appliances.environment.vacuum'],
#  [' computers.components.memory',
#   ' computers.ebooks',
#   ' appliances.kitchen.mixer',
#   ' electronics.clocks',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' medicine.tools.tonometer',
#   ' medicine.tools.tonometer',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' appliances.kitchen.washer',
#   ' country_yard.cultivator',
#   ' medicine.tools.tonometer',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator',
#   ' country_yard.cultivator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.power_supply',
#   ' computers.components.power_supply',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.microwave',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' appliances.kitchen.mixer',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.washer',
#   ' electronics.tablet',
#   ' electronics.clocks',
#   ' computers.ebooks',
#   ' electronics.clocks',
#   ' appliances.kitchen.blender',
#   ' electronics.clocks',
#   ' appliances.personal.massager',
#   ' computers.notebook',
#   ' computers.notebook',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' kids.bottles',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' electronics.clocks',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.desktop',
#   ' computers.desktop',
#   ' computers.components.cdrw',
#   ' appliances.kitchen.mixer',
#   ' auto.accessories.anti_freeze',
#   ' appliances.kitchen.washer',
#   ' electronics.clocks',
#   ' computers.components.motherboard',
#   ' computers.peripherals.scanner',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks',
#   ' medicine.tools.tonometer',
#   ' appliances.kitchen.blender',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' computers.components.power_supply',
#   ' furniture.universal.light',
#   ' appliances.iron',
#   ' accessories.bag',
#   ' country_yard.lawn_mower',
#   ' sport.tennis',
#   ' appliances.environment.water_heater',
#   ' computers.notebook',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.ebooks',
#   ' appliances.kitchen.washer',
#   ' apparel.trousers',
#   ' appliances.personal.massager',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.living_room.cabinet',
#   ' appliances.kitchen.mixer',
#   ' appliances.iron',
#   ' construction.tools.drill',
#   ' computers.peripherals.joystick',
#   ' kids.skates',
#   ' kids.skates',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.grill'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' sport.tennis',
#   ' accessories.bag',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.juicer',
#   ' computers.peripherals.monitor',
#   ' appliances.kitchen.dishwasher',
#   ' appliances.kitchen.fryer',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.blender',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' construction.components.faucet',
#   ' construction.components.faucet',
#   ' construction.components.faucet',
#   ' appliances.steam_cleaner',
#   ' appliances.steam_cleaner',
#   ' country_yard.lawn_mower',
#   ' construction.tools.drill',
#   ' construction.tools.drill'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.mixer',
#   ' appliances.iron',
#   ' appliances.environment.air_conditioner',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.environment.air_conditioner',
#   ' computers.components.power_supply',
#   ' sport.tennis',
#   ' computers.peripherals.printer',
#   ' electronics.clocks',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner',
#   ' construction.tools.drill',
#   ' construction.tools.drill',
#   ' appliances.steam_cleaner'],
#  [' computers.components.memory',
#   ' accessories.bag',
#   ' computers.peripherals.mouse',
#   ' computers.components.cdrw',
#   ' appliances.kitchen.grill',
#   ' country_yard.lawn_mower',
#   ' appliances.steam_cleaner']]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(click_summer_transactions).transform(click_summer_transactions)
click_summer_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
click_summer_binary_db
# Out:
#       accessories.bag   apparel.costume   apparel.glove   apparel.shirt  \
# 0               False             False           False           False
# 1               False             False           False           False
# 2               False             False           False           False
# 3               False             False           False           False
# 4                True             False           False           False
# ..                ...               ...             ...             ...
# 400              True             False           False           False
# 401             False             False           False           False
# 402              True             False           False           False
# 403             False             False           False           False
# 404              True             False           False           False
#
#       apparel.shoes   apparel.sock   apparel.trousers   apparel.tshirt  \
# 0             False          False              False            False
# 1             False          False              False            False
# 2             False          False              False            False
# 3             False          False              False             True
# 4             False          False              False             True
# ..              ...            ...                ...              ...
# 400           False          False              False            False
# 401           False          False               True            False
# 402           False          False              False            False
# 403           False          False              False            False
# 404           False          False              False            False
#
#       appliances.environment.air_conditioner  \
# 0                                      False
# 1                                       True
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 400                                    False
# 401                                    False
# 402                                    False
# 403                                     True
# 404                                    False
#
#       appliances.environment.air_heater  ...   sport.bicycle   sport.diving  \
# 0                                  True  ...           False          False
# 1                                 False  ...           False          False
# 2                                 False  ...           False          False
# 3                                 False  ...           False          False
# 4                                 False  ...           False          False
# ..                                  ...  ...             ...            ...
# 400                               False  ...           False          False
# 401                               False  ...           False          False
# 402                               False  ...           False          False
# 403                               False  ...           False          False
# 404                               False  ...           False          False
#
#       sport.ski   sport.snowboard   sport.tennis   sport.trainer  \
# 0         False             False          False           False
# 1          True             False           True           False
# 2         False             False          False           False
# 3         False              True          False           False
# 4         False             False           True           False
# ..          ...               ...            ...             ...
# 400       False             False           True           False
# 401       False             False           True           False
# 402       False             False           True           False
# 403       False             False           True           False
# 404       False             False          False           False
#
#       stationery.battery   stationery.cartrige   stationery.paper  \
# 0                  False                 False              False
# 1                  False                  True              False
# 2                  False                 False              False
# 3                  False                 False              False
# 4                  False                 False              False
# ..                   ...                   ...                ...
# 400                False                 False              False
# 401                False                 False              False
# 402                False                 False              False
# 403                False                 False              False
# 404                False                 False              False
#
#       stationery.stapler
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 400                False
# 401                False
# 402                False
# 403                False
# 404                False
#
# [405 rows x 120 columns]

# %% [markdown]
# ###  3.1.4 Clicks Spring

# %%
clicks_spring_df
# Out:
# Empty DataFrame
# Columns: [Session_ID, Item_ID, Product_Categories, Timestamp]
# Index: []

# %%
click_spring_transactions= []

for i in list(clicks_spring_df.Session_ID.unique()):
    click_spring_transactions.append(clicks_spring_df[clicks_spring_df.Session_ID==i].Product_Categories.values.tolist())
    
click_spring_transactions
# Out:
# []

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(click_spring_transactions).transform(click_spring_transactions)
click_spring_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
click_spring_binary_db
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3.2. Compute Frequent Itemsets

# %% [markdown]
# * Compute frequent itemsets considering a minimum support of X%.
# * Present frequent itemsets organized by length (number of items).
# * List frequent 1-itemsets, 2-itemsets, 3-itemsets, etc with support of at least Y%.
# * Change X and Y when it makes sense and discuss the results.

# %% [markdown]
# **Buys- Spring**

# %%
frequent_itemsets = apriori(buy_spring_binary_db, min_support=0.16,  use_colnames=True)
frequent_itemsets
# Out:
#     support         itemsets
# 0  0.160904  ( sport.tennis)

# %% [markdown]
# **What are the most bought products during the Spring?** The most bought product is sport.tennis , appearing approximatly 16% of all transactions.

# %%
frequent_itemsets = apriori(buy_spring_binary_db, min_support=0.02, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                   itemsets  length
# 0   0.026683                         ( accessories.bag)       1
# 1   0.044702              ( appliances.environment.fan)       1
# 2   0.024684           ( appliances.environment.vacuum)       1
# 3   0.029801                         ( appliances.iron)       1
# 4   0.093479              ( appliances.kitchen.blender)       1
# 5   0.052297         ( appliances.kitchen.meat_grinder)       1
# 6   0.020959                ( appliances.kitchen.mixer)       1
# 7   0.058121               ( appliances.kitchen.toster)       1
# 8   0.023264                ( computers.components.hdd)       1
# 9   0.106965             ( computers.components.memory)       1
# 10  0.027824         ( computers.components.videocards)       1
# 11  0.069970                        ( computers.gaming)       1
# 12  0.039757                      ( computers.notebook)       1
# 13  0.022546          ( computers.peripherals.joystick)       1
# 14  0.044134           ( computers.peripherals.monitor)       1
# 15  0.025653              ( construction.tools.welding)       1
# 16  0.041372                 ( country_yard.lawn_mower)       1
# 17  0.023520                   ( electronics.telephone)       1
# 18  0.031054                    ( electronics.video.tv)       1
# 19  0.023910                ( medicine.tools.tonometer)       1
# 20  0.160904                            ( sport.tennis)       1
# 21  0.026711  ( country_yard.lawn_mower,  sport.tennis)       2

# %%
frequent_itemsets_spring = frequent_itemsets[ (frequent_itemsets['support'] >= 0.02) & (frequent_itemsets['length'] == 2)]
frequent_itemsets_spring
# Out:
#      support                                   itemsets  length
# 21  0.026711  ( country_yard.lawn_mower,  sport.tennis)       2

# %% [markdown]
# **Buys Summer**

# %%
frequent_itemsets = apriori(buy_summer_binary_db, min_support=0.121,  use_colnames=True)
frequent_itemsets
# Out:
#     support                    itemsets
# 0  0.121935  ( country_yard.lawn_mower)

# %% [markdown]
# **What are the most bought products during the Summer?** The most bought product is country_yard.lawn_mower , appearing approximatly 12% of all transactions.

# %%
frequent_itemsets = apriori(buy_summer_binary_db, min_support=0.02, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0   0.024364                                 ( accessories.bag)       1
# 1   0.076635                   ( appliances.environment.vacuum)       1
# 2   0.030406                      ( appliances.kitchen.blender)       1
# 3   0.105284                        ( appliances.kitchen.grill)       1
# 4   0.032862                 ( appliances.kitchen.meat_grinder)       1
# 5   0.027986                        ( appliances.kitchen.mixer)       1
# 6   0.066423                       ( appliances.kitchen.toster)       1
# 7   0.120667                        ( appliances.steam_cleaner)       1
# 8   0.022981                        ( computers.components.hdd)       1
# 9   0.053949                     ( computers.components.memory)       1
# 10  0.043658                              ( computers.notebook)       1
# 11  0.074575                   ( computers.peripherals.monitor)       1
# 12  0.069023                        ( construction.tools.drill)       1
# 13  0.121935                         ( country_yard.lawn_mower)       1
# 14  0.049016                              ( electronics.clocks)       1
# 15  0.025811                            ( electronics.video.tv)       1
# 16  0.037767                                    ( kids.bottles)       1
# 17  0.093091                        ( medicine.tools.tonometer)       1
# 18  0.089116                                    ( sport.tennis)       1
# 19  0.026143  ( country_yard.lawn_mower,  appliances.kitchen...       2
# 20  0.020324  ( appliances.steam_cleaner,  construction.tool...       2
# 21  0.023500  ( country_yard.lawn_mower,  appliances.steam_c...       2

# %%
frequent_itemsets_summer = frequent_itemsets[ (frequent_itemsets['support'] >= 0.02) & (frequent_itemsets['length'] == 2)]
frequent_itemsets_summer
# Out:
#      support                                           itemsets  length
# 19  0.026143  ( country_yard.lawn_mower,  appliances.kitchen...       2
# 20  0.020324  ( appliances.steam_cleaner,  construction.tool...       2
# 21  0.023500  ( country_yard.lawn_mower,  appliances.steam_c...       2

# %% [markdown]
# ### Compering the sets of products bought during the Spring and the Summer

# %%
frequent_itemsets_spring
# Out:
#      support                                   itemsets  length
# 21  0.026711  ( country_yard.lawn_mower,  sport.tennis)       2

# %%
frequent_itemsets_summer
# Out:
#      support                                           itemsets  length
# 19  0.026143  ( country_yard.lawn_mower,  appliances.kitchen...       2
# 20  0.020324  ( appliances.steam_cleaner,  construction.tool...       2
# 21  0.023500  ( country_yard.lawn_mower,  appliances.steam_c...       2

# %% [markdown]
# When compering the sets of products bought during the Spring and the Summer we can see that lawn mowers are bought on Spring and on Summer(probably because plants grow more on these times of the year) and then on Spring because its after winter and people will start to walk and run again sport.tennis are bought as a set and on Summer there are appliances and construction tools as a set.

# %% [markdown]
# **Clicks Spring**

# %%
frequent_itemsets = apriori(click_spring_binary_db, min_support=0.001,  use_colnames=True)
frequent_itemsets
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
frequent_itemsets = apriori(click_spring_binary_db, min_support=0.02, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length]
# Index: []

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.02) & (frequent_itemsets['length'] == 2)]
frequent_itemsets
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length]
# Index: []

# %% [markdown]
# **Clicks Summer**

# %%
frequent_itemsets = apriori(click_summer_binary_db, min_support=0.1,  use_colnames=True)
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.192593                                 ( accessories.bag)
# 1    0.106173                                  ( apparel.tshirt)
# 2    0.261728                   ( appliances.environment.vacuum)
# 3    0.192593                                 ( appliances.iron)
# 4    0.143210                      ( appliances.kitchen.blender)
# ..        ...                                                ...
# 225  0.167901  ( country_yard.lawn_mower,  electronics.clocks...
# 226  0.106173  ( country_yard.lawn_mower,  medicine.tools.ton...
# 227  0.103704  ( country_yard.lawn_mower,  appliances.kitchen...
# 228  0.103704  ( appliances.kitchen.grill,  sport.tennis,  co...
# 229  0.128395  ( country_yard.lawn_mower,  appliances.kitchen...
#
# [230 rows x 2 columns]

# %%
frequent_itemsets = apriori(click_summer_binary_db, min_support=0.02, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#         support                                           itemsets  length
# 0      0.192593                                 ( accessories.bag)       1
# 1      0.022222                                   ( apparel.shirt)       1
# 2      0.074074                                   ( apparel.shoes)       1
# 3      0.037037                                    ( apparel.sock)       1
# 4      0.032099                                ( apparel.trousers)       1
# ...         ...                                                ...     ...
# 22040  0.024691  ( country_yard.lawn_mower,  medicine.tools.ton...       9
# 22041  0.022222  ( country_yard.lawn_mower,  medicine.tools.ton...       9
# 22042  0.022222  ( country_yard.lawn_mower,  medicine.tools.ton...       9
# 22043  0.022222  ( country_yard.lawn_mower,  medicine.tools.ton...       9
# 22044  0.022222  ( country_yard.lawn_mower,  medicine.tools.ton...       9
#
# [22045 rows x 3 columns]

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.02) & (frequent_itemsets['length'] == 2)]
frequent_itemsets
# Out:
#       support                                           itemsets  length
# 83   0.022222                 ( apparel.shoes,  accessories.bag)       2
# 84   0.039506                ( apparel.tshirt,  accessories.bag)       2
# 85   0.041975  ( appliances.environment.climate,  accessories...       2
# 86   0.039506    ( appliances.environment.fan,  accessories.bag)       2
# 87   0.074074  ( appliances.environment.vacuum,  accessories....       2
# ..        ...                                                ...     ...
# 862  0.046914   ( medicine.tools.tonometer,  stationery.battery)       2
# 863  0.093827  ( medicine.tools.tonometer,  stationery.cartrige)       2
# 864  0.041975               ( stationery.battery,  sport.tennis)       2
# 865  0.103704              ( stationery.cartrige,  sport.tennis)       2
# 866  0.037037        ( stationery.battery,  stationery.cartrige)       2
#
# [784 rows x 3 columns]

# %% [markdown]
# ### 3.3. Generate Association Rules from Frequent Itemsets

# %% [markdown]
# * Generate association rules with a choosed value (C) for minimum confidence.
# * Generate association rules with a choosed value (L) for minimum lift.
# * Generate association rules with both confidence >= C% and lift >= L.
# * Change C and L when it makes sense and discuss the results.

# %% [markdown]
# ### 3.3.1 Buys Spring

# %%
frequent_itemsets = apriori(buy_spring_binary_db, min_support=0.02, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2.0)
lift_rules

# %% [markdown]
# ### 3.3.2 Buys Summer

# %%
frequent_itemsets = apriori(buy_summer_binary_db, min_support=0.02, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2.0)
lift_rules

# %% [markdown]
# ### 3.3.4 Clicks Spring

# %%
frequent_itemsets = apriori(click_spring_binary_db, min_support=0.02, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2.0)
lift_rules

# %% [markdown]
# ### 3.3.5 Clicks Summer

# %%
frequent_itemsets = apriori(click_summer_binary_db, min_support=0.02, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2.0)
lift_rules

# %% [markdown]
# ### 3.4. Conclusions

# %% [markdown]
# ## 4. Conclusions
# Draw some conclusions about this project work.

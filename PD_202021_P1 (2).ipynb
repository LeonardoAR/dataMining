# %% [markdown]
# ## Data Mining / Prospeção de Dados
#
# ## Diogo Soares and Sara C. Madeira, 2020/21
#
# # Project 1 - Pattern Mining

# %% [markdown]
# ## Logistics
# **_Read Carefully_**
#
# **Students should work in teams of 2 or 3 people**.
#
# **TASK 3 - Spring vs Summer Purchases** must be done only by groups of 3 people.
#
# Individual projects might be allowed (with valid justification), but will not have better grades for this reason.
#
# The quality of the project will dictate its grade, not the number of people working.
#
# **The project's solution should be uploaded in Moodle before the end of `March, 28th (23:59)`.**
#
# Students should **upload a `.zip` file** containing all the files necessary for project evaluation.
# Groups should be registered in [Moodle](https://moodle.ciencias.ulisboa.pt/mod/groupselect/view.php?id=139096) and the zip file should be identified as `PDnn.zip` where `nn` is the number of your group.
#
# **It is mandatory to produce a Jupyter notebook containing code and text/images/tables/etc describing the solution and the results. Projects not delivered in this format will not be graded. You can use `PD_202021_P1.ipynb`as template. In your `.zip` folder you should also include an HTML version of your notebook with all the outputs** (File > Download as > HTML).
#
# **Decisions should be justified and results should be critically discussed.**
#
# _Project solutions containing only code and outputs without discussions will achieve a maximum grade 10 out of 20._

# %% [markdown]
# ## Dataset and Tools
#
#
#
# In this project you will analyse data from an online Store collected over 4 months (April - July 2014). The folder `data` contains three files that you should use to obtain the dataset to be used in pattern mining.
#
# The file `store-buys.dat` comprises the buy events of the users over the items. It contains **318.444 sessions**. Each record/line in the file has the following fields (with this order):
#
# * **Session ID** - the id of the session. In one session there are one or many buying events. Could be represented as an integer number.
# * **Timestamp** - the time when the buy occurred. Format of YYYY-MM-DDThh:mm:ss.SSSZ
# * **Item ID** – the unique identifier of item that has been bought. Could be represented as an integer number.
# * **Price** – the price of the item. Could be represented as an integer number.
# * **Quantity** – the quantity in this buying.  Could be represented as an integer number.
#
# The file `store-clicks.dat` comprises the clicks of the users over the items. It contains **5.613.499 sessions**.  Each record/line in the file has the following fields (with this order):
#
# * **Session ID** – the id of the session. In one session there are one or many clicks. Could be represented as an integer number.
# * **Timestamp** – the time when the click occurred. Format of YYYY-MM-DDThh:mm:ss.SSSZ
# * **Item ID** – the unique identifier of the item that has been clicked. Could be represented as an integer number.
# * **Context** – the context of the click. The value "S" indicates a special offer, "0" indicates  a missing value, a number between 1 to 12 indicates a real category identifier,
# any other number indicates a brand. E.g. if an item has been clicked in the context of a promotion or special offer then the value will be "S", if the context was a brand i.e BOSCH,
# then the value will be an 8-10 digits number. If the item has been clicked under regular category, i.e. sport, then the value will be a number between 1 to 12.
#
# The file `products.csv` comprises the list of products sold by the online store. It contains **46.294 different products** associated with **123 different subcategories**. Each record/line in the file has the following fields:
#
# * **Item ID** - the unique identifier of the item. Could be represented as an integer number.
# * **Product Categories** - the category and subcategories of the item. It is a string containing the category and subcategories of the item. Eg. `appliances.kitchen.juice`
#
#
# In this project you should use [Python 3](https://www.python.org), [Jupyter Notebook](http://jupyter.org) and **[MLxtend](http://rasbt.github.io/mlxtend/)**. When using MLxtend, frequent patterns can either be discovered using `Apriori` and `FP-Growth`. **Choose the pattern mining algorithm to be used.**

# %% [markdown]
# ## Team Identification
#
# **GROUP NNN**
#
# Students:
#
# * Student 1 - n_student1
# * Student 2 - n_student2
# * Student 3 - n_student3

# %% [markdown]
# ## 1. Mining Frequent Itemsets and Association Rules
#
#
# In this first part of the project you should load and preprocess the dataset  in order to compute frequent itemsets and generate association rules considering all the sessions.

# %% [markdown]
# **In what follows keep the following question in mind and be creative!**
#
# 1. What are the most interesting products?
# 2. What are the most bought products?
# 3. Which products are bought together?
# 4. Can you find associations between the clicked products?
# 5. Can you find associations highliting that when people buy a product/set of products also buy other product(s)?
# 6. Can you find associations highliting that when people click in a product/set of products also buy this product(s)?
# 7. Can you find relevant associated categories?

# %% [markdown]
# ### 1.1. Load and Preprocess Data
#
#  **Product quantities should not be considered.**

# %% [markdown]
# Aqui fizemos os imports

# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import  TransactionEncoder
from mlxtend.frequent_patterns import apriori
import mlxtend.preprocessing
import mlxtend.frequent_patterns
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ### 1.1.1 Product
#
# The file `products.csv` comprises the list of products sold by the online store. It contains **46.294 different products** associated with **123 different subcategories**. Each record/line in the file has the following fields:
#
# * **Item ID** - the unique identifier of the item. Could be represented as an integer number.
# * **Product Categories** - the category and subcategories of the item. It is a string containing the category and subcategories of the item. Eg. `appliances.kitchen.juice`

# %%
product_df = pd.read_csv("products.csv")
product_df.columns = ["Item_ID","Product_Categories"]
product_df.head(5)
# Out:
#      Item_ID            Product_Categories
# 0  214536500            electronics.tablet
# 1  214536506            electronics.tablet
# 2  214577561   electronics.audio.headphone
# 3  214662742       furniture.kitchen.table
# 4  214662742       furniture.kitchen.table

# %%
product_df.shape
# Out:
# (20704558, 2)

# %%
pdf = product_df.drop_duplicates()

# %%
pdf.shape
# Out:
# (46294, 2)

# %% [markdown]
# ### 1.1.2 Store-buys
#
# The file `store-buys.dat` comprises the buy events of the users over the items. It contains **318.444 sessions**. Each record/line in the file has the following fields (with this order):
#
# * **Session ID** - the id of the session. In one session there are one or many buying events. Could be represented as an integer number.
# * **Timestamp** - the time when the buy occurred. Format of YYYY-MM-DDThh:mm:ss.SSSZ
# * **Item ID** – the unique identifier of item that has been bought. Could be represented as an integer number.
# * **Price** – the price of the item. Could be represented as an integer number.
# * **Quantity** – the quantity in this buying.  Could be represented as an integer number.

# %%
store_buys = pd.read_csv("store-buys.dat")

store_buys.columns = ["Session_ID","Timestamp","Item_ID", "Price", "Quantity"]

store_buys.head(5)
# Out:
#    Session_ID                 Timestamp    Item_ID  Price  Quantity
# 0      420374  2014-04-06T18:44:58.325Z  214537850  10471         1
# 1      281626  2014-04-06T09:40:13.032Z  214535653   1883         1
# 2      420368  2014-04-04T06:13:28.848Z  214530572   6073         1
# 3      420368  2014-04-04T06:13:28.858Z  214835025   2617         1
# 4      140806  2014-04-07T09:22:28.132Z  214668193    523         1

# %% [markdown]
# **Drop quantities**

# %%
store_buys = store_buys.drop("Quantity",axis=1)
store_buys = store_buys.drop("Price",axis=1)
store_buys
# Out:
#         Session_ID                 Timestamp    Item_ID
# 0           420374  2014-04-06T18:44:58.325Z  214537850
# 1           281626  2014-04-06T09:40:13.032Z  214535653
# 2           420368  2014-04-04T06:13:28.848Z  214530572
# 3           420368  2014-04-04T06:13:28.858Z  214835025
# 4           140806  2014-04-07T09:22:28.132Z  214668193
# ...            ...                       ...        ...
# 679483     6926714  2014-07-27T15:35:40.221Z  214665277
# 679484     6645086  2014-07-28T10:08:58.076Z  214567057
# 679485     6740437  2014-07-25T19:02:58.252Z  214708044
# 679486     6926707  2014-07-27T13:58:54.040Z  214848986
# 679487     6926707  2014-07-27T13:58:54.351Z  214848986
#
# [679488 rows x 3 columns]

# %% [markdown]
# ### 1.1.3 Store-clicks(falta processar melhor os dados)
#
#
# The file `store-clicks.dat` comprises the clicks of the users over the items. It contains **5.613.499 sessions**.  Each record/line in the file has the following fields (with this order):
#
# * **Session ID** – the id of the session. In one session there are one or many clicks. Could be represented as an integer number.
# * **Timestamp** – the time when the click occurred. Format of YYYY-MM-DDThh:mm:ss.SSSZ
# * **Item ID** – the unique identifier of the item that has been clicked. Could be represented as an integer number.
# * **Context** – the context of the click. The value "S" indicates a special offer, "0" indicates  a missing value, a number between 1 to 12 indicates a real category identifier,
# any other number indicates a brand. E.g. if an item has been clicked in the context of a promotion or special offer then the value will be "S", if the context was a brand i.e BOSCH,
# then the value will be an 8-10 digits number. If the item has been clicked under regular category, i.e. sport, then the value will be a number between 1 to 12.

# %%
store_clicks = pd.read_csv("store-clicks.dat")

store_clicks.columns = ["Session_ID","Timestamp","Item_ID", "Context"]

store_clicks.head(5)
# Out:
# D:\Apps\ANACONDA\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Session_ID                 Timestamp    Item_ID Context
# 0           1  2014-04-07T10:54:09.868Z  214536500       0
# 1           1  2014-04-07T10:54:46.998Z  214536506       0
# 2           1  2014-04-07T10:57:00.306Z  214577561       0
# 3           2  2014-04-07T13:56:37.614Z  214662742       0
# 4           2  2014-04-07T13:57:19.373Z  214662742       0

# %%
store_clicks.shape
# Out:
# (20704512, 4)

# %%
store_clicks = store_clicks.drop_duplicates()

# %% [markdown]
# ### 1.2 Merge store-buys and product_df
#
# To get a transaction list with the storage buys with the correspondent product description, we did a merge with the ghsfnofdks

# %%
masterdf = pd.merge(pdf.set_index('Item_ID'), store_buys.set_index('Item_ID'),on='Item_ID')
masterdf = masterdf.reset_index()

# %%
masterdf = masterdf[['Session_ID','Item_ID','Product_Categories','Timestamp']]

# %%
masterdf
# Out:
#         Session_ID    Item_ID          Product_Categories  \
# 0          2859734  214536500          electronics.tablet
# 1          4276371  214536500          electronics.tablet
# 2          4440056  214536500          electronics.tablet
# 3            70532  214536506          electronics.tablet
# 4           691119  214536506          electronics.tablet
# ...            ...        ...                         ...
# 679483     6649378  214851182   furniture.universal.light
# 679484     6649378  214851182   furniture.universal.light
# 679485     7001599  214571152            stationery.paper
# 679486     6961172  214571152            stationery.paper
# 679487     6873084  214847137                sport.tennis
#
#                        Timestamp
# 0       2014-05-14T12:06:02.717Z
# 1       2014-06-04T13:44:10.725Z
# 2       2014-06-14T19:14:00.581Z
# 3       2014-04-06T09:59:03.143Z
# 4       2014-04-14T15:56:30.514Z
# ...                          ...
# 679483  2014-07-28T15:33:57.709Z
# 679484  2014-07-28T15:53:12.209Z
# 679485  2014-07-24T20:16:42.857Z
# 679486  2014-07-28T19:39:09.688Z
# 679487  2014-07-23T14:35:11.496Z
#
# [679488 rows x 4 columns]

# %%
buy_transactions= []
#for i in list(masterdf.Session_ID[:50].unique()):
for i in list(masterdf.Session_ID[:500].unique()):
    buy_transactions.append(masterdf[masterdf.Session_ID==i].Product_Categories.values.tolist())
    
buy_transactions
# Out:
# [[' electronics.tablet'],
#  [' electronics.tablet', ' computers.peripherals.monitor'],
#  [' electronics.tablet', ' sport.tennis'],
#  [' electronics.tablet'],
#  [' electronics.tablet',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' furniture.living_room.cabinet'],
#  [' furniture.kitchen.table', ' computers.components.memory'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv'],
#  [' furniture.kitchen.table', ' electronics.audio.dictaphone'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table', ' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table',
#   ' computers.components.videocards',
#   ' furniture.kitchen.table',
#   ' country_yard.lawn_mower'],
#  [' electronics.smartphone', ' computers.components.memory'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.iron',
#   ' appliances.environment.water_heater',
#   ' construction.tools.heater'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' computers.peripherals.scanner'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' computers.notebook'],
#  [' appliances.kitchen.refrigerators', ' appliances.sewing_machine'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators', ' medicine.tools.tonometer'],
#  [' appliances.kitchen.refrigerators', ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators',
#   ' construction.tools.screw',
#   ' furniture.kitchen.table',
#   ' stationery.stapler',
#   ' appliances.kitchen.coffee_machine',
#   ' apparel.trousers',
#   ' construction.tools.heater',
#   ' construction.tools.saw',
#   ' construction.tools.heater',
#   ' computers.components.cpu',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.hdd',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' construction.tools.heater'],
#  [' appliances.kitchen.refrigerators', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.motherboard'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.water_heater'],
#  [' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.peripherals.camera',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.camera'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.living_room.cabinet',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.hood',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' country_yard.cultivator',
#   ' apparel.trousers'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.environment.air_heater'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.components.memory'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' furniture.living_room.shelving',
#   ' appliances.kitchen.blender'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' stationery.cartrige'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.peripherals.mouse'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' auto.accessories.player'],
#  [' electronics.video.tv', ' electronics.video.tv', ' accessories.bag'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' accessories.bag', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.mixer', ' electronics.tablet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.components.memory'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.telephone'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' computers.desktop',
#   ' computers.peripherals.mouse',
#   ' construction.tools.saw'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.steam_cooker'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.clocks', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' furniture.living_room.cabinet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.microwave'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' auto.accessories.videoregister'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' furniture.living_room.shelving'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.cartrige',
#   ' computers.components.cpu'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.paper',
#   ' sport.tennis',
#   ' appliances.environment.fan'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.kitchen.table',
#   ' computers.components.videocards'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' apparel.costume',
#   ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.bedroom.blanket',
#   ' furniture.bedroom.blanket',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' apparel.shoes', ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' electronics.telephone',
#   ' appliances.iron'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' sport.bicycle',
#   ' construction.tools.generator'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.printer'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.mouse'],
#  [' computers.components.cpu',
#   ' computers.notebook',
#   ' apparel.sock',
#   ' furniture.living_room.sofa'],
#  [' computers.components.cpu',
#   ' appliances.environment.water_heater',
#   ' computers.peripherals.scanner'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.kitchen.microwave'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.toster'],
#  [' computers.components.cpu', ' computers.peripherals.monitor'],
#  [' computers.components.cpu', ' medicine.tools.tonometer'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' construction.tools.welding',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' computers.notebook', ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.power_supply'],
#  [' computers.components.cpu',
#   ' appliances.environment.climate',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' electronics.tablet',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.dishwasher',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' kids.toys'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.peripherals.camera',
#   ' electronics.tablet',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.steam_cleaner'],
#  [' computers.components.cpu', ' appliances.kitchen.toster', ' sport.tennis'],
#  [' computers.components.cpu', ' accessories.bag', ' sport.tennis'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.notebook', ' sport.ski'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' apparel.trousers'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' auto.accessories.videoregister',
#   ' furniture.living_room.shelving',
#   ' electronics.video.projector',
#   ' apparel.trousers'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook', ' furniture.bedroom.blanket'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' apparel.trousers',
#   ' apparel.trousers',
#   ' country_yard.watering',
#   ' country_yard.watering'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.audio.microphone',
#   ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' accessories.bag',
#   ' sport.bicycle',
#   ' accessories.bag'],
#  [' computers.notebook',
#   ' computers.peripherals.printer',
#   ' computers.components.motherboard',
#   ' electronics.telephone'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.peripherals.camera'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' construction.tools.screw'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook', ' appliances.environment.fan'],
#  [' computers.notebook', ' appliances.environment.water_heater'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.telephone',
#   ' computers.components.memory',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' apparel.costume'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.hdd',
#   ' computers.peripherals.printer'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.components.memory', ' sport.tennis'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' apparel.tshirt', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' apparel.shirt'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook', ' apparel.shirt'],
#  [' computers.notebook', ' electronics.camera.video'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.gaming',
#   ' apparel.sock',
#   ' electronics.clocks'],
#  [' computers.notebook', ' computers.peripherals.scanner', ' apparel.costume'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.notebook',
#   ' furniture.living_room.chair',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.headphone',
#   ' apparel.glove',
#   ' construction.tools.heater',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster'],
#  [' computers.notebook', ' electronics.video.tv'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.components.cooler'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor',
#   ' computers.peripherals.printer',
#   ' computers.peripherals.monitor',
#   ' appliances.iron',
#   ' appliances.kitchen.kettle'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' stationery.cartrige'],
#  [' computers.peripherals.monitor', ' stationery.battery'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' appliances.kitchen.toster'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.printer'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' accessories.bag'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle']]

# %% [markdown]
# Now that we have a transactions list, ggfsdafs
#
# The Apriori implementation at MLxtend receives a binary database

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(buy_transactions).transform(buy_transactions)
binary_database = pd.DataFrame(trans_array, columns=tr_enc.columns_)
binary_database
# Out:
#       accessories.bag   apparel.costume   apparel.glove   apparel.shirt  \
# 0               False             False           False           False
# 1               False             False           False           False
# 2               False             False           False           False
# 3               False             False           False           False
# 4               False             False           False           False
# ..                ...               ...             ...             ...
# 443             False             False           False           False
# 444              True             False           False           False
# 445             False             False           False           False
# 446             False             False           False           False
# 447             False             False           False           False
#
#       apparel.shoes   apparel.sock   apparel.trousers   apparel.tshirt  \
# 0             False          False              False            False
# 1             False          False              False            False
# 2             False          False              False            False
# 3             False          False              False            False
# 4             False          False              False            False
# ..              ...            ...                ...              ...
# 443           False          False              False            False
# 444           False          False              False            False
# 445           False          False              False            False
# 446           False          False              False            False
# 447           False          False              False            False
#
#       appliances.environment.air_heater   appliances.environment.climate  ...  \
# 0                                 False                            False  ...
# 1                                 False                            False  ...
# 2                                 False                            False  ...
# 3                                 False                            False  ...
# 4                                 False                            False  ...
# ..                                  ...                              ...  ...
# 443                               False                            False  ...
# 444                               False                            False  ...
# 445                               False                            False  ...
# 446                               False                            False  ...
# 447                               False                            False  ...
#
#       furniture.living_room.sofa   kids.toys   medicine.tools.tonometer  \
# 0                          False       False                      False
# 1                          False       False                      False
# 2                          False       False                      False
# 3                          False       False                      False
# 4                          False       False                      False
# ..                           ...         ...                        ...
# 443                        False       False                      False
# 444                        False       False                      False
# 445                        False       False                      False
# 446                        False       False                      False
# 447                        False       False                      False
#
#       sport.bicycle   sport.ski   sport.tennis   stationery.battery  \
# 0             False       False          False                False
# 1             False       False          False                False
# 2             False       False           True                False
# 3             False       False          False                False
# 4             False       False          False                False
# ..              ...         ...            ...                  ...
# 443           False       False          False                False
# 444           False       False          False                False
# 445           False       False          False                False
# 446           False       False          False                False
# 447           False       False          False                False
#
#       stationery.cartrige   stationery.paper   stationery.stapler
# 0                   False              False                False
# 1                   False              False                False
# 2                   False              False                False
# 3                   False              False                False
# 4                   False              False                False
# ..                    ...                ...                  ...
# 443                 False              False                False
# 444                 False              False                False
# 445                 False              False                False
# 446                 False              False                False
# 447                 False              False                False
#
# [448 rows x 83 columns]

# %% [markdown]
# ### 1.3  Merge store-clicks and product_df

# %%
clickprod_df = pd.merge(pdf.set_index('Item_ID'), store_clicks.set_index('Item_ID'),on='Item_ID')
clickprod_df = clickprod_df.reset_index()

# %%
clickprod_df = clickprod_df[['Session_ID','Item_ID','Product_Categories','Timestamp']]

# %%
clickprod_df
# Out:
#           Session_ID    Item_ID            Product_Categories  \
# 0                  1  214536500            electronics.tablet
# 1              21133  214536500            electronics.tablet
# 2              26623  214536500            electronics.tablet
# 3              25964  214536500            electronics.tablet
# 4              33429  214536500            electronics.tablet
# ...              ...        ...                           ...
# 20704507     6928129  214535055                    kids.dolls
# 20704508     6927372  214818485   furniture.living_room.chair
# 20704509     6927372  214818485   furniture.living_room.chair
# 20704510     6926506  214646096                 apparel.glove
# 20704511     6926506  214646096                 apparel.glove
#
#                          Timestamp
# 0         2014-04-07T10:54:09.868Z
# 1         2014-04-06T11:07:41.937Z
# 2         2014-04-06T12:54:28.549Z
# 3         2014-04-02T00:37:45.985Z
# 4         2014-04-03T19:49:41.979Z
# ...                            ...
# 20704507  2014-07-28T09:46:10.486Z
# 20704508  2014-07-23T19:32:47.960Z
# 20704509  2014-07-23T19:33:33.705Z
# 20704510  2014-07-27T10:12:04.929Z
# 20704511  2014-07-27T10:23:26.381Z
#
# [20704512 rows x 4 columns]

# %%
#teste
buyers_list = list(store_buys.Session_ID.unique())
new_store_clicks = store_clicks.loc[store_clicks.Session_ID.isin(buyers_list)]
new_store_clicks
# Out:
#           Session_ID                 Timestamp    Item_ID Context
# 23                11  2014-04-03T10:44:35.672Z  214821275       0
# 24                11  2014-04-03T10:45:01.674Z  214821275       0
# 25                11  2014-04-03T10:45:29.873Z  214821371       0
# 26                11  2014-04-03T10:46:12.162Z  214821371       0
# 27                11  2014-04-03T10:46:57.355Z  214821371       0
# ...              ...                       ...        ...     ...
# 20704553     6926707  2014-07-27T13:46:14.563Z  214848757       S
# 20704554     6926707  2014-07-27T13:47:47.168Z  214848986       S
# 20704555     6926707  2014-07-27T13:49:35.200Z  214848945       S
# 20704556     6926707  2014-07-27T13:52:29.177Z  214561477       3
# 20704557     6926707  2014-07-27T13:52:30.033Z  214561477       3
#
# [2040371 rows x 4 columns]

# %% [markdown]
# (Só meti 500 transanctions q tem tipo 2M e demora imenso)

# %%
click_transactions= []
#for i in list(masterdf.Session_ID[:50].unique()):
for i in list(clickprod_df.Session_ID.unique()):
    click_transactions.append(clickprod_df[clickprod_df.Session_ID==i].Product_Categories.values.tolist())
    
click_transactions
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-22-9c38d798b3d5> in <module>
#       3 for i in list(clickprod_df.Session_ID.unique()):
# ----> 4     click_transactions.append(clickprod_df[clickprod_df.Session_ID==i].Product_Categories.values.tolist())
#       5
#
# D:\Apps\ANACONDA\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      64
# ---> 65         return method(self, other)
#      66
#
# D:\Apps\ANACONDA\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#
# D:\Apps\ANACONDA\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#
# D:\Apps\ANACONDA\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     249             with np.errstate(all="ignore"):
# --> 250                 res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     251
#
# D:\Apps\ANACONDA\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# D:\Apps\ANACONDA\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# D:\Apps\ANACONDA\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68     with np.errstate(all="ignore"):
# ---> 69         return op(a, b)
#      70
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(click_transactions).transform(click_transactions)
binary_database2 = pd.DataFrame(trans_array, columns=tr_enc.columns_)
binary_database2
# Out:
#       accessories.bag   accessories.umbrella   apparel.costume  \
# 0               False                  False             False
# 1                True                  False             False
# 2               False                  False             False
# 3               False                  False             False
# 4               False                  False             False
# ..                ...                    ...               ...
# 408             False                  False             False
# 409             False                  False             False
# 410             False                  False             False
# 411             False                  False             False
# 412             False                  False             False
#
#       apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0             False           False           False          False
# 1             False           False           False          False
# 2             False           False           False          False
# 3             False           False           False          False
# 4             False           False           False           True
# ..              ...             ...             ...            ...
# 408           False           False           False          False
# 409           False           False           False          False
# 410           False           False           False          False
# 411           False           False           False          False
# 412           False           False           False          False
#
#       apparel.trousers   apparel.tshirt  \
# 0                False            False
# 1                False            False
# 2                 True            False
# 3                False            False
# 4                False            False
# ..                 ...              ...
# 408              False            False
# 409              False            False
# 410              False            False
# 411              False            False
# 412              False            False
#
#       appliances.environment.air_conditioner  ...   sport.bicycle  \
# 0                                      False  ...           False
# 1                                      False  ...           False
# 2                                      False  ...           False
# 3                                      False  ...           False
# 4                                      False  ...           False
# ..                                       ...  ...             ...
# 408                                    False  ...           False
# 409                                    False  ...           False
# 410                                    False  ...           False
# 411                                    False  ...           False
# 412                                    False  ...           False
#
#       sport.diving   sport.ski   sport.snowboard   sport.tennis  \
# 0            False       False             False          False
# 1            False       False             False          False
# 2            False       False             False          False
# 3            False        True             False          False
# 4            False       False             False          False
# ..             ...         ...               ...            ...
# 408          False       False             False          False
# 409          False       False             False          False
# 410          False       False             False          False
# 411          False       False             False          False
# 412          False       False             False          False
#
#       sport.trainer   stationery.battery   stationery.cartrige  \
# 0             False                False                 False
# 1             False                False                 False
# 2             False                False                 False
# 3             False                False                 False
# 4              True                 True                 False
# ..              ...                  ...                   ...
# 408           False                False                 False
# 409           False                False                 False
# 410           False                False                 False
# 411           False                False                 False
# 412           False                False                 False
#
#       stationery.paper   stationery.stapler
# 0                False                False
# 1                False                False
# 2                 True                False
# 3                False                False
# 4                False                False
# ..                 ...                  ...
# 408              False                False
# 409              False                False
# 410              False                False
# 411              False                False
# 412              False                False
#
# [413 rows x 119 columns]

# %% [markdown]
# ## 1.2. Compute Frequent Itemsets

# %% [markdown]
# * Compute frequent itemsets considering a minimum support of X%.
# * Present frequent itemsets organized by length (number of items).
# * List frequent 1-itemsets, 2-itemsets, 3-itemsets, etc with support of at least Y%.
# * Change X and Y when it makes sense and discuss the results.

# %% [markdown]
# ### 1.2.1 Store Buys

# %%
frequent_itemsets = apriori(binary_database, min_support=0.1,  use_colnames=True)
frequent_itemsets
# Out:
#     support                       itemsets
# 0  0.113839  ( appliances.personal.scales)
# 1  0.116071    ( computers.components.cpu)
# 2  0.180804          ( computers.notebook)
# 3  0.468750        ( electronics.video.tv)

# %% [markdown]
# **What are the most bought products?**
#
# The most bought product is sport.tennis

# %%
frequent_itemsets = apriori(binary_database, min_support=0.05, use_colnames=True)
frequent_itemsets
# Out:
#     support                                           itemsets
# 0  0.058036                      ( appliances.kitchen.blender)
# 1  0.113839                      ( appliances.personal.scales)
# 2  0.116071                        ( computers.components.cpu)
# 3  0.180804                              ( computers.notebook)
# 4  0.082589                   ( computers.peripherals.monitor)
# 5  0.468750                            ( electronics.video.tv)
# 6  0.051339  ( appliances.kitchen.blender,  appliances.pers...

# %%
frequent_itemsets = apriori(binary_database, min_support=0.01, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.031250                                 ( accessories.bag)
# 1   0.011161                                ( apparel.trousers)
# 2   0.017857                   ( appliances.environment.vacuum)
# 3   0.017857             ( appliances.environment.water_heater)
# 4   0.058036                      ( appliances.kitchen.blender)
# 5   0.020089                       ( appliances.kitchen.kettle)
# 6   0.011161                 ( appliances.kitchen.meat_grinder)
# 7   0.026786                ( appliances.kitchen.refrigerators)
# 8   0.024554                       ( appliances.kitchen.toster)
# 9   0.113839                      ( appliances.personal.scales)
# 10  0.116071                        ( computers.components.cpu)
# 11  0.026786                     ( computers.components.memory)
# 12  0.180804                              ( computers.notebook)
# 13  0.082589                   ( computers.peripherals.monitor)
# 14  0.011161                   ( computers.peripherals.printer)
# 15  0.011161                         ( country_yard.lawn_mower)
# 16  0.011161                              ( electronics.clocks)
# 17  0.017857                              ( electronics.tablet)
# 18  0.468750                            ( electronics.video.tv)
# 19  0.031250                         ( furniture.kitchen.table)
# 20  0.046875                                    ( sport.tennis)
# 21  0.011161            ( accessories.bag,  computers.notebook)
# 22  0.013393  ( appliances.environment.vacuum,  appliances.p...
# 23  0.011161  ( appliances.environment.water_heater,  applia...
# 24  0.051339  ( appliances.kitchen.blender,  appliances.pers...
# 25  0.013393  ( computers.components.cpu,  appliances.kitche...
# 26  0.011161  ( appliances.kitchen.toster,  computers.periph...
# 27  0.013393   ( computers.components.cpu,  computers.notebook)
# 28  0.031250         ( computers.components.cpu,  sport.tennis)

# %%
frequent_itemsets = apriori(binary_database, min_support=0.01, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0   0.031250                                 ( accessories.bag)       1
# 1   0.011161                                ( apparel.trousers)       1
# 2   0.017857                   ( appliances.environment.vacuum)       1
# 3   0.017857             ( appliances.environment.water_heater)       1
# 4   0.058036                      ( appliances.kitchen.blender)       1
# 5   0.020089                       ( appliances.kitchen.kettle)       1
# 6   0.011161                 ( appliances.kitchen.meat_grinder)       1
# 7   0.026786                ( appliances.kitchen.refrigerators)       1
# 8   0.024554                       ( appliances.kitchen.toster)       1
# 9   0.113839                      ( appliances.personal.scales)       1
# 10  0.116071                        ( computers.components.cpu)       1
# 11  0.026786                     ( computers.components.memory)       1
# 12  0.180804                              ( computers.notebook)       1
# 13  0.082589                   ( computers.peripherals.monitor)       1
# 14  0.011161                   ( computers.peripherals.printer)       1
# 15  0.011161                         ( country_yard.lawn_mower)       1
# 16  0.011161                              ( electronics.clocks)       1
# 17  0.017857                              ( electronics.tablet)       1
# 18  0.468750                            ( electronics.video.tv)       1
# 19  0.031250                         ( furniture.kitchen.table)       1
# 20  0.046875                                    ( sport.tennis)       1
# 21  0.011161            ( accessories.bag,  computers.notebook)       2
# 22  0.013393  ( appliances.environment.vacuum,  appliances.p...       2
# 23  0.011161  ( appliances.environment.water_heater,  applia...       2
# 24  0.051339  ( appliances.kitchen.blender,  appliances.pers...       2
# 25  0.013393  ( computers.components.cpu,  appliances.kitche...       2
# 26  0.011161  ( appliances.kitchen.toster,  computers.periph...       2
# 27  0.013393   ( computers.components.cpu,  computers.notebook)       2
# 28  0.031250         ( computers.components.cpu,  sport.tennis)       2

# %% [markdown]
# **Which products are bought together?**

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.01) & (frequent_itemsets['length'] == 2)]
frequent_itemsets
# Out:
#      support                                           itemsets  length
# 21  0.011161            ( accessories.bag,  computers.notebook)       2
# 22  0.013393  ( appliances.environment.vacuum,  appliances.p...       2
# 23  0.011161  ( appliances.environment.water_heater,  applia...       2
# 24  0.051339  ( appliances.kitchen.blender,  appliances.pers...       2
# 25  0.013393  ( computers.components.cpu,  appliances.kitche...       2
# 26  0.011161  ( appliances.kitchen.toster,  computers.periph...       2
# 27  0.013393   ( computers.components.cpu,  computers.notebook)       2
# 28  0.031250         ( computers.components.cpu,  sport.tennis)       2

# %% [markdown]
# ### 1.2.2 Store Clicks (Só tá com 500 transactions)

# %%
frequent_itemsets = apriori(binary_database2, min_support=0.2,  use_colnames=True)
frequent_itemsets
# Out:
#     support                                           itemsets
# 0  0.382567                      ( appliances.personal.scales)
# 1  0.992736                              ( electronics.tablet)
# 2  0.380145  ( electronics.tablet,  appliances.personal.sca...

# %% [markdown]
# ### 1.3. Generate Association Rules from Frequent Itemsets

# %% [markdown]
# * Generate association rules with a choosed value (C) for minimum confidence.
# * Generate association rules with a choosed value (L) for minimum lift.
# * Generate association rules with both confidence >= C% and lift >= L.
# * Change C and L when it makes sense and discuss the results.

# %% [markdown]
# ### 1.3.1 Store Buys

# %%
frequent_itemsets = apriori(binary_database, min_support=0.01, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules
# Out:
#                               antecedents                       consequents  \
# 0                      ( accessories.bag)             ( computers.notebook)
# 1        ( appliances.environment.vacuum)     ( appliances.personal.scales)
# 2  ( appliances.environment.water_heater)     ( appliances.personal.scales)
# 3           ( appliances.kitchen.blender)     ( appliances.personal.scales)
# 4           ( appliances.personal.scales)     ( appliances.kitchen.blender)
# 5            ( appliances.kitchen.toster)       ( computers.components.cpu)
# 6            ( appliances.kitchen.toster)  ( computers.peripherals.monitor)
# 7             ( computers.components.cpu)                   ( sport.tennis)
# 8                         ( sport.tennis)       ( computers.components.cpu)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.031250            0.180804  0.011161    0.357143  1.975309
# 1            0.017857            0.113839  0.013393    0.750000  6.588235
# 2            0.017857            0.113839  0.011161    0.625000  5.490196
# 3            0.058036            0.113839  0.051339    0.884615  7.770739
# 4            0.113839            0.058036  0.051339    0.450980  7.770739
# 5            0.024554            0.116071  0.013393    0.545455  4.699301
# 6            0.024554            0.082589  0.011161    0.454545  5.503686
# 7            0.116071            0.046875  0.031250    0.269231  5.743590
# 8            0.046875            0.116071  0.031250    0.666667  5.743590
#
#    leverage  conviction
# 0  0.005511    1.274306
# 1  0.011360    3.544643
# 2  0.009128    2.363095
# 3  0.044733    7.680060
# 4  0.044733    1.715721
# 5  0.010543    1.944643
# 6  0.009133    1.681920
# 7  0.025809    1.304276
# 8  0.025809    2.651786

# %% [markdown]
# * When people buy appliances.environment.fan, computers.components.memory appears in 36% of the transactions.
#
# * When people buy appliances.kitchen.grill, country_yard.lawn_mowe appears in 23% of the transactions.
#
# * When people buy country_yard.lawn_mower, sport.tennis appears in 25% of the transactions.

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2.0)
lift_rules
# Out:
#                                antecedents  \
# 0         ( appliances.environment.vacuum)
# 1            ( appliances.personal.scales)
# 2   ( appliances.environment.water_heater)
# 3            ( appliances.personal.scales)
# 4            ( appliances.kitchen.blender)
# 5            ( appliances.personal.scales)
# 6              ( computers.components.cpu)
# 7             ( appliances.kitchen.toster)
# 8             ( appliances.kitchen.toster)
# 9         ( computers.peripherals.monitor)
# 10             ( computers.components.cpu)
# 11                         ( sport.tennis)
#
#                                consequents  antecedent support  \
# 0            ( appliances.personal.scales)            0.017857
# 1         ( appliances.environment.vacuum)            0.113839
# 2            ( appliances.personal.scales)            0.017857
# 3   ( appliances.environment.water_heater)            0.113839
# 4            ( appliances.personal.scales)            0.058036
# 5            ( appliances.kitchen.blender)            0.113839
# 6             ( appliances.kitchen.toster)            0.116071
# 7              ( computers.components.cpu)            0.024554
# 8         ( computers.peripherals.monitor)            0.024554
# 9             ( appliances.kitchen.toster)            0.082589
# 10                         ( sport.tennis)            0.116071
# 11             ( computers.components.cpu)            0.046875
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.113839  0.013393    0.750000  6.588235  0.011360    3.544643
# 1             0.017857  0.013393    0.117647  6.588235  0.011360    1.113095
# 2             0.113839  0.011161    0.625000  5.490196  0.009128    2.363095
# 3             0.017857  0.011161    0.098039  5.490196  0.009128    1.088898
# 4             0.113839  0.051339    0.884615  7.770739  0.044733    7.680060
# 5             0.058036  0.051339    0.450980  7.770739  0.044733    1.715721
# 6             0.024554  0.013393    0.115385  4.699301  0.010543    1.102679
# 7             0.116071  0.013393    0.545455  4.699301  0.010543    1.944643
# 8             0.082589  0.011161    0.454545  5.503686  0.009133    1.681920
# 9             0.024554  0.011161    0.135135  5.503686  0.009133    1.127860
# 10            0.046875  0.031250    0.269231  5.743590  0.025809    1.304276
# 11            0.116071  0.031250    0.666667  5.743590  0.025809    2.651786

# %% [markdown]
# Lift - how likely item Y is to be purchased when item X is purchased, while controlling for how popular item Y is.
# A lift value greater than 1 means that item Y is likely to be bought if item X is bought
#
# Can you find associations highliting that when people buy a product/set of products also buy other product(s)?
#
# Resposta: gfsdfsddfsvssvgrsfff

# %% [markdown]
# ### 1.2.3 Store Clicks(só tá com 500 transactions)

# %%
frequent_itemsets = apriori(binary_database2, min_support=0.15, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
rules
# Out:
#                       antecedents                     consequents  \
# 0           ( electronics.tablet)   ( appliances.personal.scales)
# 1   ( appliances.personal.scales)           ( electronics.tablet)
# 2  ( electronics.audio.headphone)           ( electronics.tablet)
# 3           ( electronics.tablet)  ( electronics.audio.headphone)
# 4           ( electronics.tablet)   ( furniture.living_room.sofa)
# 5   ( furniture.living_room.sofa)           ( electronics.tablet)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.992736            0.382567  0.380145    0.382927  1.000942
# 1            0.382567            0.992736  0.380145    0.993671  1.000942
# 2            0.188862            0.992736  0.181598    0.961538  0.968574
# 3            0.992736            0.188862  0.181598    0.182927  0.968574
# 4            0.992736            0.179177  0.179177    0.180488  1.007317
# 5            0.179177            0.992736  0.179177    1.000000  1.007317
#
#    leverage  conviction
# 0  0.000358    1.000584
# 1  0.000358    1.147700
# 2 -0.005892    0.188862
# 3 -0.005892    0.992736
# 4  0.001302    1.001600
# 5  0.001302         inf

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
lift_rules
# Out:
#                      antecedents                    consequents  \
# 0          ( electronics.tablet)  ( appliances.personal.scales)
# 1  ( appliances.personal.scales)          ( electronics.tablet)
# 2          ( electronics.tablet)  ( furniture.living_room.sofa)
# 3  ( furniture.living_room.sofa)          ( electronics.tablet)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.992736            0.382567  0.380145    0.382927  1.000942
# 1            0.382567            0.992736  0.380145    0.993671  1.000942
# 2            0.992736            0.179177  0.179177    0.180488  1.007317
# 3            0.179177            0.992736  0.179177    1.000000  1.007317
#
#    leverage  conviction
# 0  0.000358    1.000584
# 1  0.000358    1.147700
# 2  0.001302    1.001600
# 3  0.001302         inf

# %% [markdown]
# ### 1.4. Take a Look at Maximal Patterns: Compute Maximal Frequent Itemsets

# %%
# %timeit FI_apriori = apriori(binary_database, min_support=0.6, use_colnames=True)
# Out:
# 3.52 ms ± 40.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### 1.5. Conclusions

# %% [markdown]
# # 2. Week vs Weekend Purchases

# %% [markdown]
# In this part of the project you should analyse the consumption patterns during the week vs during the weekeed.
#
# **In what follows keep the following question in mind and be creative!**
#
# 1. The most interesting products are the same during the week and the weekend?
# 2. What are the most bought products during the week? And during the weekend?
# 3. There are differences between the sets of products bought during the week and the weekend?
# 4. Can you find different associations highliting that when people click in a product/set of products also buy this product(s) during the week vs the weekend?
# 5. Discuss the results obtained for the week sessions vs weekend sessions.

# %% [markdown]
# ### 2.1. Load and Preprocess Data
#
#  **Product quantities should not be considered.**

# %% [markdown]
# ### 2.1.1Store Buys df
#
# We have to separate this df into 2 different df one with week days and the other with weekend days

# %%
masterdf.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories                 Timestamp
# 0     2859734  214536500   electronics.tablet  2014-05-14T12:06:02.717Z
# 1     4276371  214536500   electronics.tablet  2014-06-04T13:44:10.725Z
# 2     4440056  214536500   electronics.tablet  2014-06-14T19:14:00.581Z
# 3       70532  214536506   electronics.tablet  2014-04-06T09:59:03.143Z
# 4      691119  214536506   electronics.tablet  2014-04-14T15:56:30.514Z

# %%
weeksdf = masterdf
time = weeksdf["Timestamp"].str.split("T", n = 1, expand = True)
weeksdf["Timestamp"] = time[0]
weeksdf.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories   Timestamp
# 0     2859734  214536500   electronics.tablet  2014-05-14
# 1     4276371  214536500   electronics.tablet  2014-06-04
# 2     4440056  214536500   electronics.tablet  2014-06-14
# 3       70532  214536506   electronics.tablet  2014-04-06
# 4      691119  214536506   electronics.tablet  2014-04-14

# %%
teste = weeksdf
teste["Timestamp"] = pd.to_datetime(teste['Timestamp'])
teste['Semana'] = teste['Timestamp'].dt.day_name()

buys_weeknd_df =  teste.loc[teste['Semana'].isin(['Saturday', 'Sunday'])] 
buys_weekday_df = teste.loc[~teste['Semana'].isin(['Saturday', 'Sunday'])]

# %% [markdown]
# ## Weekend

# %%
buys_weeknd_df
# Out:
#         Session_ID    Item_ID          Product_Categories  Timestamp    Semana
# 2          4440056  214536500          electronics.tablet 2014-06-14  Saturday
# 3            70532  214536506          electronics.tablet 2014-04-06    Sunday
# 5           405567  214662742     furniture.kitchen.table 2014-04-06    Sunday
# 6           763567  214662742     furniture.kitchen.table 2014-04-13    Sunday
# 7           842649  214662742     furniture.kitchen.table 2014-04-13    Sunday
# ...            ...        ...                         ...        ...       ...
# 679464     6724562  214789372                sport.tennis 2014-07-27    Sunday
# 679467     6940131  214816352    appliances.ironing_board 2014-07-27    Sunday
# 679475     6797042  214854759      electronics.calculator 2014-07-27    Sunday
# 679476     6711771  214851605   furniture.universal.light 2014-07-27    Sunday
# 679482     6829368  214851182   furniture.universal.light 2014-07-26  Saturday
#
# [267909 rows x 5 columns]

# %%
buy_weeknd_transactions= []

for i in list(buys_weeknd_df.Session_ID[:100].unique()):
    buy_weeknd_transactions.append(buys_weeknd_df[buys_weeknd_df.Session_ID==i].Product_Categories.values.tolist())
    
buy_weeknd_transactions
# Out:
# [[' electronics.tablet', ' sport.tennis'],
#  [' electronics.tablet'],
#  [' furniture.kitchen.table', ' computers.components.memory'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table',
#   ' computers.components.memory',
#   ' kids.toys',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.video.tv'],
#  [' electronics.smartphone', ' computers.components.memory'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.iron',
#   ' appliances.environment.water_heater',
#   ' construction.tools.heater'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' computers.peripherals.scanner'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators', ' medicine.tools.tonometer'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' accessories.bag',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.motherboard'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.environment.water_heater',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' accessories.bag'],
#  [' electronics.video.tv',
#   ' furniture.living_room.cabinet',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.hood',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' country_yard.cultivator',
#   ' apparel.trousers'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' furniture.living_room.shelving',
#   ' appliances.kitchen.blender'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' auto.accessories.player'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' accessories.bag', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.steam_cooker'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.microwave'],
#  [' electronics.video.tv', ' furniture.living_room.shelving'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.kitchen.table',
#   ' computers.components.videocards'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' furniture.bedroom.blanket',
#   ' furniture.bedroom.blanket',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.mouse'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' computers.peripherals.monitor'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.microwave',
#   ' appliances.kitchen.toster'],
#  [' computers.components.cpu', ' medicine.tools.tonometer'],
#  [' computers.components.cpu', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' electronics.tablet',
#   ' appliances.kitchen.coffee_machine',
#   ' appliances.kitchen.dishwasher',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' kids.toys'],
#  [' computers.components.cpu'],
#  [' computers.notebook', ' sport.ski'],
#  [' computers.notebook',
#   ' electronics.video.tv',
#   ' appliances.kitchen.blender',
#   ' apparel.trousers'],
#  [' computers.notebook',
#   ' auto.accessories.videoregister',
#   ' furniture.living_room.shelving',
#   ' electronics.video.projector',
#   ' apparel.trousers'],
#  [' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' construction.tools.screw'],
#  [' computers.notebook'],
#  [' computers.notebook']]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(buy_weeknd_transactions).transform(buy_weeknd_transactions)
buy_weeknd_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
buy_weeknd_binary_db
# Out:
#      accessories.bag   apparel.trousers   appliances.environment.vacuum  \
# 0              False              False                           False
# 1              False              False                           False
# 2              False              False                           False
# 3              False              False                           False
# 4              False              False                           False
# ..               ...                ...                             ...
# 88             False              False                           False
# 89             False              False                           False
# 90             False              False                           False
# 91             False              False                           False
# 92             False              False                           False
#
#      appliances.environment.water_heater   appliances.iron  \
# 0                                  False             False
# 1                                  False             False
# 2                                  False             False
# 3                                  False             False
# 4                                  False             False
# ..                                   ...               ...
# 88                                 False             False
# 89                                 False             False
# 90                                 False             False
# 91                                 False             False
# 92                                 False             False
#
#      appliances.kitchen.blender   appliances.kitchen.coffee_machine  \
# 0                         False                               False
# 1                         False                               False
# 2                         False                               False
# 3                         False                               False
# 4                         False                               False
# ..                          ...                                 ...
# 88                        False                               False
# 89                        False                               False
# 90                        False                               False
# 91                        False                               False
# 92                        False                               False
#
#      appliances.kitchen.dishwasher   appliances.kitchen.hood  \
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# 3                            False                     False
# 4                            False                     False
# ..                             ...                       ...
# 88                           False                     False
# 89                           False                     False
# 90                           False                     False
# 91                           False                     False
# 92                           False                     False
#
#      appliances.kitchen.microwave  ...   electronics.video.projector  \
# 0                           False  ...                         False
# 1                           False  ...                         False
# 2                           False  ...                         False
# 3                           False  ...                         False
# 4                           False  ...                         False
# ..                            ...  ...                           ...
# 88                          False  ...                         False
# 89                          False  ...                         False
# 90                          False  ...                         False
# 91                          False  ...                         False
# 92                          False  ...                         False
#
#      electronics.video.tv   furniture.bedroom.blanket  \
# 0                   False                       False
# 1                   False                       False
# 2                   False                       False
# 3                   False                       False
# 4                    True                       False
# ..                    ...                         ...
# 88                  False                       False
# 89                  False                       False
# 90                  False                       False
# 91                  False                       False
# 92                  False                       False
#
#      furniture.kitchen.table   furniture.living_room.cabinet  \
# 0                      False                           False
# 1                      False                           False
# 2                       True                           False
# 3                       True                           False
# 4                       True                           False
# ..                       ...                             ...
# 88                     False                           False
# 89                     False                           False
# 90                     False                           False
# 91                     False                           False
# 92                     False                           False
#
#      furniture.living_room.shelving   kids.toys   medicine.tools.tonometer  \
# 0                             False       False                      False
# 1                             False       False                      False
# 2                             False       False                      False
# 3                             False       False                      False
# 4                             False        True                      False
# ..                              ...         ...                        ...
# 88                            False       False                      False
# 89                            False       False                      False
# 90                            False       False                      False
# 91                            False       False                      False
# 92                            False       False                      False
#
#      sport.ski   sport.tennis
# 0        False           True
# 1        False          False
# 2        False          False
# 3        False          False
# 4        False          False
# ..         ...            ...
# 88       False          False
# 89       False          False
# 90       False          False
# 91       False          False
# 92       False          False
#
# [93 rows x 40 columns]

# %% [markdown]
# ## WeekDay

# %%
buys_weekday_df
# Out:
#         Session_ID    Item_ID          Product_Categories  Timestamp  \
# 0          2859734  214536500          electronics.tablet 2014-05-14
# 1          4276371  214536500          electronics.tablet 2014-06-04
# 4           691119  214536506          electronics.tablet 2014-04-14
# 8           573948  214662742     furniture.kitchen.table 2014-04-10
# 9           877203  214662742     furniture.kitchen.table 2014-04-14
# ...            ...        ...                         ...        ...
# 679483     6649378  214851182   furniture.universal.light 2014-07-28
# 679484     6649378  214851182   furniture.universal.light 2014-07-28
# 679485     7001599  214571152            stationery.paper 2014-07-24
# 679486     6961172  214571152            stationery.paper 2014-07-28
# 679487     6873084  214847137                sport.tennis 2014-07-23
#
#            Semana
# 0       Wednesday
# 1       Wednesday
# 4          Monday
# 8        Thursday
# 9          Monday
# ...           ...
# 679483     Monday
# 679484     Monday
# 679485   Thursday
# 679486     Monday
# 679487  Wednesday
#
# [411579 rows x 5 columns]

# %%
buy_weekday_transactions= []

for i in list(buys_weekday_df.Session_ID[:500].unique()):
    buy_weekday_transactions.append(buys_weekday_df[buys_weekday_df.Session_ID==i].Product_Categories.values.tolist())
    
buy_weekday_transactions
# Out:
# [[' electronics.tablet'],
#  [' electronics.tablet', ' computers.peripherals.monitor'],
#  [' electronics.tablet',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.grill',
#   ' furniture.living_room.cabinet'],
#  [' furniture.kitchen.table', ' electronics.audio.dictaphone'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table', ' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table'],
#  [' furniture.kitchen.table',
#   ' computers.components.videocards',
#   ' furniture.kitchen.table',
#   ' country_yard.lawn_mower'],
#  [' appliances.kitchen.refrigerators'],
#  [' appliances.kitchen.refrigerators',
#   ' appliances.kitchen.toster',
#   ' computers.peripherals.monitor',
#   ' electronics.clocks'],
#  [' appliances.kitchen.refrigerators',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' computers.notebook'],
#  [' appliances.kitchen.refrigerators', ' appliances.sewing_machine'],
#  [' appliances.kitchen.refrigerators', ' computers.peripherals.monitor'],
#  [' appliances.kitchen.refrigerators',
#   ' construction.tools.screw',
#   ' furniture.kitchen.table',
#   ' stationery.stapler',
#   ' appliances.kitchen.coffee_machine',
#   ' apparel.trousers',
#   ' construction.tools.heater',
#   ' construction.tools.saw',
#   ' construction.tools.heater',
#   ' computers.components.cpu',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' computers.components.hdd',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' construction.tools.heater'],
#  [' appliances.kitchen.refrigerators', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.environment.water_heater'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender'],
#  [' appliances.personal.scales', ' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.kitchen.blender'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales', ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum'],
#  [' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.personal.scales',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum',
#   ' appliances.environment.vacuum'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' computers.peripherals.camera',
#   ' computers.components.memory',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.camera'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.environment.air_heater'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.components.memory'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' stationery.cartrige'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.peripherals.mouse'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' accessories.bag'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' appliances.kitchen.washer'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' appliances.kitchen.mixer', ' electronics.tablet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' computers.components.memory'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.telephone'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.washer',
#   ' computers.desktop',
#   ' computers.peripherals.mouse',
#   ' construction.tools.saw'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.clocks', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.steam_cooker',
#   ' appliances.kitchen.mixer',
#   ' appliances.kitchen.mixer',
#   ' furniture.living_room.cabinet'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' auto.accessories.videoregister'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.cartrige',
#   ' computers.components.cpu'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' stationery.paper',
#   ' sport.tennis',
#   ' appliances.environment.fan'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv',
#   ' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' appliances.iron',
#   ' apparel.costume',
#   ' appliances.kitchen.meat_grinder'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv',
#   ' electronics.video.tv',
#   ' computers.peripherals.monitor',
#   ' computers.peripherals.monitor'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' electronics.video.tv', ' apparel.shoes', ' country_yard.lawn_mower'],
#  [' electronics.video.tv',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' appliances.kitchen.toster',
#   ' medicine.tools.tonometer',
#   ' country_yard.lawn_mower'],
#  [' electronics.video.tv', ' electronics.video.tv'],
#  [' electronics.video.tv'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.joystick',
#   ' computers.components.memory',
#   ' electronics.telephone',
#   ' appliances.iron'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' sport.bicycle',
#   ' construction.tools.generator'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.peripherals.printer'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.notebook',
#   ' apparel.sock',
#   ' furniture.living_room.sofa'],
#  [' computers.components.cpu',
#   ' appliances.environment.water_heater',
#   ' computers.peripherals.scanner'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.kitchen.microwave'],
#  [' computers.components.cpu', ' computers.peripherals.monitor'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' construction.tools.welding',
#   ' electronics.clocks',
#   ' sport.tennis',
#   ' sport.tennis'],
#  [' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.peripherals.monitor',
#   ' sport.tennis',
#   ' appliances.kitchen.toster',
#   ' sport.tennis'],
#  [' computers.components.cpu', ' computers.notebook', ' electronics.clocks'],
#  [' computers.components.cpu',
#   ' computers.components.cpu',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.components.cpu', ' sport.tennis'],
#  [' computers.components.cpu', ' computers.components.power_supply'],
#  [' computers.components.cpu',
#   ' appliances.environment.climate',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' computers.components.cpu'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu',
#   ' computers.peripherals.camera',
#   ' electronics.tablet',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.components.cpu'],
#  [' computers.components.cpu', ' appliances.steam_cleaner'],
#  [' computers.components.cpu', ' appliances.kitchen.toster', ' sport.tennis'],
#  [' computers.components.cpu', ' accessories.bag', ' sport.tennis'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' furniture.bedroom.blanket'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' apparel.trousers',
#   ' apparel.trousers',
#   ' country_yard.watering',
#   ' country_yard.watering'],
#  [' computers.notebook',
#   ' electronics.audio.microphone',
#   ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' accessories.bag',
#   ' sport.bicycle',
#   ' accessories.bag'],
#  [' computers.notebook',
#   ' computers.peripherals.printer',
#   ' computers.components.motherboard',
#   ' electronics.telephone'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.peripherals.camera'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' accessories.bag'],
#  [' computers.notebook', ' appliances.environment.fan'],
#  [' computers.notebook', ' appliances.environment.water_heater'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' electronics.telephone',
#   ' computers.components.memory',
#   ' construction.tools.welding',
#   ' sport.tennis'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' apparel.costume'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.hdd',
#   ' computers.peripherals.printer'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.notebook'],
#  [' computers.notebook', ' apparel.tshirt', ' computers.components.cpu'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook', ' computers.components.cpu'],
#  [' computers.notebook', ' apparel.shirt'],
#  [' computers.notebook', ' electronics.camera.video'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.gaming',
#   ' apparel.sock',
#   ' electronics.clocks'],
#  [' computers.notebook', ' computers.peripherals.scanner', ' apparel.costume'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.notebook',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' accessories.bag'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.environment.vacuum',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' country_yard.lawn_mower'],
#  [' computers.notebook',
#   ' furniture.living_room.chair',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.headphone',
#   ' apparel.glove',
#   ' construction.tools.heater',
#   ' appliances.kitchen.grill',
#   ' appliances.kitchen.toster'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.notebook'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.monitor', ' appliances.kitchen.toster'],
#  [' computers.peripherals.monitor'],
#  [' computers.peripherals.printer'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle', ' accessories.bag'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks'],
#  [' appliances.kitchen.kettle',
#   ' electronics.camera.photo',
#   ' computers.peripherals.mouse',
#   ' sport.ski',
#   ' medicine.tools.tonometer'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle',
#   ' appliances.kitchen.kettle'],
#  [' appliances.kitchen.kettle'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' stationery.cartrige',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.video.tv',
#   ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.notebook',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' stationery.battery'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' appliances.kitchen.washer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.watering',
#   ' appliances.environment.vacuum',
#   ' computers.components.hdd'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.tablet'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.ebooks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.videocards',
#   ' accessories.bag'],
#  [' computers.components.memory', ' furniture.kitchen.table'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' apparel.shoes',
#   ' construction.tools.welding',
#   ' appliances.environment.climate',
#   ' electronics.video.tv'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' electronics.camera.video',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' appliances.environment.climate'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.ebooks',
#   ' accessories.umbrella'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.coffee_grinder',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.environment.fan',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.camera.photo'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.camera',
#   ' computers.peripherals.scanner'],
#  [' computers.components.memory', ' appliances.kitchen.mixer'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' country_yard.watering',
#   ' computers.ebooks',
#   ' computers.ebooks',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.personal.scales',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.cartrige',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' computers.notebook',
#   ' appliances.environment.climate'],
#  [' computers.components.memory', ' accessories.umbrella'],
#  [' computers.components.memory', ' electronics.audio.headphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.videocards'],
#  [' computers.components.memory', ' appliances.iron', ' electronics.clocks'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.environment.vacuum',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' appliances.kitchen.coffee_machine'],
#  [' computers.components.memory', ' computers.components.videocards'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' country_yard.watering'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.ebooks',
#   ' computers.ebooks'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory',
#   ' electronics.clocks',
#   ' electronics.clocks',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' country_yard.watering',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' sport.tennis',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' computers.components.memory',
#   ' country_yard.watering',
#   ' construction.tools.welding',
#   ' furniture.bedroom.pillow',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.juicer'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory',
#   ' stationery.cartrige',
#   ' construction.tools.screw',
#   ' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' appliances.kitchen.microwave',
#   ' auto.accessories.alarm'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' construction.tools.welding',
#   ' computers.components.memory',
#   ' construction.tools.generator',
#   ' apparel.trousers',
#   ' electronics.calculator'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' electronics.audio.subwoofer'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.ebooks',
#   ' appliances.kitchen.blender',
#   ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' appliances.kitchen.washer',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.peripherals.joystick',
#   ' electronics.audio.subwoofer',
#   ' auto.accessories.radar'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' electronics.telephone'],
#  [' computers.components.memory',
#   ' electronics.calculator',
#   ' electronics.calculator'],
#  [' computers.components.memory', ' appliances.kitchen.meat_grinder'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' appliances.kitchen.blender'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' computers.notebook'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' computers.components.cpu',
#   ' sport.tennis',
#   ' appliances.environment.fan',
#   ' appliances.environment.fan',
#   ' sport.tennis',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory',
#   ' computers.peripherals.monitor',
#   ' computers.components.memory',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory', ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' accessories.bag',
#   ' construction.tools.heater'],
#  [' computers.components.memory',
#   ' furniture.living_room.cabinet',
#   ' appliances.iron',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.kitchen.meat_grinder',
#   ' apparel.tshirt',
#   ' sport.tennis'],
#  [' computers.components.memory', ' appliances.environment.fan'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' appliances.kitchen.juicer',
#   ' appliances.kitchen.meat_grinder',
#   ' country_yard.cultivator'],
#  [' computers.components.memory',
#   ' appliances.kitchen.blender',
#   ' computers.peripherals.scanner',
#   ' computers.components.memory'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' appliances.iron',
#   ' appliances.kitchen.blender',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' computers.network.router'],
#  [' computers.components.memory', ' construction.tools.welding'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' stationery.stapler',
#   ' computers.network.router',
#   ' country_yard.lawn_mower'],
#  [' computers.components.memory', ' sport.tennis', ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.iron',
#   ' electronics.telephone',
#   ' sport.tennis',
#   ' appliances.kitchen.meat_grinder',
#   ' sport.tennis'],
#  [' computers.components.memory',
#   ' appliances.kitchen.meat_grinder',
#   ' furniture.universal.light'],
#  [' computers.components.memory',
#   ' computers.components.memory',
#   ' auto.accessories.player',
#   ' construction.tools.welding'],
#  [' computers.components.memory'],
#  [' computers.components.memory'],
#  [' computers.components.memory',
#   ' electronics.telephone',
#   ' construction.tools.welding',
#   ' computers.components.memory'],
#  [' computers.components.memory', ' sport.tennis'],
#  [' computers.components.memory', ' electronics.smartphone'],
#  [' computers.components.memory',
#   ' computers.components.videocards',
#   ' stationery.cartrige',
#   ' electronics.telephone',
#   ' sport.tennis',
#   ' sport.tennis',
#   ' country_yard.lawn_mower',
#   ' appliances.kitchen.toster',
#   ' computers.components.memory',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster',
#   ' appliances.kitchen.toster'],
#  [' computers.components.memory',
#   ' appliances.kitchen.washer',
#   ' sport.tennis'],
#  [' computers.components.memory']]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(buy_weekday_transactions).transform(buy_weekday_transactions)
buy_weekday_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
buy_weekday_binary_db
# Out:
#       accessories.bag   accessories.umbrella   apparel.costume  \
# 0               False                  False             False
# 1               False                  False             False
# 2               False                  False             False
# 3               False                  False             False
# 4               False                  False             False
# ..                ...                    ...               ...
# 444             False                  False             False
# 445             False                  False             False
# 446             False                  False             False
# 447             False                  False             False
# 448             False                  False             False
#
#       apparel.glove   apparel.shirt   apparel.shoes   apparel.sock  \
# 0             False           False           False          False
# 1             False           False           False          False
# 2             False           False           False          False
# 3             False           False           False          False
# 4             False           False           False          False
# ..              ...             ...             ...            ...
# 444           False           False           False          False
# 445           False           False           False          False
# 446           False           False           False          False
# 447           False           False           False          False
# 448           False           False           False          False
#
#       apparel.trousers   apparel.tshirt   appliances.environment.air_heater  \
# 0                False            False                               False
# 1                False            False                               False
# 2                False            False                               False
# 3                False            False                               False
# 4                False            False                               False
# ..                 ...              ...                                 ...
# 444              False            False                               False
# 445              False            False                               False
# 446              False            False                               False
# 447              False            False                               False
# 448              False            False                               False
#
#      ...   furniture.living_room.sofa   furniture.universal.light  \
# 0    ...                        False                       False
# 1    ...                        False                       False
# 2    ...                        False                       False
# 3    ...                        False                       False
# 4    ...                        False                       False
# ..   ...                          ...                         ...
# 444  ...                        False                       False
# 445  ...                        False                       False
# 446  ...                        False                       False
# 447  ...                        False                       False
# 448  ...                        False                       False
#
#       medicine.tools.tonometer   sport.bicycle   sport.ski   sport.tennis  \
# 0                        False           False       False          False
# 1                        False           False       False          False
# 2                        False           False       False          False
# 3                        False           False       False          False
# 4                        False           False       False          False
# ..                         ...             ...         ...            ...
# 444                      False           False       False           True
# 445                      False           False       False          False
# 446                      False           False       False           True
# 447                      False           False       False           True
# 448                      False           False       False          False
#
#       stationery.battery   stationery.cartrige   stationery.paper  \
# 0                  False                 False              False
# 1                  False                 False              False
# 2                  False                 False              False
# 3                  False                 False              False
# 4                  False                 False              False
# ..                   ...                   ...                ...
# 444                False                 False              False
# 445                False                 False              False
# 446                False                  True              False
# 447                False                 False              False
# 448                False                 False              False
#
#       stationery.stapler
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 444                False
# 445                False
# 446                False
# 447                False
# 448                False
#
# [449 rows x 87 columns]

# %% [markdown]
# ### 2.1.2 Clicks Buys df
#
# The same has to be done for the clicks df

# %%
clickprod_df.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories                 Timestamp
# 0           1  214536500   electronics.tablet  2014-04-07T10:54:09.868Z
# 1       21133  214536500   electronics.tablet  2014-04-06T11:07:41.937Z
# 2       26623  214536500   electronics.tablet  2014-04-06T12:54:28.549Z
# 3       25964  214536500   electronics.tablet  2014-04-02T00:37:45.985Z
# 4       33429  214536500   electronics.tablet  2014-04-03T19:49:41.979Z

# %%
weeksdf = clickprod_df[:500]
time = weeksdf["Timestamp"].str.split("T", n = 1, expand = True)
weeksdf["Timestamp"] = time[0]
weeksdf.head(5)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Session_ID    Item_ID   Product_Categories   Timestamp
# 0           1  214536500   electronics.tablet  2014-04-07
# 1       21133  214536500   electronics.tablet  2014-04-06
# 2       26623  214536500   electronics.tablet  2014-04-06
# 3       25964  214536500   electronics.tablet  2014-04-02
# 4       33429  214536500   electronics.tablet  2014-04-03

# %%
teste = weeksdf
teste["Timestamp"] = pd.to_datetime(teste['Timestamp'])
teste['Semana'] = teste['Timestamp'].dt.day_name()

clicks_weeknd_df =  teste.loc[teste['Semana'].isin(['Saturday', 'Sunday'])] 
clicks_weekday_df = teste.loc[~teste['Semana'].isin(['Saturday', 'Sunday'])]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Weekend

# %%
clicks_weeknd_df
# Out:
#      Session_ID    Item_ID            Product_Categories  Timestamp    Semana
# 1         21133  214536500            electronics.tablet 2014-04-06    Sunday
# 2         26623  214536500            electronics.tablet 2014-04-06    Sunday
# 10       141376  214536500            electronics.tablet 2014-04-06    Sunday
# 17       483849  214536500            electronics.tablet 2014-04-06    Sunday
# 34       666396  214536500            electronics.tablet 2014-04-12  Saturday
# ..          ...        ...                           ...        ...       ...
# 485      859688  214536506            electronics.tablet 2014-04-13    Sunday
# 486      859688  214536506            electronics.tablet 2014-04-13    Sunday
# 487      865129  214536506            electronics.tablet 2014-04-12  Saturday
# 490     1899381  214536506            electronics.tablet 2014-05-03  Saturday
# 499      151891  214577561   electronics.audio.headphone 2014-04-05  Saturday
#
# [155 rows x 5 columns]

# %%
clicks_weeknd_transactions= []
for i in list(buys_weeknd_df.Session_ID[:150].unique()):
    clicks_weeknd_transactions.append(clicks_weeknd_df[clicks_weeknd_df.Session_ID==i].Product_Categories.values.tolist())
    
#clicks_weeknd_transactions

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(clicks_weeknd_transactions).transform(clicks_weeknd_transactions)
click_weeknd_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
click_weeknd_binary_db
# Out:
#       electronics.tablet
# 0                   True
# 1                   True
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 133                False
# 134                False
# 135                False
# 136                False
# 137                False
#
# [138 rows x 1 columns]

# %% [markdown]
# ## WeekDay

# %%
clicks_weekday_df
# Out:
#      Session_ID    Item_ID            Product_Categories  Timestamp     Semana
# 0             1  214536500            electronics.tablet 2014-04-07     Monday
# 3         25964  214536500            electronics.tablet 2014-04-02  Wednesday
# 4         33429  214536500            electronics.tablet 2014-04-03   Thursday
# 5         53412  214536500            electronics.tablet 2014-04-03   Thursday
# 6         73463  214536500            electronics.tablet 2014-04-03   Thursday
# ..          ...        ...                           ...        ...        ...
# 494     6861812  214536506            electronics.tablet 2014-07-23  Wednesday
# 495     6861812  214536506            electronics.tablet 2014-07-23  Wednesday
# 496           1  214577561   electronics.audio.headphone 2014-04-07     Monday
# 497       56398  214577561   electronics.audio.headphone 2014-04-02  Wednesday
# 498       60088  214577561   electronics.audio.headphone 2014-04-02  Wednesday
#
# [345 rows x 5 columns]

# %%
click_weekday_transactions= []
for i in list(clicks_weekday_df.Session_ID.unique()):
    click_weekday_transactions.append(clicks_weekday_df[clicks_weekday_df.Session_ID==i].Product_Categories.values.tolist())
    
click_weekday_transactions
# Out:
# [[' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.audio.headphone'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet',
#   ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet'],
#  [' electronics.tablet', ' electronics.tablet'],
#  [' electronics.audio.headphone'],
#  [' electronics.audio.headphone']]

# %%
tr_enc = TransactionEncoder()
trans_array = tr_enc.fit(click_weekday_transactions).transform(click_weekday_transactions)
click_weekday_binary_db = pd.DataFrame(trans_array, columns=tr_enc.columns_)
click_weekday_binary_db
# Out:
#       electronics.audio.headphone   electronics.tablet
# 0                            True                 True
# 1                           False                 True
# 2                           False                 True
# 3                           False                 True
# 4                           False                 True
# ..                            ...                  ...
# 283                         False                 True
# 284                         False                 True
# 285                         False                 True
# 286                          True                False
# 287                          True                False
#
# [288 rows x 2 columns]

# %% [markdown]
# ### 2.2. Compute Frequent Itemsets

# %% [markdown]
# * Compute frequent itemsets considering a minimum support of X%.
# * Present frequent itemsets organized by length (number of items).
# * List frequent 1-itemsets, 2-itemsets, 3-itemsets, etc with support of at least Y%.
# * Change X and Y when it makes sense and discuss the results.

# %% [markdown]
# ### 2.2.1 Buys Week Day

# %%
frequent_itemsets = apriori(buy_weekday_binary_db, min_support=0.1,  use_colnames=True)
frequent_itemsets
# Out:
#     support                        itemsets
# 0  0.251670  ( computers.components.memory)
# 1  0.140312           ( computers.notebook)
# 2  0.380846         ( electronics.video.tv)

# %%
frequent_itemsets = apriori(buy_weekday_binary_db, min_support=0.02, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0   0.024499                                 ( accessories.bag)       1
# 1   0.020045                      ( appliances.environment.fan)       1
# 2   0.020045                                 ( appliances.iron)       1
# 3   0.073497                      ( appliances.kitchen.blender)       1
# 4   0.031180                       ( appliances.kitchen.kettle)       1
# 5   0.048998                 ( appliances.kitchen.meat_grinder)       1
# 6   0.022272                       ( appliances.kitchen.toster)       1
# 7   0.075724                      ( appliances.personal.scales)       1
# 8   0.086860                        ( computers.components.cpu)       1
# 9   0.251670                     ( computers.components.memory)       1
# 10  0.140312                              ( computers.notebook)       1
# 11  0.057906                   ( computers.peripherals.monitor)       1
# 12  0.024499                      ( construction.tools.welding)       1
# 13  0.033408                           ( country_yard.watering)       1
# 14  0.020045                           ( electronics.telephone)       1
# 15  0.380846                            ( electronics.video.tv)       1
# 16  0.024499                         ( furniture.kitchen.table)       1
# 17  0.053452                                    ( sport.tennis)       1
# 18  0.028953  ( appliances.kitchen.blender,  appliances.pers...       2
# 19  0.046771  ( computers.components.memory,  appliances.kit...       2
# 20  0.037862  ( computers.components.memory,  appliances.kit...       2
# 21  0.022272         ( computers.components.cpu,  sport.tennis)       2
# 22  0.031180  ( computers.components.memory,  country_yard.w...       2
# 23  0.028953      ( computers.components.memory,  sport.tennis)       2

# %%
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['support'] >= 0.02) & (frequent_itemsets['length'] == 2)]
frequent_itemsets
# Out:
#      support                                           itemsets  length
# 18  0.028953  ( appliances.kitchen.blender,  appliances.pers...       2
# 19  0.046771  ( computers.components.memory,  appliances.kit...       2
# 20  0.037862  ( computers.components.memory,  appliances.kit...       2
# 21  0.022272         ( computers.components.cpu,  sport.tennis)       2
# 22  0.031180  ( computers.components.memory,  country_yard.w...       2
# 23  0.028953      ( computers.components.memory,  sport.tennis)       2

# %% [markdown]
# ### 2.2.2 Buys Weekend

# %%
frequent_itemsets = apriori(buy_weeknd_binary_db, min_support=0.1,  use_colnames=True)
frequent_itemsets
# Out:
#     support                                           itemsets
# 0  0.139785                      ( appliances.kitchen.blender)
# 1  0.193548                      ( appliances.personal.scales)
# 2  0.150538                        ( computers.components.cpu)
# 3  0.129032                              ( computers.notebook)
# 4  0.430108                            ( electronics.video.tv)
# 5  0.118280  ( appliances.kitchen.blender,  appliances.pers...

# %% [markdown]
# ### 2.2.3 Clicks WeekDay

# %%
frequent_itemsets = apriori(click_weekday_binary_db, min_support=0.1,  use_colnames=True)
frequent_itemsets
# Out:
#     support               itemsets
# 0  0.993056  ( electronics.tablet)

# %% [markdown]
# ### 2.2.4 Clicks Weekend

# %%
frequent_itemsets = apriori(click_weeknd_binary_db, min_support=0.01,  use_colnames=True)
frequent_itemsets
# Out:
#     support               itemsets
# 0  0.014493  ( electronics.tablet)

# %% [markdown]
# ### 2.3. Generate Association Rules from Frequent Itemsets

# %% [markdown]
# * Generate association rules with a choosed value (C) for minimum confidence.
# * Generate association rules with a choosed value (L) for minimum lift.
# * Generate association rules with both confidence >= C% and lift >= L.
# * Change C and L when it makes sense and discuss the results.

# %% [markdown]
# ### 2.3.1 Buys Week Day

# %%
frequent_itemsets = apriori(buy_weekday_binary_db, min_support=0.02, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules
# Out:
#                           antecedents                     consequents  \
# 0       ( appliances.kitchen.blender)   ( appliances.personal.scales)
# 1       ( appliances.personal.scales)   ( appliances.kitchen.blender)
# 2       ( appliances.kitchen.blender)  ( computers.components.memory)
# 3  ( appliances.kitchen.meat_grinder)  ( computers.components.memory)
# 4         ( computers.components.cpu)                 ( sport.tennis)
# 5                     ( sport.tennis)     ( computers.components.cpu)
# 6            ( country_yard.watering)  ( computers.components.memory)
# 7                     ( sport.tennis)  ( computers.components.memory)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.073497            0.075724  0.028953    0.393939  5.202317
# 1            0.075724            0.073497  0.028953    0.382353  5.202317
# 2            0.073497            0.251670  0.046771    0.636364  2.528560
# 3            0.048998            0.251670  0.037862    0.772727  3.070394
# 4            0.086860            0.053452  0.022272    0.256410  4.797009
# 5            0.053452            0.086860  0.022272    0.416667  4.797009
# 6            0.033408            0.251670  0.031180    0.933333  3.708555
# 7            0.053452            0.251670  0.028953    0.541667  2.152286
#
#    leverage  conviction
# 0  0.023388    1.525056
# 1  0.023388    1.500053
# 2  0.028274    2.057906
# 3  0.025531    3.292650
# 4  0.017629    1.272944
# 5  0.017629    1.565383
# 6  0.022773   11.224944
# 7  0.015501    1.632719

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2.0)
lift_rules
# Out:
#                            antecedents                         consequents  \
# 0        ( appliances.kitchen.blender)       ( appliances.personal.scales)
# 1        ( appliances.personal.scales)       ( appliances.kitchen.blender)
# 2       ( computers.components.memory)       ( appliances.kitchen.blender)
# 3        ( appliances.kitchen.blender)      ( computers.components.memory)
# 4       ( computers.components.memory)  ( appliances.kitchen.meat_grinder)
# 5   ( appliances.kitchen.meat_grinder)      ( computers.components.memory)
# 6          ( computers.components.cpu)                     ( sport.tennis)
# 7                      ( sport.tennis)         ( computers.components.cpu)
# 8       ( computers.components.memory)            ( country_yard.watering)
# 9             ( country_yard.watering)      ( computers.components.memory)
# 10      ( computers.components.memory)                     ( sport.tennis)
# 11                     ( sport.tennis)      ( computers.components.memory)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.073497            0.075724  0.028953    0.393939  5.202317
# 1             0.075724            0.073497  0.028953    0.382353  5.202317
# 2             0.251670            0.073497  0.046771    0.185841  2.528560
# 3             0.073497            0.251670  0.046771    0.636364  2.528560
# 4             0.251670            0.048998  0.037862    0.150442  3.070394
# 5             0.048998            0.251670  0.037862    0.772727  3.070394
# 6             0.086860            0.053452  0.022272    0.256410  4.797009
# 7             0.053452            0.086860  0.022272    0.416667  4.797009
# 8             0.251670            0.033408  0.031180    0.123894  3.708555
# 9             0.033408            0.251670  0.031180    0.933333  3.708555
# 10            0.251670            0.053452  0.028953    0.115044  2.152286
# 11            0.053452            0.251670  0.028953    0.541667  2.152286
#
#     leverage  conviction
# 0   0.023388    1.525056
# 1   0.023388    1.500053
# 2   0.028274    1.137988
# 3   0.028274    2.057906
# 4   0.025531    1.119409
# 5   0.025531    3.292650
# 6   0.017629    1.272944
# 7   0.017629    1.565383
# 8   0.022773    1.103282
# 9   0.022773   11.224944
# 10  0.015501    1.069599
# 11  0.015501    1.632719

# %% [markdown]
# ### 2.3.2 Buys Weekend

# %%
frequent_itemsets = apriori(buy_weeknd_binary_db, min_support=0.1, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules
# Out:
#                      antecedents                    consequents  \
# 0  ( appliances.kitchen.blender)  ( appliances.personal.scales)
# 1  ( appliances.personal.scales)  ( appliances.kitchen.blender)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0            0.139785            0.193548  0.11828    0.846154  4.371795
# 1            0.193548            0.139785  0.11828    0.611111  4.371795
#
#    leverage  conviction
# 0  0.091224    5.241935
# 1  0.091224    2.211982

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2.0)
lift_rules
# Out:
#                      antecedents                    consequents  \
# 0  ( appliances.kitchen.blender)  ( appliances.personal.scales)
# 1  ( appliances.personal.scales)  ( appliances.kitchen.blender)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0            0.139785            0.193548  0.11828    0.846154  4.371795
# 1            0.193548            0.139785  0.11828    0.611111  4.371795
#
#    leverage  conviction
# 0  0.091224    5.241935
# 1  0.091224    2.211982

# %% [markdown]
# ### 2.3.3 Clicks WeekDay

# %%
frequent_itemsets = apriori(click_weekday_binary_db, min_support=0.02, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2.0)
lift_rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# ### 2.3.4 Clicks Weekend

# %%
frequent_itemsets = apriori(click_weeknd_binary_db, min_support=0.01, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
lift_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2.0)
lift_rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# ### 2.4. Conclusions

# %% [markdown]
# # 3. [Only Groups of 3] Spring vs Summer Purchases

# %% [markdown]
# In this part of the project you should analyse the consumption patterns during the Spring months (April and May) vs Summer months (June and July).
#
# **In what follows keep the following question in mind and be creative!**
#
# 1. The most interesting products are the same during the Spring and the Summer?
# 2. What are the most bought products during the Spring? And during the Summer?
# 3. There are differences between the sets of products bought during the Spring and the Summer?
# 4. Can you find different associations highliting that when people click in a product/set of products also buy this product(s) during the Spring vs the Summer?
# 5. Discuss the results obtained for the Spring sessions vs Summer sessions.

# %% [markdown]
# ### 3.1. Load and Preprocess Data
#
#  **Product quantities should not be considered.**

# %% [markdown]
# ### 3.1.1Store Buys df
#
# We have to separate this df into 2 different df one with summer months and the other with Spring months

# %%
masterdf.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories   Timestamp
# 0     2859734  214536500   electronics.tablet  2014-05-14
# 1     4276371  214536500   electronics.tablet  2014-06-04
# 2     4440056  214536500   electronics.tablet  2014-06-14
# 3       70532  214536506   electronics.tablet  2014-04-06
# 4      691119  214536506   electronics.tablet  2014-04-14

# %%
time = masterdf["Timestamp"].astype(str).str.split("-", n = 2, expand = True)
masterdf["Timestamp"] = time[1]
masterdf.head(5)
# Out:
#    Session_ID    Item_ID   Product_Categories Timestamp     Semana
# 0     2859734  214536500   electronics.tablet        05  Wednesday
# 1     4276371  214536500   electronics.tablet        06  Wednesday
# 2     4440056  214536500   electronics.tablet        06   Saturday
# 3       70532  214536506   electronics.tablet        04     Sunday
# 4      691119  214536506   electronics.tablet        04     Monday

# %%
teste = masterdf
teste = teste.drop("Semana",axis=1)
spring_df =  teste.loc[teste['Timestamp'].isin(['04', '05'])] 
summer_df = teste.loc[teste['Timestamp'].isin(['06', '07'])]

# %%
spring_df.head(10)
# Out:
#     Session_ID    Item_ID        Product_Categories Timestamp
# 0      2859734  214536500        electronics.tablet        05
# 3        70532  214536506        electronics.tablet        04
# 4       691119  214536506        electronics.tablet        04
# 5       405567  214662742   furniture.kitchen.table        04
# 6       763567  214662742   furniture.kitchen.table        04
# 7       842649  214662742   furniture.kitchen.table        04
# 8       573948  214662742   furniture.kitchen.table        04
# 9       877203  214662742   furniture.kitchen.table        04
# 10      655821  214662742   furniture.kitchen.table        04
# 11     1002166  214662742   furniture.kitchen.table        04

# %%
summer_df.head(10)
# Out:
#     Session_ID    Item_ID                 Product_Categories Timestamp
# 1      4276371  214536500                 electronics.tablet        06
# 2      4440056  214536500                 electronics.tablet        06
# 16     6355708  214662742            furniture.kitchen.table        07
# 25     3770444  214757390   appliances.kitchen.refrigerators        06
# 26     4040279  214757390   appliances.kitchen.refrigerators        06
# 27     4343874  214757390   appliances.kitchen.refrigerators        06
# 28     4468136  214757390   appliances.kitchen.refrigerators        06
# 78     3703813  214551617         appliances.personal.scales        06
# 79     4212793  214551617         appliances.personal.scales        06
# 80     4212793  214551617         appliances.personal.scales        06

# %% [markdown]
# ### 2.1.2 Clicks Buys df
#
# The same has to be done for the clicks df

# %% [markdown]
# ### 3.2. Compute Frequent Itemsets

# %% [markdown]
# * Compute frequent itemsets considering a minimum support of X%.
# * Present frequent itemsets organized by length (number of items).
# * List frequent 1-itemsets, 2-itemsets, 3-itemsets, etc with support of at least Y%.
# * Change X and Y when it makes sense and discuss the results.

# %% [markdown]
# ### 3.3. Generate Association Rules from Frequent Itemsets

# %% [markdown]
# * Generate association rules with a choosed value (C) for minimum confidence.
# * Generate association rules with a choosed value (L) for minimum lift.
# * Generate association rules with both confidence >= C% and lift >= L.
# * Change C and L when it makes sense and discuss the results.

# %% [markdown]
# ### 3.4. Conclusions

# %% [markdown]
# ## 4. Conclusions
# Draw some conclusions about this project work.
